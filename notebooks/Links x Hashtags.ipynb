# %%
import psycopg2
import pandas as pd
import config
from matplotlib import pylab as plt
import seaborn as sns
import numpy as np
from IPython.display import display, HTML
import re


color_palette = sns.color_palette(palette='muted', n_colors=None, desat=.75)
sns.set(context='notebook', palette=color_palette, style='whitegrid', font='sans-serif', font_scale=1.5, color_codes=False, rc=None)
pd.set_option('display.max_colwidth', -1)
table_styles = [{'selector': 'td',
                 'props': [('min-width', '100px'), ('text-align', 'center')]},
                {'selector': 'tr',
                 'props': [('border-bottom', '1px dotted black')]},
                {'selector': 'th',
                 'props': [('text-align', 'center')]}
               ]

# %matplotlib inline

directory = "url_top_lists/"
stream = "comparison"

# %%
def compareRows(row, df_to_compare, column_name):
    comparison_row = df_to_compare.loc[df_to_compare[column_name] == row[column_name]]
    if comparison_row.empty:
        comparison = " - "
    else:
        percentage_dif = row['percentage'] - comparison_row['percentage'].values[0]
        difference = "(%s. / %.3f%% / %.3f%%)" % (comparison_row['rank'].values[0], comparison_row['percentage'].values[0], percentage_dif)
        if comparison_row['rank'].values[0] == row['rank']:
            comparison = " = <br>" + difference
        else:
            if comparison_row['rank'].values[0] > row['rank']:
                comparison = " v <br>" + difference
            else:
                comparison = " ^ <br>" + difference
    return comparison

def getOpacity(val):
    value = abs(float(re.findall(r"[-+]?\d*\.\d+|\d+", val.split("/")[2])[0]))
    if value < 0.005:
        return 1
    if value < 0.01:
        return 0.95
    if value < 0.05:
        return 0.8
    if value < 0.1:
        return 0.7
    if value < 0.5:
        return 0.6
    if value < 1:
        return 0.5
    if value < 10:
        return 0.3
    if value < 40:
        return 0.2
    if value < 80:
        return 0.1
    if value < 100:
        return 0.05

def colorComparisonField(val):
    
    if isinstance(val, str):
        if ' ^ ' in val or ' v ' in val:
            return 'background-color: rgba(246, 185, 59, %s)' %getOpacity(val)
        if ' = ' in val:
            return 'background-color: rgba(184, 233, 148, %s)' %getOpacity(val)
        if ' - ' in val and len(val) == 3:
            return 'background-color: #e55039' 
    return ''

def generateRankingDataframe(series, attribute_name):
    size = series.sum()
    rank = []
    parameter = []
    count = []
    percentage = []

    i = 1
    for index, value in series.iteritems():
        rank.append(i)
        parameter.append(index)
        count.append(value)
        percentage.append((value/size)*100)
        i += 1

    data = {'rank': rank, attribute_name: parameter, 'value': count, 'percentage': percentage}
    return pd.DataFrame(data=data)

def generateComparisonDataframes(df1, df2, column_name, size):
    compare_list = []
    for index, row in df1.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df2, column_name))

    data = {'rank': df1['rank'][:size], column_name: df1[column_name][:size], 'value': df1['value'][:size], 'percentage': df1['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df1_compared = pd.DataFrame(data=data)
    df1_compared.set_index(keys='rank', inplace=True)
    
    compare_list = []
    for index, row in df2.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df1, column_name))

    data = {'rank': df2['rank'][:size], column_name: df2[column_name][:size], 'value': df2['value'][:size], 'percentage': df2['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df2_compared = pd.DataFrame(data=data)
    df2_compared.set_index(keys='rank', inplace=True)
    
    return df1_compared, df2_compared

def getPrettyComparisonDataframe(df, title):
    s = df.style.applymap(colorComparisonField)
    s.set_caption(title)
    s.set_table_styles(table_styles)
    return s

# %%
conn = None
try:
    # read connection parameters
    paramsS17 = config.cfgAzureS17()
    paramsS03 = config.cfgAzureS03()

    paramsF17 = config.cfgAzureF17()
    paramsF03 = config.cfgAzureF03()
    
    # connect to the PostgreSQL server
    print('Connecting to the PostgreSQL database...')
    connS17 = psycopg2.connect(**paramsS17)
    connS03 = psycopg2.connect(**paramsS03)
    
    connF17 = psycopg2.connect(**paramsF17)
    connF03 = psycopg2.connect(**paramsF03)

    # create a cursor
    curS17 = connS17.cursor()
    curS03 = connS03.cursor()
    
    curF17 = connF17.cursor()
    curF03 = connF03.cursor()

    # execute a statement
    print('PostgreSQL database version:')
    
    curS17.execute('SELECT version()')
    curS03.execute('SELECT version()')
    curF17.execute('SELECT version()')
    curF03.execute('SELECT version()')
    
    # display the PostgreSQL database server version
    db_version_curS17 = curS17.fetchone()
    db_version_curS03 = curS03.fetchone()
    db_version_curF17 = curF17.fetchone()
    db_version_curF03 = curF03.fetchone()
    
    print(db_version_curS17)
    print(db_version_curS03)
    print(db_version_curF17)
    print(db_version_curF03)

    # close the communication with the PostgreSQL
    curS17.close()
    curS03.close()
    curF17.close()
    curF03.close()

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)

# %%
tweetsS03 = pd.read_sql_query('''SELECT tu.tweet_id, tu.short_url, tu.resolved_url || ' ' || ti.hashtags as url_with_tags, tu.top_level_domain, tu.is_twitter_url, tu.is_media FROM tweets_urls as tu 
                                 INNER JOIN tweets_info as ti ON tu.tweet_id = ti.id;''', connS03 )

print("Number of Tweets: %s" %len(tweetsS03))
tweetsS03.head()
# Out:
# Number of Tweets: 40339
#              tweet_id  \
# 0  952676758066728960
# 1  952677513070809088
# 2  952677827647688704
# 3  952678045743271943
# 4  952678284810248193
#
#                                                       short_url  \
# 0  http://bit.ly/2D8B0mK
# 1  http://EyeEm.com/p/117474810
# 2  http://fapza.com/skinny/small-teenie-auf-mallorca-im-urlaub/
# 3  http://rp-online.de/1.7320027
# 4  https://twitter.com/maltekaufmann/status/952661547880509440
#
#                                                                                                                 url_with_tags  \
# 0  None
# 1  https://www.eyeem.com/p/117474810 Evening Winter Tower Rheinturm View Rhine Rhein Hochwasser HighWater Architecture Sunset
# 2  http://fapza.com/skinny/small-teenie-auf-mallorca-im-urlaub/ fapza
# 3  None
# 4  https://twitter.com/maltekaufmann/status/952661547880509440 Merkel
#
#   top_level_domain  is_twitter_url is_media
# 0  dalyaakota.ru    False           None
# 1  eyeem.com        False           False
# 2  fapza.com        False           False
# 3  rp-online.de     False           False
# 4  twitter.com      True            False

# %%
tweetsS03['url_with_tags'].value_counts()
# Out:
# https://farm5.staticflickr.com/4658/27991711159_fca7ac03bb_o.jpg EXO                                                                                                                                                                                               31
# https://farm5.staticflickr.com/4632/25898289958_0b5d369677_o.jpg EXO                                                                                                                                                                                               31
# https://www.instagram.com/p/BeGyLOHn6YR/?taken-by=exopassion12 EXO                                                                                                                                                                                                 31
# https://www.emma-care.de/blog/teufelskralle-fuers-pferd-was-ist-das TEUFELSKRALLE                                                                                                                                                                                  30
# https://pi2.17bullets.com/tw_post.php?messageId=achievement&values=&locale=en_US ParadiseIsland2 GameInsight                                                                                                                                                       28
# http://www.the-sz.com/products/vbbinfo/?f=3 BVG                                                                                                                                                                                                                    23
# https://pi2.17bullets.com/tw_post.php?messageId=achievement&values=&locale=en_US GameInsight ParadiseIsland2                                                                                                                                                       22
# https://fcbayern.com/goretzka FCBayern Goretzka                                                                                                                                                                                                                    22
# https://www.amazon.com/Shally-Vintage-Bracelet-Tassel-Bohemia/dp/B0753D9LQ4/ref=sr_1_2?s=apparel&ie=UTF8&qid=1514463817&sr=1-2&nodeID=7147440011&psd=1&keywords=coin+bracelets+for+women giveaway                                                                  20
# http://www.es-wird-morgen.de/ ewm eswirdmorgen lautfm                                                                                                                                                                                                              19
# http://webradio.m945.de/ NowPlaying                                                                                                                                                                                                                                19
# http://on4us.eu/up1sn/ infos                                                                                                                                                                                                                                       18
# https://www.campact.de/campact/unterstuetzen/kampagne-beendet/ Bienensterben                                                                                                                                                                                       15
# http://der-x-code.com/ Wahrheit                                                                                                                                                                                                                                    14
# http://www.my-dirty-hobby.com/profil/2801014-LAUREEN-PINK LaureenPinkPorn                                                                                                                                                                                          12
# http://webradio.afkmax.de/ NowPlaying                                                                                                                                                                                                                              12
# http://www.bestbet4u.com/offers/offers.php?bpofferid=547 William                                                                                                                                                                                                   12
# https://www.emma-care.de/blog/reiskeimoel-fuer-s-pferd-fakten-und-vorteile REISKEIMÖL                                                                                                                                                                              11
# https://m.weibo.cn/status/4197985359508180 EXOL iHeartAwards BestFanArmy                                                                                                                                                                                           10
# https://www.facebook.com/ZukunftHeimat/posts/812757952237279 Cottbus                                                                                                                                                                                               10
# http://www.tagesschau.de/ausland/syrien-truppen-afrin-101.html Afrin Syrien                                                                                                                                                                                        9
# https://store.playstation.com/de-de/home/games PS4share                                                                                                                                                                                                            9
# http://www.bestbet4u.com/offers/offers.php?bpofferid=1102 1xBet                                                                                                                                                                                                    9
# https://weibo.cn/comment/FEPCmyBSo EXO                                                                                                                                                                                                                             9
# https://www.instagram.com/p/BeEpgStHcW4/ フィッシャーズ公式 フィッシャーズ fischers                                                                                                                                                                                                9
# https://www.amazon.com/Shally-Stylish-Artificial-Necklace-Valentines/dp/B0753DNRJL/ref=sr_1_5?s=apparel&ie=UTF8&qid=1514462386&sr=1-5&nodeID=7141123011&psd=1&keywords=valentine+day+gifts+for+her giveaway                                                        9
# http://www.bestbet4u.com/offers/offers.php?bpofferid=1028 Ladbrokes                                                                                                                                                                                                9
# http://wx3.sinaimg.cn/large/a157f83bly1fnk017dgu2j20zk0qogoh.jpg EXO                                                                                                                                                                                               9
# http://www.bestbet4u.com/offers/offers.php?bpofferid=1030 Ironbet                                                                                                                                                                                                  8
# https://www.binance.com/?ref=10809690 LiteCoin                                                                                                                                                                                                                     8
#                                                                                                                                                                                                                                                                   ..
# https://www.facebook.com/events/178951156032477/ Geflüchtete Merseburg                                                                                                                                                                                             1
# http://politicalscience.ku.dk/calendar/debate-with-carles-puigdemont/ MP Dänemark Uni Tak Denmark Katalonien Spanien                                                                                                                                               1
# https://www.nzz.ch/sport/die-olympiasiegerin-simone-biles-sagt-auch-sie-sei-vom-teamarzt-sexuell-missbraucht-worden-ld.1347908 SimoneBiles                                                                                                                         1
# https://twitter.com/googuns_lulz/status/953914106662223873 MTVHottest                                                                                                                                                                                              1
# https://social-booster.de/news/48339_87.html nachricht                                                                                                                                                                                                             1
# https://ingosbuchfabrik.blogspot.de/2016/04/bartitsu.html?platform=hootsuite Amazon Kindle Sachbuch AmazonKindle Serie Selbstverteidigung Geschichte Kampfkunst SelfDefense Buch book ebooks London ebook books MustRead series Nonfiction Paperback paperbacks    1
# https://thebuzzard.org/ FakeNews UnwortDesJahres AlternativeFakten Qualitätsjournalismus                                                                                                                                                                           1
# https://www.fir.rwth-aachen.de/veranstaltungen/rwth-zertifikatskurs-chief-supply-chain-manager RWTH SupplyChain Logistik chiefsupplychainmanager rwthcampus clustersmartlogistik rwth                                                                              1
# http://tuppu.net/c923e5a6 ChocolateDogStudio Castteam                                                                                                                                                                                                              1
# http://toastradio.com/np/FB11E557780F6CA0 nowplaying                                                                                                                                                                                                               1
# https://globalnews.ca/video/3966557/global-durham-100/ toronto news                                                                                                                                                                                                1
# https://twitter.com/ohenning/status/913556600992014336 Groko                                                                                                                                                                                                       1
# https://www.zsclions.ch/saison/spielplaene/spieldetail/action/vorschau/game/klo-zsc-20180120/ Nilsson                                                                                                                                                              1
# https://www.youtube.com/watch?v=XB1nP99tWMg&feature=youtu.be BITCONNECTX Coincheck Hangout                                                                                                                                                                         1
# http://www.faz.net/aktuell/rhein-main/rheinland-pfalz-spd-ueberlaesst-delegierten-groko-entscheidung-15407854.html?utm_content=buffer050fd&utm_medium=social&utm_source=twitter.com&utm_campaign=GEPC%253Ds30 SPD Dreyer                                           1
# http://live.musical.ly/live/318938624983638016?_branch_match_id=link-482956914901282831 lively musically                                                                                                                                                           1
# https://www.jobsrmine.com/tester-frankfurt-am-main-hessen/22883740 hiring frankfurtammain dejobs itcommunications jobs                                                                                                                                             1
# https://twitter.com/WolfgangMichal/status/954837516846354434 spdbpt18                                                                                                                                                                                              1
# http://www.faz.net/aktuell/wissen/was-haben-kreative-was-andere-nicht-haben-15402549.html?GEPC=s3 Kreative Piraten Bildung Forschung Wissenschaft Technik DIY Gehirn Psychologie Medizin                                                                           1
# http://www.greenpeace.org/austria/de/presse/presseaussendungen/Greenpeace-Auftakt-internationaler-Kampagne-zum-Schutz-der-Antarktis/ Antarktis AntarcticSanctuary Meeresschutz                                                                                     1
# http://www.ebay.de/itm/like/302607577991?clk_rvr_id=1524771312757&lgeo=1&vectorid=229487&utm_medium=twitter&utm_source=dlvr.it&item=302607577991&rmvSB=true Bundesliga                                                                                             1
# https://www.berlin.de/aktuelles/berlin/5157300-958092-rbb-strahlt-thadeusz-und-die-beobachter-.html?utm_source=dlvr.it&utm_medium=twitter Berlin                                                                                                                   1
# https://www.amnesty.de/mitmachen/urgent-action/zwangsraeumungen-kenia Kenia EU EU                                                                                                                                                                                  1
# http://www.gutjahr.biz/2018/01/hatespeech Hatespeech                                                                                                                                                                                                               1
# https://www.youtube.com/watch?v=iYs2KDXtq1g ReaktionsDrache                                                                                                                                                                                                        1
# http://www.aloeveradortmund.de/ AloeVera                                                                                                                                                                                                                           1
# https://www.sportschau.de/handballem2018/video-deutschland-gegen-slowenien---die-dramatische-schlussphase-100.html ehfeuro2018 badboys SLOGER                                                                                                                      1
# http://www.strassenbahn-hagen.de/ Hagen VRR                                                                                                                                                                                                                        1
# https://twitter.com/vamp_kris2102/status/954286111467110400/photo/1 Saab                                                                                                                                                                                           1
# https://www.twitch.tv/prallerholaender LIvestream Earlybird Fortnite FortniteBattleRoyale                                                                                                                                                                          1
# Name: url_with_tags, Length: 13573, dtype: int64
