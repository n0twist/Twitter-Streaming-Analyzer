# %% [markdown]
# # Youtube URL Comparison (Sampled vs Filtered)

# %%
import psycopg2
import pandas as pd
import config
from matplotlib import pylab as plt
import seaborn as sns
import numpy as np
from IPython.display import display, HTML
import re


color_palette = sns.color_palette(palette='muted', n_colors=None, desat=.75)
sns.set(context='notebook', palette=color_palette, style='whitegrid', font='sans-serif', font_scale=1.5, color_codes=False, rc=None)
pd.set_option('display.max_colwidth', -1)
table_styles = [{'selector': 'td',
                 'props': [('min-width', '100px'), ('text-align', 'center')]},
                {'selector': 'tr',
                 'props': [('border-bottom', '1px dotted black')]},
                {'selector': 'th',
                 'props': [('text-align', 'center')]}
               ]

# %matplotlib inline

directory = "url_top_lists/"
stream = "comparison"
# Out:
# /media/raid/home/pflugmacher/virtualenv/twitterenvold/lib/python3.4/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /media/raid/home/pflugmacher/virtualenv/twitterenvold/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## Util Methods

# %%
def compareRows(row, df_to_compare, column_name):
    comparison_row = df_to_compare.loc[df_to_compare[column_name] == row[column_name]]
    if comparison_row.empty:
        comparison = " - "
    else:
        percentage_dif = row['percentage'] - comparison_row['percentage'].values[0]
        difference = "(%s. / %.3f%% / %.3f%%)" % (comparison_row['rank'].values[0], comparison_row['percentage'].values[0], percentage_dif)
        if comparison_row['rank'].values[0] == row['rank']:
            comparison = " = <br>" + difference
        else:
            if comparison_row['rank'].values[0] > row['rank']:
                comparison = " v <br>" + difference
            else:
                comparison = " ^ <br>" + difference
    return comparison

def getOpacity(val):
    value = abs(float(re.findall(r"[-+]?\d*\.\d+|\d+", val.split("/")[2])[0]))
    if value < 0.005:
        return 1
    if value < 0.01:
        return 0.95
    if value < 0.05:
        return 0.8
    if value < 0.1:
        return 0.7
    if value < 0.5:
        return 0.6
    if value < 1:
        return 0.5
    if value < 10:
        return 0.3
    if value < 40:
        return 0.2
    if value < 80:
        return 0.1
    if value < 100:
        return 0.05

def colorComparisonField(val):
    
    if isinstance(val, str):
        if ' ^ ' in val or ' v ' in val:
            return 'background-color: rgba(246, 185, 59, %s)' %getOpacity(val)
        if ' = ' in val:
            return 'background-color: rgba(184, 233, 148, %s)' %getOpacity(val)
        if ' - ' in val and len(val) == 3:
            return 'background-color: #e55039' 
    return ''

def generateRankingDataframe(series, attribute_name):
    size = series.sum()
    rank = []
    parameter = []
    count = []
    percentage = []

    i = 1
    for index, value in series.iteritems():
        rank.append(i)
        parameter.append(index)
        count.append(value)
        percentage.append((value/size)*100)
        i += 1

    data = {'rank': rank, attribute_name: parameter, 'value': count, 'percentage': percentage}
    return pd.DataFrame(data=data)

def generateComparisonDataframes(df1, df2, column_name, size):
    compare_list = []
    for index, row in df1.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df2, column_name))

    data = {'rank': df1['rank'][:size], column_name: df1[column_name][:size], 'value': df1['value'][:size], 'percentage': df1['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df1_compared = pd.DataFrame(data=data)
    df1_compared.set_index(keys='rank', inplace=True)
    
    compare_list = []
    for index, row in df2.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df1, column_name))

    data = {'rank': df2['rank'][:size], column_name: df2[column_name][:size], 'value': df2['value'][:size], 'percentage': df2['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df2_compared = pd.DataFrame(data=data)
    df2_compared.set_index(keys='rank', inplace=True)
    
    return df1_compared, df2_compared

def getPrettyComparisonDataframe(df, title):
    s = df.style.applymap(colorComparisonField)
    s.set_caption(title)
    s.set_table_styles(table_styles)
    return s

# %%
conn = None
try:
    # read connection parameters
    paramsS17 = config.cfgAzureS17()
    paramsS03 = config.cfgAzureS03()

    paramsF17 = config.cfgAzureF17()
    paramsF03 = config.cfgAzureF03()
    
    # connect to the PostgreSQL server
    print('Connecting to the PostgreSQL database...')
    connS17 = psycopg2.connect(**paramsS17)
    connS03 = psycopg2.connect(**paramsS03)
    
    connF17 = psycopg2.connect(**paramsF17)
    connF03 = psycopg2.connect(**paramsF03)

    # create a cursor
    curS17 = connS17.cursor()
    curS03 = connS03.cursor()
    
    curF17 = connF17.cursor()
    curF03 = connF03.cursor()

    # execute a statement
    print('PostgreSQL database version:')
    
    curS17.execute('SELECT version()')
    curS03.execute('SELECT version()')
    curF17.execute('SELECT version()')
    curF03.execute('SELECT version()')
    
    # display the PostgreSQL database server version
    db_version_curS17 = curS17.fetchone()
    db_version_curS03 = curS03.fetchone()
    db_version_curF17 = curF17.fetchone()
    db_version_curF03 = curF03.fetchone()
    
    print(db_version_curS17)
    print(db_version_curS03)
    print(db_version_curF17)
    print(db_version_curF03)

    # close the communication with the PostgreSQL
    curS17.close()
    curS03.close()
    curF17.close()
    curF03.close()

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 9.6.9, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.9, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.9, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.9, compiled by Visual C++ build 1800, 64-bit',)

# %% [markdown]
# ## Query URLs

# %% [markdown]
# ### Sampled

# %%
urlsS03 = pd.read_sql_query("SELECT * FROM tweets_urls where top_level_domain ~ 'youtube.com';", connS03 )
print("# of URLs sampled 03: %s" %len(urlsS03))

urlsS17 = pd.read_sql_query("SELECT * FROM tweets_urls where top_level_domain ~ 'youtube.com';", connS17 )
print("# of URLs sampled 17: %s" %len(urlsS17))

urlsS = urlsS17.append(urlsS03)
print("# of URLs sampled: %s" %len(urlsS))

urlsS.head()
# Out:
# # of URLs sampled 03: 3262
# # of URLs sampled 17: 2961
# # of URLs sampled: 6223
#              tweet_id                      short_url  \
# 0  988176579586088960  http://youtu.be/ucIOOEMq-VQ?a
# 1  988176646686560256  http://youtu.be/8adyeFS7HD8?a
# 2  988077828091580427  https://youtu.be/Jv0cdrYUkMI
# 3  988178949342572544  http://youtu.be/RffAHV3tcgM?a
# 4  988024824336343040  https://youtu.be/tiyBmhd5Yrc
#
#                                                      resolved_url  \
# 0  https://www.youtube.com/watch?v=ucIOOEMq-VQ&feature=youtu.be&a
# 1  https://www.youtube.com/watch?v=8adyeFS7HD8&feature=youtu.be&a
# 2  https://www.youtube.com/watch?v=Jv0cdrYUkMI&feature=youtu.be
# 3  https://www.youtube.com/watch?v=RffAHV3tcgM&feature=youtu.be&a
# 4  https://www.youtube.com/watch?v=tiyBmhd5Yrc&feature=youtu.be
#
#    response_code                    domain top_level_domain  is_twitter_url  \
# 0  200            https://www.youtube.com/  youtube.com      False
# 1  200            https://www.youtube.com/  youtube.com      False
# 2  200            https://www.youtube.com/  youtube.com      False
# 3  200            https://www.youtube.com/  youtube.com      False
# 4  200            https://www.youtube.com/  youtube.com      False
#
#    is_media  is_processed  failed
# 0  False     True          False
# 1  False     True          False
# 2  False     True          False
# 3  False     True          False
# 4  False     True          False

# %%
len(urlsF)
# Out:
# 439201

# %% [markdown]
# ###  Filtered

# %%
urlsF03 = pd.read_sql_query("SELECT * FROM tweets_urls where top_level_domain ~ 'youtube.com';", connF03 )
print("# of URLs filtered 03: %s" %len(urlsF03))

urlsF17 = pd.read_sql_query("SELECT * FROM tweets_urls where top_level_domain ~ 'youtube.com';", connF17 )
print("# of URLs filtered 17: %s" %len(urlsF17))

urlsF = urlsF17.append(urlsF03)
print("# of URLs filtered: %s" %len(urlsF))

urlsF.head()
# Out:
# # of URLs filtered 03: 233499
# # of URLs filtered 17: 205702
# # of URLs filtered: 439201
#              tweet_id                                    short_url  \
# 0  988437991168335872  http://youtu.be/3xxDlETxKz8?a
# 1  988437993630420993  http://youtu.be/HscStpberLc?a
# 2  988438000773271552  https://www.youtube.com/watch?v=TIPbGZu_cpg
# 3  988438008289484801  http://youtu.be/GeWueT1_-oA?a
# 4  988438008192995331  https://youtu.be/K8jLEgPsXKw
#
#                                                      resolved_url  \
# 0  https://www.youtube.com/watch?v=3xxDlETxKz8&feature=youtu.be&a
# 1  https://www.youtube.com/watch?v=HscStpberLc&feature=youtu.be&a
# 2  https://www.youtube.com/watch?v=TIPbGZu_cpg
# 3  https://www.youtube.com/watch?v=GeWueT1_-oA&feature=youtu.be&a
# 4  https://www.youtube.com/watch?v=K8jLEgPsXKw&feature=youtu.be
#
#    response_code                    domain top_level_domain  is_twitter_url  \
# 0  200.0          https://www.youtube.com/  youtube.com      False
# 1  200.0          https://www.youtube.com/  youtube.com      False
# 2  200.0          https://www.youtube.com/  youtube.com      False
# 3  200.0          https://www.youtube.com/  youtube.com      False
# 4  200.0          https://www.youtube.com/  youtube.com      False
#
#   is_media  is_processed  failed
# 0  False    True          False
# 1  False    True          False
# 2  False    True          False
# 3  False    True          False
# 4  False    True          False

# %% [markdown]
# ## URLs

# %% [markdown]
# ### Calendar Week 03 - URLs - Sampled x Filtered

# %%
attribute = 'resolved_url'
column_name = 'url'
    
df_sampled = generateRankingDataframe(urlsS03[attribute].value_counts(), column_name)
df_filtered = generateRankingDataframe(urlsF03[attribute].value_counts(), column_name)

df_sampled_comparison, df_filtered_comparison = generateComparisonDataframes(df_sampled, df_filtered, column_name, 25)

# %%
s = getPrettyComparisonDataframe(df_sampled_comparison, "CW 03 - Youtube URLs - Sampled Data (compared to Filtered Data)")
s
# Out:
# <style  type="text/css" >
#     #T_2a79fe0c_9595_11e8_a015_0025905a74ac td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_2a79fe0c_9595_11e8_a015_0025905a74ac tr {
#           border-bottom: 1px dotted black;
#     }    #T_2a79fe0c_9595_11e8_a015_0025905a74ac th {
#           text-align: center;
#     }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow0_col0 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow1_col0 {
#             background-color:  #e55039;
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow2_col0 {
#             background-color:  #e55039;
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow3_col0 {
#             background-color:  #e55039;
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow4_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow5_col0 {
#             background-color:  #e55039;
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow6_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow7_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow8_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow9_col0 {
#             background-color:  #e55039;
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow10_col0 {
#             background-color:  #e55039;
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow11_col0 {
#             background-color:  #e55039;
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow12_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow13_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow14_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow15_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow16_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow17_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow18_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow19_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow20_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow21_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow22_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow23_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_2a79fe0c_9595_11e8_a015_0025905a74acrow24_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }</style>
# <table id="T_2a79fe0c_9595_11e8_a015_0025905a74ac" ><caption>CW 03 - Youtube URLs - Sampled Data (compared to Filtered Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >difference (rank / percentage / diff)</th>
#         <th class="col_heading level0 col1" >percentage</th>
#         <th class="col_heading level0 col2" >url</th>
#         <th class="col_heading level0 col3" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2a79fe0c_9595_11e8_a015_0025905a74aclevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow0_col0" class="data row0 col0" > = <br>(1. / 2.836% / -0.752%)</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow0_col1" class="data row0 col1" >2.08461</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow0_col2" class="data row0 col2" >https://www.youtube.com/watch?v=Dw-2hh6G_D8&feature=youtu.be&a</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow0_col3" class="data row0 col3" >68</td>
#     </tr>    <tr>
#         <th id="T_2a79fe0c_9595_11e8_a015_0025905a74aclevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow1_col0" class="data row1 col0" > - </td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow1_col1" class="data row1 col1" >0.429185</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow1_col2" class="data row1 col2" >https://www.youtube.com/results?search_query=sehun+solo</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow1_col3" class="data row1 col3" >14</td>
#     </tr>    <tr>
#         <th id="T_2a79fe0c_9595_11e8_a015_0025905a74aclevel0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow2_col0" class="data row2 col0" > - </td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow2_col1" class="data row2 col1" >0.429185</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow2_col2" class="data row2 col2" >https://www.youtube.com/results?search_query=sehun+fancam</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow2_col3" class="data row2 col3" >14</td>
#     </tr>    <tr>
#         <th id="T_2a79fe0c_9595_11e8_a015_0025905a74aclevel0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow3_col0" class="data row3 col0" > - </td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow3_col1" class="data row3 col1" >0.429185</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow3_col2" class="data row3 col2" >https://www.youtube.com/results?search_query=sehun+focus</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow3_col3" class="data row3 col3" >14</td>
#     </tr>    <tr>
#         <th id="T_2a79fe0c_9595_11e8_a015_0025905a74aclevel0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow4_col0" class="data row4 col0" > ^ <br>(3. / 0.358% / -0.021%)</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow4_col1" class="data row4 col1" >0.337216</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow4_col2" class="data row4 col2" >https://www.youtube.com/watch?v=Xeqf_HHEMJk</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow4_col3" class="data row4 col3" >11</td>
#     </tr>    <tr>
#         <th id="T_2a79fe0c_9595_11e8_a015_0025905a74aclevel0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow5_col0" class="data row5 col0" > - </td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow5_col1" class="data row5 col1" >0.30656</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow5_col2" class="data row5 col2" >https://www.youtube.com/watch?v=EP7TYxOrXoU&feature=share</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow5_col3" class="data row5 col3" >10</td>
#     </tr>    <tr>
#         <th id="T_2a79fe0c_9595_11e8_a015_0025905a74aclevel0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow6_col0" class="data row6 col0" > ^ <br>(4. / 0.294% / 0.013%)</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow6_col1" class="data row6 col1" >0.30656</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_0025905a74acrow6_col2" class="data row6 col2" >https://www.youtube.com/channel/UCXDyAGuwSxI4Y-X-N6RXqew/videos</td>
#         <td id="T_2a79fe0c_9595_11e8_a015_002

# %%
s = getPrettyComparisonDataframe(df_filtered_comparison, "CW 03 - Youtube URLs - Filtered Data (compared to Sampled Data)")
s
# Out:
# <style  type="text/css" >
#     #T_38a2e4b2_9595_11e8_a015_0025905a74ac td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_38a2e4b2_9595_11e8_a015_0025905a74ac tr {
#           border-bottom: 1px dotted black;
#     }    #T_38a2e4b2_9595_11e8_a015_0025905a74ac th {
#           text-align: center;
#     }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow0_col0 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow1_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow2_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow3_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow4_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow5_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow6_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow7_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow8_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow9_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow10_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow11_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow12_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow13_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow14_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow15_col0 {
#             background-color:  #e55039;
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow16_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow17_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow18_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow19_col0 {
#             background-color:  #e55039;
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow20_col0 {
#             background-color:  #e55039;
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow21_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow22_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow23_col0 {
#             background-color:  #e55039;
#         }    #T_38a2e4b2_9595_11e8_a015_0025905a74acrow24_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }</style>
# <table id="T_38a2e4b2_9595_11e8_a015_0025905a74ac" ><caption>CW 03 - Youtube URLs - Filtered Data (compared to Sampled Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >difference (rank / percentage / diff)</th>
#         <th class="col_heading level0 col1" >percentage</th>
#         <th class="col_heading level0 col2" >url</th>
#         <th class="col_heading level0 col3" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_38a2e4b2_9595_11e8_a015_0025905a74aclevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow0_col0" class="data row0 col0" > = <br>(1. / 2.085% / 0.752%)</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow0_col1" class="data row0 col1" >2.83641</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow0_col2" class="data row0 col2" >https://www.youtube.com/watch?v=Dw-2hh6G_D8&feature=youtu.be&a</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow0_col3" class="data row0 col3" >6623</td>
#     </tr>    <tr>
#         <th id="T_38a2e4b2_9595_11e8_a015_0025905a74aclevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow1_col0" class="data row1 col0" > v <br>(13. / 0.184% / 0.399%)</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow1_col1" class="data row1 col1" >0.582872</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow1_col2" class="data row1 col2" >https://www.youtube.com/user/videodeutschland/videos</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow1_col3" class="data row1 col3" >1361</td>
#     </tr>    <tr>
#         <th id="T_38a2e4b2_9595_11e8_a015_0025905a74aclevel0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow2_col0" class="data row2 col0" > v <br>(5. / 0.337% / 0.021%)</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow2_col1" class="data row2 col1" >0.358032</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow2_col2" class="data row2 col2" >https://www.youtube.com/watch?v=Xeqf_HHEMJk</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow2_col3" class="data row2 col3" >836</td>
#     </tr>    <tr>
#         <th id="T_38a2e4b2_9595_11e8_a015_0025905a74aclevel0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow3_col0" class="data row3 col0" > v <br>(7. / 0.307% / -0.013%)</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow3_col1" class="data row3 col1" >0.293791</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow3_col2" class="data row3 col2" >https://www.youtube.com/channel/UCXDyAGuwSxI4Y-X-N6RXqew/videos</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow3_col3" class="data row3 col3" >686</td>
#     </tr>    <tr>
#         <th id="T_38a2e4b2_9595_11e8_a015_0025905a74aclevel0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow4_col0" class="data row4 col0" > v <br>(8. / 0.276% / -0.025%)</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow4_col1" class="data row4 col1" >0.250965</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow4_col2" class="data row4 col2" >https://www.youtube.com/watch?v=JEVtiDeHKdc&feature=youtu.be&a</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow4_col3" class="data row4 col3" >586</td>
#     </tr>    <tr>
#         <th id="T_38a2e4b2_9595_11e8_a015_0025905a74aclevel0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow5_col0" class="data row5 col0" > v <br>(14. / 0.153% / 0.050%)</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow5_col1" class="data row5 col1" >0.203427</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow5_col2" class="data row5 col2" >https://www.youtube.com/watch?v=XBcu5D7EI6g&feature=youtu.be</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow5_col3" class="data row5 col3" >475</td>
#     </tr>    <tr>
#         <th id="T_38a2e4b2_9595_11e8_a015_0025905a74aclevel0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow6_col0" class="data row6 col0" > v <br>(17. / 0.153% / 0.009%)</td>
#         <td id="T_38a2e4b2_9595_11e8_a015_0025905a74acrow6_col1" class="data row6 col1" >0.161885</td>
#         <td id="T_38a2e4b2

# %% [markdown]
# ### Calendar Week 17 - URLs - Sampled x Filtered

# %%
attribute = 'resolved_url'
column_name = 'url'
    
df_sampled = generateRankingDataframe(urlsS17[attribute].value_counts(), column_name)
df_filtered = generateRankingDataframe(urlsF17[attribute].value_counts(), column_name)

df_sampled_comparison, df_filtered_comparison = generateComparisonDataframes(df_sampled, df_filtered, column_name, 25)

# %%
s = getPrettyComparisonDataframe(df_sampled_comparison, "CW 17 - Youtube URLs - Sampled Data (compared to Filtered Data)")
s
# Out:
# <style  type="text/css" >
#     #T_69096842_9595_11e8_a015_0025905a74ac td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_69096842_9595_11e8_a015_0025905a74ac tr {
#           border-bottom: 1px dotted black;
#     }    #T_69096842_9595_11e8_a015_0025905a74ac th {
#           text-align: center;
#     }    #T_69096842_9595_11e8_a015_0025905a74acrow0_col0 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow1_col0 {
#             background-color:  #e55039;
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow2_col0 {
#             background-color:  #e55039;
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow3_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow4_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow5_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow6_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow7_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow8_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow9_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow10_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow11_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow12_col0 {
#             background-color:  #e55039;
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow13_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow14_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow15_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow16_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow17_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow18_col0 {
#             background-color:  #e55039;
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow19_col0 {
#             background-color:  #e55039;
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow20_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow21_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow22_col0 {
#             background-color:  #e55039;
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow23_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_69096842_9595_11e8_a015_0025905a74acrow24_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }</style>
# <table id="T_69096842_9595_11e8_a015_0025905a74ac" ><caption>CW 17 - Youtube URLs - Sampled Data (compared to Filtered Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >difference (rank / percentage / diff)</th>
#         <th class="col_heading level0 col1" >percentage</th>
#         <th class="col_heading level0 col2" >url</th>
#         <th class="col_heading level0 col3" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_69096842_9595_11e8_a015_0025905a74aclevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow0_col0" class="data row0 col0" > v <br>(44. / 0.039% / 1.211%)</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow0_col1" class="data row0 col1" >1.24958</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow0_col2" class="data row0 col2" >https://www.youtube.com/watch?v=F-eMt3SrfFU&feature=youtu.be</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow0_col3" class="data row0 col3" >37</td>
#     </tr>    <tr>
#         <th id="T_69096842_9595_11e8_a015_0025905a74aclevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow1_col0" class="data row1 col0" > - </td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow1_col1" class="data row1 col1" >1.21581</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow1_col2" class="data row1 col2" >https://www.youtube.com/watch?v=tBWJ3bvJuT0&feature=youtu.be</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow1_col3" class="data row1 col3" >36</td>
#     </tr>    <tr>
#         <th id="T_69096842_9595_11e8_a015_0025905a74aclevel0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow2_col0" class="data row2 col0" > - </td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow2_col1" class="data row2 col1" >1.11449</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow2_col2" class="data row2 col2" >https://www.youtube.com/watch?v=tzni9QRNMEU&feature=youtu.be</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow2_col3" class="data row2 col3" >33</td>
#     </tr>    <tr>
#         <th id="T_69096842_9595_11e8_a015_0025905a74aclevel0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow3_col0" class="data row3 col0" > ^ <br>(2. / 0.586% / -0.181%)</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow3_col1" class="data row3 col1" >0.405268</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow3_col2" class="data row3 col2" >https://www.youtube.com/user/videodeutschland/videos</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow3_col3" class="data row3 col3" >12</td>
#     </tr>    <tr>
#         <th id="T_69096842_9595_11e8_a015_0025905a74aclevel0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow4_col0" class="data row4 col0" > ^ <br>(3. / 0.214% / 0.191%)</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow4_col1" class="data row4 col1" >0.405268</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow4_col2" class="data row4 col2" >https://www.youtube.com/watch?v=zvKjfWSPI7s</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow4_col3" class="data row4 col3" >12</td>
#     </tr>    <tr>
#         <th id="T_69096842_9595_11e8_a015_0025905a74aclevel0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow5_col0" class="data row5 col0" > v <br>(157. / 0.017% / 0.321%)</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow5_col1" class="data row5 col1" >0.337724</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow5_col2" class="data row5 col2" >https://www.youtube.com/channel/UC_dZp8bZipnjntBGLVHm6rw/about?sub_confirmation=1</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow5_col3" class="data row5 col3" >10</td>
#     </tr>    <tr>
#         <th id="T_69096842_9595_11e8_a015_0025905a74aclevel0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow6_col0" class="data row6 col0" > ^ <br>(1. / 0.717% / -0.379%)</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow6_col1" class="data row6 col1" >0.337724</td>
#         <td id="T_69096842_9595_11e8_a015_0025905a74acrow6_col2" class="data row6 col2" >https://www.youtube.

# %%
s = getPrettyComparisonDataframe(df_filtered_comparison, "CW 17 - Youtube URLs - Filtered Data (compared to Sampled Data)")
s
# Out:
# <style  type="text/css" >
#     #T_6ad2aeae_9595_11e8_a015_0025905a74ac td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_6ad2aeae_9595_11e8_a015_0025905a74ac tr {
#           border-bottom: 1px dotted black;
#     }    #T_6ad2aeae_9595_11e8_a015_0025905a74ac th {
#           text-align: center;
#     }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow0_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow1_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow2_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow3_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow4_col0 {
#             background-color:  #e55039;
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow5_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow6_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow7_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow8_col0 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow9_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow10_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow11_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow12_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow13_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow14_col0 {
#             background-color:  #e55039;
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow15_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow16_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow17_col0 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow18_col0 {
#             background-color:  #e55039;
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow19_col0 {
#             background-color:  #e55039;
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow20_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow21_col0 {
#             background-color:  #e55039;
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow22_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow23_col0 {
#             background-color:  #e55039;
#         }    #T_6ad2aeae_9595_11e8_a015_0025905a74acrow24_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }</style>
# <table id="T_6ad2aeae_9595_11e8_a015_0025905a74ac" ><caption>CW 17 - Youtube URLs - Filtered Data (compared to Sampled Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >difference (rank / percentage / diff)</th>
#         <th class="col_heading level0 col1" >percentage</th>
#         <th class="col_heading level0 col2" >url</th>
#         <th class="col_heading level0 col3" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6ad2aeae_9595_11e8_a015_0025905a74aclevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow0_col0" class="data row0 col0" > v <br>(7. / 0.338% / 0.379%)</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow0_col1" class="data row0 col1" >0.716571</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow0_col2" class="data row0 col2" >https://www.youtube.com/watch?v=6bTQkwftlf0&feature=youtu.be&a</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow0_col3" class="data row0 col3" >1474</td>
#     </tr>    <tr>
#         <th id="T_6ad2aeae_9595_11e8_a015_0025905a74aclevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow1_col0" class="data row1 col0" > v <br>(4. / 0.405% / 0.181%)</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow1_col1" class="data row1 col1" >0.585799</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow1_col2" class="data row1 col2" >https://www.youtube.com/user/videodeutschland/videos</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow1_col3" class="data row1 col3" >1205</td>
#     </tr>    <tr>
#         <th id="T_6ad2aeae_9595_11e8_a015_0025905a74aclevel0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow2_col0" class="data row2 col0" > v <br>(5. / 0.405% / -0.191%)</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow2_col1" class="data row2 col1" >0.213902</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow2_col2" class="data row2 col2" >https://www.youtube.com/watch?v=zvKjfWSPI7s</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow2_col3" class="data row2 col3" >440</td>
#     </tr>    <tr>
#         <th id="T_6ad2aeae_9595_11e8_a015_0025905a74aclevel0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow3_col0" class="data row3 col0" > v <br>(8. / 0.203% / -0.016%)</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow3_col1" class="data row3 col1" >0.186192</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow3_col2" class="data row3 col2" >https://www.youtube.com/watch?v=fAYjSLtz6wQ&feature=youtu.be</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow3_col3" class="data row3 col3" >383</td>
#     </tr>    <tr>
#         <th id="T_6ad2aeae_9595_11e8_a015_0025905a74aclevel0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow4_col0" class="data row4 col0" > - </td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow4_col1" class="data row4 col1" >0.130772</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow4_col2" class="data row4 col2" >https://www.youtube.com/channel/UCXDyAGuwSxI4Y-X-N6RXqew/videos</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow4_col3" class="data row4 col3" >269</td>
#     </tr>    <tr>
#         <th id="T_6ad2aeae_9595_11e8_a015_0025905a74aclevel0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow5_col0" class="data row5 col0" > v <br>(22. / 0.135% / -0.008%)</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow5_col1" class="data row5 col1" >0.127369</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow5_col2" class="data row5 col2" >https://www.youtube.com/channel/UCVnvMpMVel0KMCqZM69XMbQ</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow5_col3" class="data row5 col3" >262</td>
#     </tr>    <tr>
#         <th id="T_6ad2aeae_9595_11e8_a015_0025905a74aclevel0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow6_col0" class="data row6 col0" > v <br>(34. / 0.101% / 0.017%)</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow6_col1" class="data row6 col1" >0.118618</td>
#         <td id="T_6ad2aeae_9595_11e8_a015_0025905a74acrow6_col2" class="data row6 col2" >https:/

# %% [markdown]
# ## Sampled vs Filtered

# %%
attribute = 'resolved_url'
column_name = 'url'
    
df_sampled = generateRankingDataframe(urlsS[attribute].value_counts(), column_name)
df_filtered = generateRankingDataframe(urlsF[attribute].value_counts(), column_name)

df_sampled_comparison, df_filtered_comparison = generateComparisonDataframes(df_sampled, df_filtered, column_name, 25)

# %%
s = getPrettyComparisonDataframe(df_sampled_comparison, "Youtube URLs - Sampled Data (compared to Filtered Data)")
s
# Out:
# <style  type="text/css" >
#     #T_51cb5be4_9596_11e8_a015_0025905a74ac td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_51cb5be4_9596_11e8_a015_0025905a74ac tr {
#           border-bottom: 1px dotted black;
#     }    #T_51cb5be4_9596_11e8_a015_0025905a74ac th {
#           text-align: center;
#     }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow0_col0 {
#             background-color:  rgba(184, 233, 148, 0.6);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow1_col0 {
#             background-color:  rgba(246, 185, 59, 0.5);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow2_col0 {
#             background-color:  #e55039;
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow3_col0 {
#             background-color:  #e55039;
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow4_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow5_col0 {
#             background-color:  #e55039;
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow6_col0 {
#             background-color:  #e55039;
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow7_col0 {
#             background-color:  #e55039;
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow8_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow9_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow10_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow11_col0 {
#             background-color:  #e55039;
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow12_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow13_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow14_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow15_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow16_col0 {
#             background-color:  #e55039;
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow17_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow18_col0 {
#             background-color:  #e55039;
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow19_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow20_col0 {
#             background-color:  #e55039;
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow21_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow22_col0 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow23_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_51cb5be4_9596_11e8_a015_0025905a74acrow24_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }</style>
# <table id="T_51cb5be4_9596_11e8_a015_0025905a74ac" ><caption>Youtube URLs - Sampled Data (compared to Filtered Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >difference (rank / percentage / diff)</th>
#         <th class="col_heading level0 col1" >percentage</th>
#         <th class="col_heading level0 col2" >url</th>
#         <th class="col_heading level0 col3" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_51cb5be4_9596_11e8_a015_0025905a74aclevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow0_col0" class="data row0 col0" > = <br>(1. / 1.508% / -0.415%)</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow0_col1" class="data row0 col1" >1.09272</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow0_col2" class="data row0 col2" >https://www.youtube.com/watch?v=Dw-2hh6G_D8&feature=youtu.be&a</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow0_col3" class="data row0 col3" >68</td>
#     </tr>    <tr>
#         <th id="T_51cb5be4_9596_11e8_a015_0025905a74aclevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow1_col0" class="data row1 col0" > v <br>(93. / 0.018% / 0.576%)</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow1_col1" class="data row1 col1" >0.594569</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow1_col2" class="data row1 col2" >https://www.youtube.com/watch?v=F-eMt3SrfFU&feature=youtu.be</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow1_col3" class="data row1 col3" >37</td>
#     </tr>    <tr>
#         <th id="T_51cb5be4_9596_11e8_a015_0025905a74aclevel0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow2_col0" class="data row2 col0" > - </td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow2_col1" class="data row2 col1" >0.578499</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow2_col2" class="data row2 col2" >https://www.youtube.com/watch?v=tBWJ3bvJuT0&feature=youtu.be</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow2_col3" class="data row2 col3" >36</td>
#     </tr>    <tr>
#         <th id="T_51cb5be4_9596_11e8_a015_0025905a74aclevel0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow3_col0" class="data row3 col0" > - </td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow3_col1" class="data row3 col1" >0.530291</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow3_col2" class="data row3 col2" >https://www.youtube.com/watch?v=tzni9QRNMEU&feature=youtu.be</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow3_col3" class="data row3 col3" >33</td>
#     </tr>    <tr>
#         <th id="T_51cb5be4_9596_11e8_a015_0025905a74aclevel0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow4_col0" class="data row4 col0" > ^ <br>(2. / 0.584% / -0.295%)</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow4_col1" class="data row4 col1" >0.28925</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow4_col2" class="data row4 col2" >https://www.youtube.com/user/videodeutschland/videos</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow4_col3" class="data row4 col3" >18</td>
#     </tr>    <tr>
#         <th id="T_51cb5be4_9596_11e8_a015_0025905a74aclevel0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow5_col0" class="data row5 col0" > - </td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow5_col1" class="data row5 col1" >0.224972</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow5_col2" class="data row5 col2" >https://www.youtube.com/results?search_query=sehun+fancam</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow5_col3" class="data row5 col3" >14</td>
#     </tr>    <tr>
#         <th id="T_51cb5be4_9596_11e8_a015_0025905a74aclevel0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow6_col0" class="data row6 col0" > - </td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow6_col1" class="data row6 col1" >0.224972</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow6_col2" class="data row6 col2" >https://www.youtube.com/results?search_query=sehun+solo</td>
#         <td id="T_51cb5be4_9596_11e8_a015_0025905a74acrow6_col3" class="d

# %%
s = getPrettyComparisonDataframe(df_filtered_comparison, "Youtube URLs - Filtered Data (compared to Sampled Data)")
s
# Out:
# <style  type="text/css" >
#     #T_5d171bbe_9596_11e8_a015_0025905a74ac td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_5d171bbe_9596_11e8_a015_0025905a74ac tr {
#           border-bottom: 1px dotted black;
#     }    #T_5d171bbe_9596_11e8_a015_0025905a74ac th {
#           text-align: center;
#     }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow0_col0 {
#             background-color:  rgba(184, 233, 148, 0.6);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow1_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow2_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow3_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow4_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow5_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow6_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow7_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow8_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow9_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow10_col0 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow11_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow12_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow13_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow14_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow15_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow16_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow17_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow18_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow19_col0 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow20_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow21_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow22_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow23_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_5d171bbe_9596_11e8_a015_0025905a74acrow24_col0 {
#             background-color:  #e55039;
#         }</style>
# <table id="T_5d171bbe_9596_11e8_a015_0025905a74ac" ><caption>Youtube URLs - Filtered Data (compared to Sampled Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >difference (rank / percentage / diff)</th>
#         <th class="col_heading level0 col1" >percentage</th>
#         <th class="col_heading level0 col2" >url</th>
#         <th class="col_heading level0 col3" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5d171bbe_9596_11e8_a015_0025905a74aclevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow0_col0" class="data row0 col0" > = <br>(1. / 1.093% / 0.415%)</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow0_col1" class="data row0 col1" >1.50797</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow0_col2" class="data row0 col2" >https://www.youtube.com/watch?v=Dw-2hh6G_D8&feature=youtu.be&a</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow0_col3" class="data row0 col3" >6623</td>
#     </tr>    <tr>
#         <th id="T_5d171bbe_9596_11e8_a015_0025905a74aclevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow1_col0" class="data row1 col0" > v <br>(5. / 0.289% / 0.295%)</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow1_col1" class="data row1 col1" >0.584243</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow1_col2" class="data row1 col2" >https://www.youtube.com/user/videodeutschland/videos</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow1_col3" class="data row1 col3" >2566</td>
#     </tr>    <tr>
#         <th id="T_5d171bbe_9596_11e8_a015_0025905a74aclevel0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow2_col0" class="data row2 col0" > v <br>(13. / 0.161% / 0.175%)</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow2_col1" class="data row2 col1" >0.335609</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow2_col2" class="data row2 col2" >https://www.youtube.com/watch?v=6bTQkwftlf0&feature=youtu.be&a</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow2_col3" class="data row2 col3" >1474</td>
#     </tr>    <tr>
#         <th id="T_5d171bbe_9596_11e8_a015_0025905a74aclevel0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow3_col0" class="data row3 col0" > v <br>(14. / 0.161% / 0.057%)</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow3_col1" class="data row3 col1" >0.21744</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow3_col2" class="data row3 col2" >https://www.youtube.com/channel/UCXDyAGuwSxI4Y-X-N6RXqew/videos</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow3_col3" class="data row3 col3" >955</td>
#     </tr>    <tr>
#         <th id="T_5d171bbe_9596_11e8_a015_0025905a74aclevel0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow4_col0" class="data row4 col0" > v <br>(10. / 0.177% / 0.014%)</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow4_col1" class="data row4 col1" >0.190346</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow4_col2" class="data row4 col2" >https://www.youtube.com/watch?v=Xeqf_HHEMJk</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow4_col3" class="data row4 col3" >836</td>
#     </tr>    <tr>
#         <th id="T_5d171bbe_9596_11e8_a015_0025905a74aclevel0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow5_col0" class="data row5 col0" > v <br>(15. / 0.145% / -0.011%)</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow5_col1" class="data row5 col1" >0.133424</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow5_col2" class="data row5 col2" >https://www.youtube.com/watch?v=JEVtiDeHKdc&feature=youtu.be&a</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow5_col3" class="data row5 col3" >586</td>
#     </tr>    <tr>
#         <th id="T_5d171bbe_9596_11e8_a015_0025905a74aclevel0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow6_col0" class="data row6 col0" > v <br>(25. / 0.080% / 0.028%)</td>
#         <td id="T_5d171bbe_9596_11e8_a015_0025905a74acrow6_col1" class="data row6 col1"

# %% [markdown]
# ## Query Tweets

# %% [markdown]
# ### Sampled

# %%
tweetsS03 = pd.read_sql_query("SELECT * FROM tweets_info;", connS03 )
print("# of Tweets sampled 03: %s" %len(tweetsS03))

tweetsS17 = pd.read_sql_query("SELECT * FROM tweets_info;", connS17 )
print("# of tweets sampled 17: %s" %len(tweetsS17))

tweetsS = tweetsS17.append(tweetsS03)
print("# of URLs sampled: %s" %len(tweetsS))

tweetsS.head()
# Out:
# # of Tweets sampled 03: 123680
# # of tweets sampled 17: 112003
# # of URLs sampled: 235683
#                    id             user_id  \
# 0  988175614908788736  1647758059
# 1  988175619098861568  234778734
# 2  988175627453952002  821834588158853120
# 3  988175627479146498  859148218915069952
# 4  988175681996681218  3206249890
#
#                                                                                                                                  text  \
# 0  Johangeorgenstadt 23:59 Nachtzeit/Trocken/Klar ,Temp: 14°C, Hum:66%, Wind:WSW 0-&gt;24kmh, Baro: 1012.80hPa, Regen: 0.00mm #wetter
# 1  Beim nächsten Ton ist es 0 Uhr: ♩♩♩
# 2  [d] DiplIngMarkus  Verbrauch gestern:  3.71 kWh                      Uptime: 41 days 21:01:04 since 23:48:32 13/10/2017
# 3  Alien Mutterschiff sozusagen \n(Hab das Gefühl bin schwanger) \n(Das gibt dann rr Stress) https://t.co/z4uHz2dugO
# 4  @MDegen55 🇩🇪🇩🇪 Gute Nacht 🌃🌃🌃 https://t.co/OTnsAsDGrc
#
#                        created_at  \
# 0  Sun Apr 22 22:00:00 +0000 2018
# 1  Sun Apr 22 22:00:01 +0000 2018
# 2  Sun Apr 22 22:00:03 +0000 2018
# 3  Sun Apr 22 22:00:03 +0000 2018
# 4  Sun Apr 22 22:00:16 +0000 2018
#
#                                                                                          source  \
# 0  <a href="http://saratoga-weather.org/scripts-TweetWX.php#TweetWX" rel="nofollow">TweetWX</a>
# 1  <a href="http://www.rasputin.de/" rel="nofollow">rasputin</a>
# 2  <a href="http://arduino-tweet.appspot.com/" rel="nofollow">Arduino</a>
# 3  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#   lang  truncated  is_retweet  retweet_id  is_quote       ...         \
# 0  de   False      False      NaN          False          ...
# 1  de   False      False      NaN          False          ...
# 2  de   False      False      NaN          False          ...
# 3  de   False      False      NaN          False          ...
# 4  de   False      False      NaN          False          ...
#
#    favorite_count  favorited  retweeted  hashtags  user_mentions  \
# 0  0               False      False      wetter    None
# 1  0               False      False      None      None
# 2  0               False      False      None      None
# 3  0               False      False      None      None
# 4  0               False      False      None      3206249890
#
#    number_of_urls  extracted  coordinates_type  coordinates_long  \
# 0  0               False      None             NaN
# 1  0               False      None             NaN
# 2  0               False      None             NaN
# 3  0               False      None             NaN
# 4  0               False      None             NaN
#
#    coordinates_lat
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
# [5 rows x 27 columns]

# %%
tweetsS[tweetsS['id'].isin(urlsS[urlsS['resolved_url'] == "https://www.youtube.com/watch?v=tzni9QRNMEU&feature=youtu.be"]['tweet_id'])]
# Out:
#                         id             user_id  \
# 89443   990199324620472320  1099570976
# 89456   990199702112030720  1710032354
# 89469   990199773423636480  73732277
# 89478   990199878268669952  744423667178823680
# 89482   990199907624542211  845826939856216064
# 89495   990200083810467841  1101142141
# 89508   990200415156293632  1097049314
# 89573   990201727952572418  2399086608
# 89605   990202420016840704  1540314288
# 89629   990202940102098944  4158510612
# 89742   990205205043032066  714429210509479936
# 89763   990205720955047936  787184219915104256
# 89770   990205884524478465  786734219712090112
# 89850   990207482533330944  798532610255298561
# 89907   990208484967841797  809970362607878144
# 89977   990209676154318848  3415462334
# 89991   990210003318407169  2216976216
# 90924   990227120264654848  2409814147
# 91393   990234942675156994  1307340368
# 91997   990246053369692160  460772468
# 92646   990256455247892480  582424090
# 92831   990259508675989504  3016284333
# 93446   990272368445571073  789102186110214144
# 94070   990284141823512576  863074388505223169
# 94406   990290139699073024  710352413849354240
# 94595   990293499315564544  893692915066691584
# 96174   990322670700056577  4668056352
# 98053   990377515448393728  1512035971
# 98241   990388445787836416  2936161830
# 98991   990445832255098880  782440041322733568
# 99240   990461992925196289  962926328755335168
# 101248  990199266424504320  570842497
# 101249  990514107123036160  772759975974141952
#
#                                                                                                                                                                                            text  \
# 89443   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89456   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89469   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89478   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89482   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89495   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89508   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89573   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89605   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89629   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89742   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89763   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89770   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89850   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89907   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89977   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 89991   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 90924   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 91393   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 91997   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 92646   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 92831   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 93446   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 94070   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 94406   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 94595   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 96174   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 98053   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 98241   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 98991   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 99240   RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
# 101248  [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cookie\n#EAU_DE_VIXX #향 #Scentist https://t.co/sONOvx3cKQ
# 101249  RT @RealVIXX: [VIXX TV cookie]\n빅스(VIXX) VIXX TV cookie #4\n\n▶️ https://t.co/Sj8xa5T2V7\n▶️ https://t.co/uoM2uZ7WIr\n\n#빅스 #VIXX #VIXX_TV #cooki…
#
#                             created_at  \
# 89443   Sat Apr 28 12:01:30 +0000 2018
# 89456   Sat Apr 28 12:03:00 +0000 2018
# 89469   Sat Apr 28 12:03:17 +0000 2018
# 89478   Sat Apr 28 12:03:42 +0000 2018
# 89482   Sat Apr 28 12:03:49 +0000 2018
# 89495   Sat Apr 28 12:04:31 +0000 2018
# 89508   Sat Apr 28 12:05:50 +0000 2018
# 89573   Sat Apr 28 12:11:03 +0000 2018
# 89605   Sat Apr 28 12:13:48 +0000 2018
# 89629   Sat Apr 28 12:15:52 +0000 2018
# 89742   Sat Apr 28 12:24:52 +0000 2018
# 89763   Sat Apr 28 12:26:55 +0000 2018
# 89770   Sat Apr 28 12:27:34 +0000 2018
# 89850   Sat Apr 28 12:33:55 +0000 2018
# 89907   Sat Apr 28 12:37:54 +0000 2018
# 89977   Sat Apr 28 12:42:38 +0000 2018
# 89991   Sat Apr 28 12:43:56 +0000 2018
# 90924   Sat Apr 28 13:51:57 +0000 2018
# 91393   Sat Apr 28 14:23:02 +0000 2018
# 91997   Sat Apr 28 15:07:11 +0000 2018
# 92646   Sat Apr 28 15:48:31 +0000 2018
# 92831   Sat Apr 28 16:00:39 +0000 2018
# 93446   Sat Apr 28 16:51:45 +0000 2018
# 94070   Sat Apr 28 17:38:32 +0000 2018
# 94406   Sat Apr 28 18:02:22 +0000 2018
# 94595   Sat Apr 28 18:15:43 +0000 2018
# 96174   Sat Apr 28 20:11:38 +0000 2018
# 98053   Sat Apr 28 23:49:34 +0000 2018
# 98241   Sun Apr 29 00:33:00 +0000 2018
# 98991   Sun Apr 29 04:21:02 +0000 2018
# 99240   Sun Apr 29 05:25:15 +0000 2018
# 101248  Sat Apr 28 12:01:16 +0000 2018
# 101249  Sun Apr 29 08:52:20 +0000 2018
#
#                                                                                       source  \
# 89443   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 89456   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 89469   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 89478   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 89482   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 89495   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 89508   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 89573   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 89605   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 89629   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 89742   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 89763   <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 89770   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 89850   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 89907   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 89977   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 89991   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 90924   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 91393   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 91997   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 92646   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 92831   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 93446   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 94070   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 94406   <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>
# 94595   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 96174   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 98053   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 98241   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 98991   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 99240   <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 101248  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 101249  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#        lang  truncated  is_retweet    retweet_id  is_quote       ...         \
# 89443   de   False      True        9.901993e+17  False          ...
# 89456   de   False      True        9.901993e+17  False          ...
# 89469   de   False      True        9.901993e+17  False          ...
# 89478   de   False      True        9.901993e+17  False          ...
# 89482   de   False      True        9.901993e+17  False          ...
# 89495   de   False      True        9.901993e+17  False          ...
# 89508   de   False      True        9.901993e+17  False          ...
# 89573   de   False      True        9.901993e+17  False          ...
# 89605   de   False      True        9.901993e+17  False          ...
# 89629   de   False      True        9.901993e+17  False          ...
# 89742   de   False      True        9.901993e+17  False          ...
# 89763   de   False      True        9.901993e+17  False          ...
# 89770   de   False      True        9.901993e+17  False          ...
# 89850   de   False      True        9.901993e+17  False          ...
# 89907   de   False      True        9.901993e+17  False          ...
# 89977   de   False      True        9.901993e+17  False          ...
# 89991   de   False      True        9.901993e+17  False          ...
# 90924   de   False      True        9.901993e+17  False          ...
# 91393   de   False      True        9.901993e+17  False          ...
# 91997   de   False      True        9.901993e+17  False          ...
# 92646   de   False      True        9.901993e+17  False          ...
# 92831   de   False      True        9.901993e+17  False          ...
# 93446   de   False      True        9.901993e+17  False          ...
# 94070   de   False      True        9.901993e+17  False          ...
# 94406   de   False      True        9.901993e+17  False          ...
# 94595   de   False      True        9.901993e+17  False          ...
# 96174   de   False      True        9.901993e+17  False          ...
# 98053   de   False      True        9.901993e+17  False          ...
# 98241   de   False      True        9.901993e+17  False          ...
# 98991   de   False      True        9.901993e+17  False          ...
# 99240   de   False      True        9.901993e+17  False          ...
# 101248  de   True       False      NaN            False          ...
# 101249  de   False      True        9.901993e+17  False          ...
#
#         favorite_count  favorited  retweeted  \
# 89443   0               False      False
# 89456   0               False      False
# 89469   0               False      False
# 89478   0               False      False
# 89482   0               False      False
# 89495   0               False      False
# 89508   0               False      False
# 89573   0               False      False
# 89605   0               False      False
# 89629   0               False      False
# 89742   0               False      False
# 89763   0               False      False
# 89770   0               False      False
# 89850   0               False      False
# 89907   0               False      False
# 89977   0               False      False
# 89991   0               False      False
# 90924   0               False      False
# 91393   0               False      False
# 91997   0               False      False
# 92646   0               False      False
# 92831   0               False      False
# 93446   0               False      False
# 94070   0               False      False
# 94406   0               False      False
# 94595   0               False      False
# 96174   0               False      False
# 98053   0               False      False
# 98241   0               False      False
# 98991   0               False      False
# 99240   0               False      False
# 101248  5461            False      False
# 101249  0               False      False
#
#                                              hashtags  user_mentions  \
# 89443   빅스 VIXX VIXX_TV                                570842497
# 89456   빅스 VIXX VIXX_TV                                570842497
# 89469   빅스 VIXX VIXX_TV                                570842497
# 89478   빅스 VIXX VIXX_TV                                570842497
# 89482   빅스 VIXX VIXX_TV                                570842497
# 89495   빅스 VIXX VIXX_TV                                570842497
# 89508   빅스 VIXX VIXX_TV                                570842497
# 89573   빅스 VIXX VIXX_TV                                570842497
# 89605   빅스 VIXX VIXX_TV                                570842497
# 89629   빅스 VIXX VIXX_TV                                570842497
# 89742   빅스 VIXX VIXX_TV                                570842497
# 89763   빅스 VIXX VIXX_TV                                570842497
# 89770   빅스 VIXX VIXX_TV                                570842497
# 89850   빅스 VIXX VIXX_TV                                570842497
# 89907   빅스 VIXX VIXX_TV                                570842497
# 89977   빅스 VIXX VIXX_TV                                570842497
# 89991   빅스 VIXX VIXX_TV                                570842497
# 90924   빅스 VIXX VIXX_TV                                570842497
# 91393   빅스 VIXX VIXX_TV                                570842497
# 91997   빅스 VIXX VIXX_TV                                570842497
# 92646   빅스 VIXX VIXX_TV                                570842497
# 92831   빅스 VIXX VIXX_TV                                570842497
# 93446   빅스 VIXX VIXX_TV                                570842497
# 94070   빅스 VIXX VIXX_TV                                570842497
# 94406   빅스 VIXX VIXX_TV                                570842497
# 94595   빅스 VIXX VIXX_TV                                570842497
# 96174   빅스 VIXX VIXX_TV                                570842497
# 98053   빅스 VIXX VIXX_TV                                570842497
# 98241   빅스 VIXX VIXX_TV                                570842497
# 98991   빅스 VIXX VIXX_TV                                570842497
# 99240   빅스 VIXX VIXX_TV                                570842497
# 101248  빅스 VIXX VIXX_TV cookie EAU_DE_VIXX 향 Scentist  None
# 101249  빅스 VIXX VIXX_TV                                570842497
#
#         number_of_urls  extracted  coordinates_type  coordinates_long  \
# 89443   2               False      None             NaN
# 89456   2               False      None             NaN
# 89469   2               False      None             NaN
# 89478   2               False      None             NaN
# 89482   2               False      None             NaN
# 89495   2               False      None             NaN
# 89508   2               False      None             NaN
# 89573   2               False      None             NaN
# 89605   2               False      None             NaN
# 89629   2               False      None             NaN
# 89742   2               False      None             NaN
# 89763   2               False      None             NaN
# 89770   2               False      None             NaN
# 89850   2               False      None             NaN
# 89907   2               False      None             NaN
# 89977   2               False      None             NaN
# 89991   2               False      None             NaN
# 90924   2               False      None             NaN
# 91393   2               False      None             NaN
# 91997   2               False      None             NaN
# 92646   2               False      None             NaN
# 92831   2               False      None             NaN
# 93446   2               False      None             NaN
# 94070   2               False      None             NaN
# 94406   2               False      None             NaN
# 94595   2               False      None             NaN
# 96174   2               False      None             NaN
# 98053   2               False      None             NaN
# 98241   2               False      None             NaN
# 98991   2               False      None             NaN
# 99240   2               False      None             NaN
# 101248  2               True       None             NaN
# 101249  2               False      None             NaN
#
#         coordinates_lat
# 89443  NaN
# 89456  NaN
# 89469  NaN
# 89478  NaN
# 89482  NaN
# 89495  NaN
# 89508  NaN
# 89573  NaN
# 89605  NaN
# 89629  NaN
# 89742  NaN
# 89763  NaN
# 89770  NaN
# 89850  NaN
# 89907  NaN
# 89977  NaN
# 89991  NaN
# 90924  NaN
# 91393  NaN
# 91997  NaN
# 92646  NaN
# 92831  NaN
# 93446  NaN
# 94070  NaN
# 94406  NaN
# 94595  NaN
# 96174  NaN
# 98053  NaN
# 98241  NaN
# 98991  NaN
# 99240  NaN
# 101248 NaN
# 101249 NaN
#
# [33 rows x 27 columns]

# %% [markdown]
# ## Query Hashtags

# %%
def getHashtagsFromTopLevelDomain(tld, urls, hashtags):
    return hashtags[ hashtags['tweet_id'].isin(urls[urls['top_level_domain'] == tld]['tweet_id'])]

# %% [markdown]
# ### Sampled

# %%
hashtagsS03 = pd.read_sql_query("SELECT * FROM tweets_hashtags", connS03 )
print("# of hashtags sampled 03: %s" %len(hashtagsS03))

hashtagsS03 = getHashtagsFromTopLevelDomain('youtube.com', urlsS03, hashtagsS03)
print("# of youtube hashtags sampled 03: %s" %len(hashtagsS03))

hashtagsS17 = pd.read_sql_query("SELECT * FROM tweets_hashtags", connS17 )
print("# of hashtags sampled 17: %s" %len(hashtagsS17))

hashtagsS17 = getHashtagsFromTopLevelDomain('youtube.com', urlsS17, hashtagsS17)
print("# of youtube hashtags sampled 17: %s" %len(hashtagsS17))

hashtagsS = hashtagsS17.append(hashtagsS03)
print("# of youtube hashtags sampled: %s" %len(hashtagsS))

hashtagsS.head()
# Out:
# # of hashtags sampled 03: 84203
# # of youtube hashtags sampled 03: 1450
# # of hashtags sampled 17: 73935
# # of youtube hashtags sampled 17: 1750
# # of youtube hashtags sampled: 3200
#               tweet_id      hashtag
# 59  988077828091580427  nullsechsTV
# 60  988077828091580427  SCPHFC
# 61  988077828091580427  scp06
# 62  988177561053286401  nullsechsTV
# 63  988177561053286401  SCPHFC

# %%
len(urlsF)
# Out:
# 439201

# %% [markdown]
# ###  Filtered

# %%
hashtagsF03 = pd.read_sql_query("SELECT * FROM tweets_hashtags", connF03 )
print("# of hashtags filtered 03: %s" %len(hashtagsF03))

hashtagsF03 = getHashtagsFromTopLevelDomain('youtube.com', urlsF03, hashtagsF03)
print("# of youtube hashtags filtered 03: %s" %len(hashtagsF03))

hashtagsF17 = pd.read_sql_query("SELECT * FROM tweets_hashtags", connF17 )
print("# of hashtags filtered 17: %s" %len(hashtagsF17))

hashtagsF17 = getHashtagsFromTopLevelDomain('youtube.com', urlsF17, hashtagsF17)
print("# of youtube hashtags filtered 17: %s" %len(hashtagsF17))

hashtagsF = hashtagsF17.append(hashtagsF03)
print("# of youtube hashtags filtered: %s" %len(hashtagsF))

hashtagsF.head()
# Out:
# # of hashtags filtered 03: 4377831
# # of youtube hashtags filtered 03: 68218
# # of hashtags filtered 17: 3780197
# # of youtube hashtags filtered 17: 70375
# # of youtube hashtags filtered: 138593
#                tweet_id         hashtag
# 119  988175640607195137  egoFM
# 120  988175640607195137  musicinbetween
# 239  988175711453302789  PS4live
# 271  988160198480154624  Bremen
# 272  988160198480154624  AfD

# %% [markdown]
# ## Hashtags

# %% [markdown]
# ### Sampled vs Filtered

# %%
attribute = 'hashtag'
column_name = 'hashtag'
    
df_sampled = generateRankingDataframe(hashtagsS[attribute].value_counts(), column_name)
df_filtered = generateRankingDataframe(hashtagsF[attribute].value_counts(), column_name)

df_sampled_comparison, df_filtered_comparison = generateComparisonDataframes(df_sampled, df_filtered, column_name, 50)

# %%
s = getPrettyComparisonDataframe(df_sampled_comparison, "Youtube Hashtags - Sampled Data (compared to Filtered Data)")
s
# Out:
# <style  type="text/css" >
#     #T_044609e4_96fb_11e8_a015_0025905a74ac td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_044609e4_96fb_11e8_a015_0025905a74ac tr {
#           border-bottom: 1px dotted black;
#     }    #T_044609e4_96fb_11e8_a015_0025905a74ac th {
#           text-align: center;
#     }    #T_044609e4_96fb_11e8_a015_0025905a74acrow0_col0 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow1_col0 {
#             background-color:  #e55039;
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow2_col0 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow3_col0 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow4_col0 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow5_col0 {
#             background-color:  rgba(246, 185, 59, 0.5);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow6_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow7_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow8_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow9_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow10_col0 {
#             background-color:  rgba(246, 185, 59, 0.5);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow11_col0 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow12_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow13_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow14_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow15_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow16_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow17_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow18_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow19_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow20_col0 {
#             background-color:  #e55039;
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow21_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow22_col0 {
#             background-color:  #e55039;
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow23_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow24_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow25_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow26_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow27_col0 {
#             background-color:  #e55039;
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow28_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow29_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow30_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow31_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow32_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow33_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow34_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow35_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow36_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow37_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow38_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow39_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow40_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow41_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow42_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow43_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow44_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow45_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow46_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow47_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow48_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_044609e4_96fb_11e8_a015_0025905a74acrow49_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }</style>
# <table id="T_044609e4_96fb_11e8_a015_0025905a74ac" ><caption>Youtube Hashtags - Sampled Data (compared to Filtered Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >difference (rank / percentage / diff)</th>
#         <th class="col_heading level0 col1" >hashtag</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_044609e4_96fb_11e8_a015_0025905a74aclevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_044609e4_96fb_11e8_a015_0025905a74acrow0_col0" class="data row0 col0" > v <br>(17434. / 0.001% / 2.281%)</td>
#         <td id="T_044609e4_96fb_11e8_a015_0025905a74acrow0_col1" class="data row0 col1" >빅스</td>
#         <td id="T_044609e4_96fb_11e8_a015_0025905a74acrow0_col2" class="data row0 col2" >2.28125</td>
#         <td id="T_044609e4_96fb_11e8_a015_0025905a74acrow0_col3" class="data row0 col3" >73</td>
#     </tr>    <tr>
#         <th id="T_044609e4_96fb_11e8_a015_0025905a74aclevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_044609e4_96fb_11e8_a015_0025905a74acrow1_col0" class="data row1 col0" > - </td>
#         <td id="T_044609e4_96fb_11e8_a015_0025905a74acrow1_col1" class="data row1 col1" >VIXX_TV</td>
#         <td id="T_044609e4_96fb_11e8_a015_0025905a74acrow1_col2" class="data row1 col2" >2.28125</td>
#         <td id="T_044609e4_

# %%
s = getPrettyComparisonDataframe(df_filtered_comparison, "Youtube URLs - Filtered Data (compared to Sampled Data)")
s
# Out:
# <style  type="text/css" >
#     #T_0e3dbb04_96fb_11e8_a015_0025905a74ac td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_0e3dbb04_96fb_11e8_a015_0025905a74ac tr {
#           border-bottom: 1px dotted black;
#     }    #T_0e3dbb04_96fb_11e8_a015_0025905a74ac th {
#           text-align: center;
#     }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow0_col0 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow1_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow2_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow3_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow4_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow5_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow6_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow7_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow8_col0 {
#             background-color:  rgba(246, 185, 59, 0.5);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow9_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow10_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow11_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow12_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow13_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow14_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow15_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow16_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow17_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow18_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow19_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow20_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow21_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow22_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow23_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow24_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow25_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow26_col0 {
#             background-color:  rgba(246, 185, 59, 0.5);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow27_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow28_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow29_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow30_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow31_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow32_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow33_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow34_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow35_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow36_col0 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow37_col0 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow38_col0 {
#             background-color:  #e55039;
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow39_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow40_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow41_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow42_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow43_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow44_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow45_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow46_col0 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow47_col0 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow48_col0 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_0e3dbb04_96fb_11e8_a015_0025905a74acrow49_col0 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }</style>
# <table id="T_0e3dbb04_96fb_11e8_a015_0025905a74ac" ><caption>Youtube URLs - Filtered Data (compared to Sampled Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >difference (rank / percentage / diff)</th>
#         <th class="col_heading level0 col1" >hashtag</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_0e3dbb04_96fb_11e8_a015_0025905a74aclevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_0e3dbb04_96fb_11e8_a015_0025905a74acrow0_col0" class="data row0 col0" > v <br>(12. / 0.719% / 1.027%)</td>
#         <td id="T_0e3dbb04_96fb_11e8_a015_0025905a74acrow0_col1" class="data row0 col1" >PS4live</td>
#         <td id="T_0e3dbb04_96fb_11e8_a015_0025905a74acrow0_col2" class="data row0 col2" >1.7454</td>
#         <td id="T_0e3dbb04_96fb_11e8_a015_0025905a74acrow0_col3" class="data row0 col3" >2419</td>
#     </tr>    <tr>
#         <th id="T_0e3dbb04_96fb_11e8_a015_0025905a74aclevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_0e3dbb04_96fb_11e8_a015_0025905a74acrow1_col0" class="data row1 col0" > v <br>(8. / 1.156% / 0.437%)</td>
#         <td id="T_0e3dbb04_96fb_11e8_a015_0025905a74acrow1_col1" class="data row1 col1" >LetsPlay</td>
#         <td id="T_0e3dbb04_96fb_11e8_a015_0025905a74acrow1_c
