# %%
import psycopg2
import pandas as pd
import config
from matplotlib import pylab as plt
import seaborn as sns
import numpy as np
from IPython.display import display, HTML
import re
from urllib.parse import parse_qs,urlparse


color_palette = sns.color_palette(palette='muted', n_colors=None, desat=.75)
sns.set(context='notebook', palette=color_palette, style='whitegrid', font='sans-serif', font_scale=1.5, color_codes=False, rc=None)
pd.set_option('display.max_colwidth', -1)
table_styles = [{'selector': 'td',
                 'props': [('min-width', '100px'), ('text-align', 'center')]},
                {'selector': 'tr',
                 'props': [('border-bottom', '1px dotted black')]},
                {'selector': 'th',
                 'props': [('text-align', 'center')]}
               ]

# %matplotlib inline

directory = "url_top_lists/"
stream = "comparison"
# Out:
# /media/raid/home/pflugmacher/virtualenv/twitterenvold/lib/python3.4/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /media/raid/home/pflugmacher/virtualenv/twitterenvold/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
conn = None
try:
    # read connection parameters
    paramsS17 = config.cfgAzureS17()
    paramsS03 = config.cfgAzureS03()

    paramsF17 = config.cfgAzureF17()
    paramsF03 = config.cfgAzureF03()
    
    # connect to the PostgreSQL server
    print('Connecting to the PostgreSQL database...')
    connS17 = psycopg2.connect(**paramsS17)
    connS03 = psycopg2.connect(**paramsS03)
    
    connF17 = psycopg2.connect(**paramsF17)
    connF03 = psycopg2.connect(**paramsF03)

    # create a cursor
    curS17 = connS17.cursor()
    curS03 = connS03.cursor()
    
    curF17 = connF17.cursor()
    curF03 = connF03.cursor()

    # execute a statement
    print('PostgreSQL database version:')
    
    curS17.execute('SELECT version()')
    curS03.execute('SELECT version()')
    curF17.execute('SELECT version()')
    curF03.execute('SELECT version()')
    
    # display the PostgreSQL database server version
    db_version_curS17 = curS17.fetchone()
    db_version_curS03 = curS03.fetchone()
    db_version_curF17 = curF17.fetchone()
    db_version_curF03 = curF03.fetchone()
    
    print(db_version_curS17)
    print(db_version_curS03)
    print(db_version_curF17)
    print(db_version_curF03)

    # close the communication with the PostgreSQL
    curS17.close()
    curS03.close()
    curF17.close()
    curF03.close()

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 9.6.9, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.9, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.9, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.9, compiled by Visual C++ build 1800, 64-bit',)

# %% [markdown]
# # Sampled Data

# %% [markdown]
# ## URLs

# %%
urlsS03 = pd.read_sql_query("SELECT * FROM tweets_urls;", connS03 )
print("# of URLs sampled 03: %s" %len(urlsS03))

urlsS17 = pd.read_sql_query("SELECT * FROM tweets_urls;", connS17 )
print("# of URLs sampled 17: %s" %len(urlsS17))

urlsS = urlsS17.append(urlsS03)
print("# of URLs sampled: %s" %len(urlsS))

urlsS.head()
# Out:
# # of URLs sampled 03: 40339
# # of URLs sampled 17: 35687
# # of URLs sampled: 76026
#              tweet_id  \
# 0  989097603664138240
# 1  988175933659021318
# 2  988176164358361088
# 3  988176403412766720
# 4  988176415995592704
#
#                                                                   short_url  \
# 0  http://arte.tv/abgedreht
# 1  https://twitter.com/piersmorgan/status/987388203593322496
# 2  https://www.journal.koeln/pol-ham-fahrradfahrer-verletzt-sich-bei-sturz/
# 3  http://www.radionomy.com/erika1
# 4  https://twitter.com/JanLatten/status/988161845205913600
#
#                                                                resolved_url  \
# 0  https://www.arte.tv/de/videos/RC-014033/abgedreht/
# 1  https://twitter.com/piersmorgan/status/987388203593322496
# 2  https://www.journal.koeln/pol-ham-fahrradfahrer-verletzt-sich-bei-sturz/
# 3  https://www.radionomy.com/en/radio/erika1
# 4  https://twitter.com/JanLatten/status/988161845205913600
#
#    response_code                      domain top_level_domain  is_twitter_url  \
# 0  200.0          https://www.arte.tv/        arte.tv          False
# 1  200.0          https://twitter.com/        twitter.com      True
# 2  200.0          https://www.journal.koeln/  journal.koeln    False
# 3  200.0          https://www.radionomy.com/  radionomy.com    False
# 4  200.0          https://twitter.com/        twitter.com      True
#
#   is_media  is_processed  failed
# 0  False    True          False
# 1  False    True          False
# 2  False    True          False
# 3  False    True          False
# 4  False    True          False

# %% [markdown]
# ## Tweets

# %%
tweetsS03 = pd.read_sql_query("SELECT * FROM tweets_info;", connS03 )
print("# of Tweets sampled 03: %s" %len(tweetsS03))

tweetsS17 = pd.read_sql_query("SELECT * FROM tweets_info;", connS17 )
print("# of tweets sampled 17: %s" %len(tweetsS17))

tweetsS = tweetsS17.append(tweetsS03)
print("# of tweets sampled: %s" %len(tweetsS))

tweetsS.head()
# Out:
# # of Tweets sampled 03: 123680
# # of tweets sampled 17: 112003
# # of tweets sampled: 235683
#                    id             user_id  \
# 0  988175614908788736  1647758059
# 1  988175619098861568  234778734
# 2  988175627453952002  821834588158853120
# 3  988175627479146498  859148218915069952
# 4  988175681996681218  3206249890
#
#                                                                                                                                  text  \
# 0  Johangeorgenstadt 23:59 Nachtzeit/Trocken/Klar ,Temp: 14°C, Hum:66%, Wind:WSW 0-&gt;24kmh, Baro: 1012.80hPa, Regen: 0.00mm #wetter
# 1  Beim nächsten Ton ist es 0 Uhr: ♩♩♩
# 2  [d] DiplIngMarkus  Verbrauch gestern:  3.71 kWh                      Uptime: 41 days 21:01:04 since 23:48:32 13/10/2017
# 3  Alien Mutterschiff sozusagen \n(Hab das Gefühl bin schwanger) \n(Das gibt dann rr Stress) https://t.co/z4uHz2dugO
# 4  @MDegen55 🇩🇪🇩🇪 Gute Nacht 🌃🌃🌃 https://t.co/OTnsAsDGrc
#
#                        created_at  \
# 0  Sun Apr 22 22:00:00 +0000 2018
# 1  Sun Apr 22 22:00:01 +0000 2018
# 2  Sun Apr 22 22:00:03 +0000 2018
# 3  Sun Apr 22 22:00:03 +0000 2018
# 4  Sun Apr 22 22:00:16 +0000 2018
#
#                                                                                          source  \
# 0  <a href="http://saratoga-weather.org/scripts-TweetWX.php#TweetWX" rel="nofollow">TweetWX</a>
# 1  <a href="http://www.rasputin.de/" rel="nofollow">rasputin</a>
# 2  <a href="http://arduino-tweet.appspot.com/" rel="nofollow">Arduino</a>
# 3  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#   lang  truncated  is_retweet  retweet_id  is_quote       ...         \
# 0  de   False      False      NaN          False          ...
# 1  de   False      False      NaN          False          ...
# 2  de   False      False      NaN          False          ...
# 3  de   False      False      NaN          False          ...
# 4  de   False      False      NaN          False          ...
#
#    favorite_count  favorited  retweeted  hashtags  user_mentions  \
# 0  0               False      False      wetter    None
# 1  0               False      False      None      None
# 2  0               False      False      None      None
# 3  0               False      False      None      None
# 4  0               False      False      None      3206249890
#
#    number_of_urls  extracted  coordinates_type  coordinates_long  \
# 0  0               False      None             NaN
# 1  0               False      None             NaN
# 2  0               False      None             NaN
# 3  0               False      None             NaN
# 4  0               False      None             NaN
#
#    coordinates_lat
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# # Little Helpers

# %%
def getTweetsByURL(url, urls, tweets):
    return tweets[tweets['id'].isin(urls[urls['resolved_url'] == url]['tweet_id'])]

# %%
getTweetsByURL('http://der-x-code.com/', urlsS, tweetsS)
# Out:
#                         id     user_id  \
# 1218    952721716836315136  864919496
# 3658    952812414470209537  864919496
# 3723    952813207160262657  2920432793
# 5510    952847357212704768  2920432793
# 7918    952892278212710400  1441138830
# 9910    952927208342831104  2920432793
# 13932   952982996818145280  864919496
# 19669   953141847680999424  2920432793
# 38539   953537655748382720  864919496
# 48626   953700176656457728  1441138830
# 54421   953843240167337984  864919496
# 57205   953915751290699777  2920432793
# 57651   953924437702840320  864919496
# 58017   953930276178157568  1441138830
# 66673   954054956033630209  864919496
# 67477   954066142250778625  1441138830
# 69529   954100598441369600  2920432793
# 71186   954134865921757184  2920432793
# 72787   954224418493947904  864919496
# 73434   954243620051169281  864919496
# 81376   954388591949488129  2920432793
# 85304   954447647737171973  864919496
# 91042   954625649817411584  2920432793
# 91580   954636391450787840  1441138830
# 91671   954638522136383488  2920432793
# 105500  954873197651898368  864919496
# 106329  954914792564670464  864919496
# 106582  954931490088894464  2920432793
# 108956  955011890677211137  2920432793
# 109284  955017411811467264  864919496
# 109285  955017997592260608  99119582
# 111344  955046955079487490  864919496
# 116894  955118564435832839  864919496
#
#                                                                                                                                 text  \
# 1218    Die #Wahrheit über unser Essen: https://t.co/ybapaC2F6Z https://t.co/n9oVNxivPq
# 3658    #Migräne? Falsche Ernährung kann der Grund sein. Mehr dazu: https://t.co/ybapaC2F6Z https://t.co/HUmxYCDMGg
# 3723    Die #Wahrheit über unser Essen: https://t.co/R92CFXbxIx https://t.co/une4N6aMps
# 5510    Die #Wahrheit über unser Essen: https://t.co/R92CFXt8A5 https://t.co/Ztyv6UGlZr
# 7918    Die #Wahrheit über unser Essen: https://t.co/oSnkWA3CQs https://t.co/hARlxgCEO1
# 9910    Die #Wahrheit über unser Essen: https://t.co/R92CFXt8A5 https://t.co/BpYmdDXJTN
# 13932   Gesunde #Ernährung sieht anders aus. Mehr dazu: https://t.co/ybapaC2F6Z https://t.co/uIfuVl1w9i
a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
# 57205   <a href="http://shop.windsor-verlag.com" rel="nofollow">30 Stunden</a>
# 57651   <a href="https://ifttt.com" rel="nofollow">IFTTT</a>
# 58017   <a href="http://shop.windsor-verlag.com" rel="nofollow">http://shop.windsor-verlag.com</a>
# 66673   <a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
# 67477   <a href="http://shop.windsor-verlag.com" rel="nofollow">http://shop.windsor-verlag.com</a>
# 69529   <a href="http://shop.windsor-verlag.com" rel="nofollow">30 Stunden</a>
# 71186   <a href="http://shop.windsor-verlag.com" rel="nofollow">30 Stunden</a>
# 72787   <a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
# 73434   <a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
# 81376   <a href="http://shop.windsor-verlag.com" rel="nofollow">30 Stunden</a>
# 85304   <a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
# 91042   <a href="https://ifttt.com" rel="nofollow">IFTTT</a>
# 91580   <a href="http://shop.windsor-verlag.com" rel="nofollow">http://shop.windsor-verlag.com</a>
# 91671   <a href="https://ifttt.com" rel="nofollow">IFTTT</a>
# 105500  <a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
# 106329  <a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
# 106582  <a href="http://shop.windsor-verlag.com" rel="nofollow">30 Stunden</a>
# 108956  <a href="https://ifttt.com" rel="nofollow">IFTTT</a>
# 109284  <a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
# 109285  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 111344  <a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
# 116894  <a href="http://shop.windsor-verlag.com/" rel="nofollow">http://shop.windsor-verlag.com/</a>
#
#        lang  truncated  is_retweet    retweet_id  is_quote       ...         \
# 1218    de   False      False      NaN            False          ...
# 3658    de   False      False      NaN            False          ...
# 3723    de   False      False      NaN            False          ...
# 5510    de   False      False      NaN            False          ...
# 7918    de   False      False      NaN            False          ...
# 9910    de   False      False      NaN            False          ...
# 13932   de   False      False      NaN            False          ...
# 19669   de   False      False      NaN            False          ...
# 38539   de   False      False      NaN            False          ...
# 48626   de   False      False      NaN            False          ...
# 54421   de   False      False      NaN            False          ...
# 57205   de   False      False      NaN            False          ...
# 57651   de   False      False      NaN            False          ...
# 58017   de   False      False      NaN            False          ...
# 66673   de   False      False      NaN            False          ...
# 67477   de   False      False      NaN            False          ...
# 69529   de   False      False      NaN            False          ...
# 71186   de   False      False      NaN            False          ...
# 72787   de   False      False      NaN            False          ...
# 73434   de   False      False      NaN            False          ...
# 81376   de   False      False      NaN            False          ...
# 85304   de   False      False      NaN            False          ...
# 91042   de   False      False      NaN            False          ...
# 91580   de   False      False      NaN            False          ...
# 91671   de   False      False      NaN            False          ...
# 105500  de   False      False      NaN            False          ...
# 106329  de   False      False      NaN            False          ...
# 106582  de   False      False      NaN            False          ...
# 108956  de   False      False      NaN            False          ...
# 109284  de   False      False      NaN            False          ...
# 109285  de   False      True        9.550174e+17  False          ...
# 111344  de   False      False      NaN            False          ...
# 116894  de   False      False      NaN            False          ...
#
#         favorite_count  favorited  retweeted                         hashtags  \
# 1218    0               False      False      Wahrheit
# 3658    0               False      False      Migräne
# 3723    0               False      False      Wahrheit
# 5510    0               False      False      Wahrheit
# 7918    0               False      False      Wahrheit
# 9910    0               False      False      Wahrheit
# 13932   0               False      False      Ernährung
# 19669   0               False      False      Phimose
# 38539   0               False      False      Wahrheit
# 48626   0               False      False      Migräne
# 54421   0               False      False      Wahrheit
# 57205   0               False      False      Augenprobleme Blutzuckerspiegel
# 57651   0               False      False      Veganer
# 58017   0               False      False      Augenprobleme Blutzuckerspiegel
# 66673   0               False      False      None
# 67477   0               False      False      Kopfschmerzen Blutzuckerspiegel
# 69529   0               False      False      Migräne
# 71186   0               False      False      Ernährung
# 72787   0               False      False      Wahrheit
# 73434   0               False      False      Veganer
# 81376   0               False      False      Wahrheit
# 85304   0               False      False      Wahrheit
# 91042   0               False      False      Veganer
# 91580   0               False      False      Diabetiker Insulin
# 91671   0               False      False      Diabetiker Insulin
# 105500  0               False      False      Rindfleisch
# 106329  0               False      False      Stevia
# 106582  0               False      False      Diabetiker Insulin
# 108956  0               False      False      Migräne
# 109284  1               False      False      Wahrheit
# 109285  0               False      False      Wahrheit
# 111344  0               False      False      Wahrheit
# 116894  0               False      False      Wahrheit
#
#         user_mentions  number_of_urls  extracted  coordinates_type  \
# 1218    None           1               False      None
# 3658    None           1               False      None
# 3723    None           1               False      None
# 5510    None           1               False      None
# 7918    None           1               False      None
# 9910    None           1               False      None
# 13932   None           1               False      None
# 19669   None           1               False      None
# 38539   None           1               False      None
# 48626   None           1               False      None
# 54421   None           1               False      None
# 57205   None           1               False      None
# 57651   None           1               False      None
# 58017   None           1               False      None
# 66673   None           1               False      None
# 67477   None           1               False      None
# 69529   None           1               False      None
# 71186   None           1               False      None
# 72787   None           1               False      None
# 73434   None           1               False      None
# 81376   None           1               False      None
# 85304   None           1               False      None
# 91042   None           1               False      None
# 91580   None           1               False      None
# 91671   None           1               False      None
# 105500  None           1               False      None
# 106329  None           1               False      None
# 106582  None           1               False      None
# 108956  None           1               False      None
# 109284  None           1               True       None
# 109285  864919496      1               False      None
# 111344  None           1               False      None
# 116894  None           1               False      None
#
#         coordinates_long  coordinates_lat
# 1218   NaN               NaN
# 3658   NaN               NaN
# 3723   NaN               NaN
# 5510   NaN               NaN
# 7918   NaN               NaN
# 9910   NaN               NaN
# 13932  NaN               NaN
# 19669  NaN               NaN
# 38539  NaN               NaN
# 48626  NaN               NaN
# 54421  NaN               NaN
# 57205  NaN               NaN
# 57651  NaN               NaN
# 58017  NaN               NaN
# 66673  NaN               NaN
# 67477  NaN               NaN
# 69529  NaN               NaN
# 71186  NaN               NaN
# 72787  NaN               NaN
# 73434  NaN               NaN
# 81376  NaN               NaN
# 85304  NaN               NaN
# 91042  NaN               NaN
# 91580  NaN               NaN
# 91671  NaN               NaN
# 105500 NaN               NaN
# 106329 NaN               NaN
# 106582 NaN               NaN
# 108956 NaN               NaN
# 109284 NaN               NaN
# 109285 NaN               NaN
# 111344 NaN               NaN
# 116894 NaN               NaN
#
# [33 rows x 27 columns]
