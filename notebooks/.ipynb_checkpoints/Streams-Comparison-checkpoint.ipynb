# %% [markdown]
# # Twitter Filtered Streaming API Evaluation

# %%
import psycopg2
import pandas as pd
import config
from matplotlib import pylab as plt
import seaborn as sns
import numpy as np

color_palette = sns.color_palette(palette='muted', n_colors=None, desat=.75)
sns.set(context='notebook', palette=color_palette, style='whitegrid', font='sans-serif', font_scale=1.5, color_codes=False, rc=None)

# %matplotlib inline

# %%
conn = None
try:
    # read connection parameters
    paramsS17 = config.cfgAzureS17()
    paramsS03 = config.cfgAzureS03()

    paramsF17 = config.cfgAzureF17()
    paramsF03 = config.cfgAzureF03()
    
    # connect to the PostgreSQL server
    print('Connecting to the PostgreSQL database...')
    connS17 = psycopg2.connect(**paramsS17)
    connS03 = psycopg2.connect(**paramsS03)
    
    connF17 = psycopg2.connect(**paramsF17)
    connF03 = psycopg2.connect(**paramsF03)

    # create a cursor
    curS17 = connS17.cursor()
    curS03 = connS03.cursor()
    
    curF17 = connF17.cursor()
    curF03 = connF03.cursor()

    # execute a statement
    print('PostgreSQL database version:')
    
    curS17.execute('SELECT version()')
    curS03.execute('SELECT version()')
    curF17.execute('SELECT version()')
    curF03.execute('SELECT version()')
    
    # display the PostgreSQL database server version
    db_version_curS17 = curS17.fetchone()
    db_version_curS03 = curS03.fetchone()
    db_version_curF17 = curF17.fetchone()
    db_version_curF03 = curF03.fetchone()
    
    print(db_version_curS17)
    print(db_version_curS03)
    print(db_version_curF17)
    print(db_version_curF03)

    # close the communication with the PostgreSQL
    curS17.close()
    curS03.close()
    curF17.close()
    curF03.close()

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)

# %%
tweetsS03 = pd.read_sql_query("SELECT created_at, extracted FROM tweets_info;", connS03, parse_dates=['created_at'] )
tweetsS03['created_at'] = tweetsS03['created_at'].dt.tz_localize("UTC").dt.tz_convert("Europe/Berlin")

print("Number of Tweets: %s" %len(tweetsS03))
tweetsS03.head()
# Out:
# Number of Tweets: 123680
#                  created_at  extracted
# 0 2018-01-15 00:00:07+01:00      False
# 1 2018-01-15 00:00:10+01:00      False
# 2 2018-01-15 00:00:13+01:00      False
# 3 2018-01-15 00:00:13+01:00      False
# 4 2018-01-15 00:00:16+01:00      False

# %%
tweetsS17 = pd.read_sql_query("SELECT created_at, extracted FROM tweets_info;", connS17, parse_dates=['created_at'] )
tweetsS17['created_at'] = tweetsS17['created_at'].dt.tz_localize("UTC").dt.tz_convert("Europe/Berlin")

print("Number of Tweets: %s" %len(tweetsS17))
tweetsS17.head()
# Out:
# Number of Tweets: 112003
#                  created_at  extracted
# 0 2018-04-23 00:00:00+02:00      False
# 1 2018-04-23 00:00:01+02:00      False
# 2 2018-04-23 00:00:03+02:00      False
# 3 2018-04-23 00:00:03+02:00      False
# 4 2018-04-23 00:00:16+02:00      False

# %%
tweetsF03 = pd.read_sql_query("SELECT created_at, extracted FROM tweets_info;", connF03, parse_dates=['created_at'] )
tweetsF03['created_at'] = tweetsF03['created_at'].dt.tz_localize("UTC").dt.tz_convert("Europe/Berlin")

print("Number of Tweets: %s" %len(tweetsF03))
tweetsF03.head()
# Out:
# Number of Tweets: 8010674
#                  created_at  extracted
# 0 2018-01-14 23:59:59+01:00      False
# 1 2018-01-14 17:01:56+01:00       True
# 2 2018-01-15 00:00:00+01:00      False
# 3 2018-01-15 00:00:00+01:00      False
# 4 2018-01-15 00:00:00+01:00      False

# %%
tweetsF17 = pd.read_sql_query("SELECT created_at, extracted FROM tweets_info;", connF17, parse_dates=['created_at'] )
tweetsF17['created_at'] = tweetsF17['created_at'].dt.tz_localize("UTC").dt.tz_convert("Europe/Berlin")

print("Number of Tweets: %s" %len(tweetsF17))
tweetsF17.head()
# Out:
# Number of Tweets: 7269347
#                  created_at  extracted
# 0 2018-04-23 15:56:34+02:00      False
# 1 2018-04-23 00:00:00+02:00      False
# 2 2018-04-23 00:00:00+02:00      False
# 3 2018-04-23 00:00:00+02:00      False
# 4 2018-04-23 00:00:00+02:00      False

# %% [markdown]
# ## Comparing Normalized Tweet Collection by Hour

# %%
dates_values15_s03 = tweetsS03['created_at'][(tweetsS03['created_at'].dt.day == 15) & (tweetsS03['created_at'].dt.year == 2018) & (tweetsS03['created_at'].dt.month == 1) & (tweetsS03['extracted'] == False)].value_counts()
dates_values16_s03 = tweetsS03['created_at'][(tweetsS03['created_at'].dt.day == 16) & (tweetsS03['created_at'].dt.year == 2018) & (tweetsS03['created_at'].dt.month == 1) & (tweetsS03['extracted'] == False)].value_counts()
dates_values17_s03 = tweetsS03['created_at'][(tweetsS03['created_at'].dt.day == 17) & (tweetsS03['created_at'].dt.year == 2018) & (tweetsS03['created_at'].dt.month == 1) & (tweetsS03['extracted'] == False)].value_counts()
dates_values18_s03 = tweetsS03['created_at'][(tweetsS03['created_at'].dt.day == 18) & (tweetsS03['created_at'].dt.year == 2018) & (tweetsS03['created_at'].dt.month == 1) & (tweetsS03['extracted'] == False)].value_counts()
dates_values19_s03 = tweetsS03['created_at'][(tweetsS03['created_at'].dt.day == 19) & (tweetsS03['created_at'].dt.year == 2018) & (tweetsS03['created_at'].dt.month == 1) & (tweetsS03['extracted'] == False)].value_counts()
dates_values20_s03 = tweetsS03['created_at'][(tweetsS03['created_at'].dt.day == 20) & (tweetsS03['created_at'].dt.year == 2018) & (tweetsS03['created_at'].dt.month == 1) & (tweetsS03['extracted'] == False)].value_counts()
dates_values21_s03 = tweetsS03['created_at'][(tweetsS03['created_at'].dt.day == 21) & (tweetsS03['created_at'].dt.year == 2018) & (tweetsS03['created_at'].dt.month == 1) & (tweetsS03['extracted'] == False)].value_counts()

dates_values23_s17 = tweetsS17['created_at'][(tweetsS17['created_at'].dt.day == 23) & (tweetsS17['created_at'].dt.year == 2018) & (tweetsS17['created_at'].dt.month == 4) & (tweetsS17['extracted'] == False)].value_counts()
dates_values24_s17 = tweetsS17['created_at'][(tweetsS17['created_at'].dt.day == 24) & (tweetsS17['created_at'].dt.year == 2018) & (tweetsS17['created_at'].dt.month == 4) & (tweetsS17['extracted'] == False)].value_counts()
dates_values25_s17 = tweetsS17['created_at'][(tweetsS17['created_at'].dt.day == 25) & (tweetsS17['created_at'].dt.year == 2018) & (tweetsS17['created_at'].dt.month == 4) & (tweetsS17['extracted'] == False)].value_counts()
dates_values26_s17 = tweetsS17['created_at'][(tweetsS17['created_at'].dt.day == 26) & (tweetsS17['created_at'].dt.year == 2018) & (tweetsS17['created_at'].dt.month == 4) & (tweetsS17['extracted'] == False)].value_counts()
dates_values27_s17 = tweetsS17['created_at'][(tweetsS17['created_at'].dt.day == 27) & (tweetsS17['created_at'].dt.year == 2018) & (tweetsS17['created_at'].dt.month == 4) & (tweetsS17['extracted'] == False)].value_counts()
dates_values28_s17 = tweetsS17['created_at'][(tweetsS17['created_at'].dt.day == 28) & (tweetsS17['created_at'].dt.year == 2018) & (tweetsS17['created_at'].dt.month == 4) & (tweetsS17['extracted'] == False)].value_counts()
dates_values29_s17 = tweetsS17['created_at'][(tweetsS17['created_at'].dt.day == 29) & (tweetsS17['created_at'].dt.year == 2018) & (tweetsS17['created_at'].dt.month == 4) & (tweetsS17['extracted'] == False)].value_counts()


dates_values15_f03 = tweetsF03['created_at'][(tweetsF03['created_at'].dt.day == 15) & (tweetsF03['created_at'].dt.year == 2018) & (tweetsF03['created_at'].dt.month == 1) & (tweetsF03['extracted'] == False)].value_counts()
dates_values16_f03 = tweetsF03['created_at'][(tweetsF03['created_at'].dt.day == 16) & (tweetsF03['created_at'].dt.year == 2018) & (tweetsF03['created_at'].dt.month == 1) & (tweetsF03['extracted'] == False)].value_counts()
dates_values17_f03 = tweetsF03['created_at'][(tweetsF03['created_at'].dt.day == 17) & (tweetsF03['created_at'].dt.year == 2018) & (tweetsF03['created_at'].dt.month == 1) & (tweetsF03['extracted'] == False)].value_counts()
dates_values18_f03 = tweetsF03['created_at'][(tweetsF03['created_at'].dt.day == 18) & (tweetsF03['created_at'].dt.year == 2018) & (tweetsF03['created_at'].dt.month == 1) & (tweetsF03['extracted'] == False)].value_counts()
dates_values19_f03 = tweetsF03['created_at'][(tweetsF03['created_at'].dt.day == 19) & (tweetsF03['created_at'].dt.year == 2018) & (tweetsF03['created_at'].dt.month == 1) & (tweetsF03['extracted'] == False)].value_counts()
dates_values20_f03 = tweetsF03['created_at'][(tweetsF03['created_at'].dt.day == 20) & (tweetsF03['created_at'].dt.year == 2018) & (tweetsF03['created_at'].dt.month == 1) & (tweetsF03['extracted'] == False)].value_counts()
dates_values21_f03 = tweetsF03['created_at'][(tweetsF03['created_at'].dt.day == 21) & (tweetsF03['created_at'].dt.year == 2018) & (tweetsF03['created_at'].dt.month == 1) & (tweetsF03['extracted'] == False)].value_counts()

dates_values23_f17 = tweetsF17['created_at'][(tweetsF17['created_at'].dt.day == 23) & (tweetsF17['created_at'].dt.year == 2018) & (tweetsF17['created_at'].dt.month == 4) & (tweetsF17['extracted'] == False)].value_counts()
dates_values24_f17 = tweetsF17['created_at'][(tweetsF17['created_at'].dt.day == 24) & (tweetsF17['created_at'].dt.year == 2018) & (tweetsF17['created_at'].dt.month == 4) & (tweetsF17['extracted'] == False)].value_counts()
dates_values25_f17 = tweetsF17['created_at'][(tweetsF17['created_at'].dt.day == 25) & (tweetsF17['created_at'].dt.year == 2018) & (tweetsF17['created_at'].dt.month == 4) & (tweetsF17['extracted'] == False)].value_counts()
dates_values26_f17 = tweetsF17['created_at'][(tweetsF17['created_at'].dt.day == 26) & (tweetsF17['created_at'].dt.year == 2018) & (tweetsF17['created_at'].dt.month == 4) & (tweetsF17['extracted'] == False)].value_counts()
dates_values27_f17 = tweetsF17['created_at'][(tweetsF17['created_at'].dt.day == 27) & (tweetsF17['created_at'].dt.year == 2018) & (tweetsF17['created_at'].dt.month == 4) & (tweetsF17['extracted'] == False)].value_counts()
dates_values28_f17 = tweetsF17['created_at'][(tweetsF17['created_at'].dt.day == 28) & (tweetsF17['created_at'].dt.year == 2018) & (tweetsF17['created_at'].dt.month == 4) & (tweetsF17['extracted'] == False)].value_counts()
dates_values29_f17 = tweetsF17['created_at'][(tweetsF17['created_at'].dt.day == 29) & (tweetsF17['created_at'].dt.year == 2018) & (tweetsF17['created_at'].dt.month == 4) & (tweetsF17['extracted'] == False)].value_counts()

# %%
date1_s = (dates_values23_s17.resample('h').sum().values + dates_values15_s03.resample('h').sum().values) / 2
date2_s = (dates_values24_s17.resample('h').sum().values + dates_values16_s03.resample('h').sum().values) / 2
date3_s = (dates_values25_s17.resample('h').sum().values + dates_values17_s03.resample('h').sum().values) / 2
date4_s = (dates_values26_s17.resample('h').sum().values + dates_values18_s03.resample('h').sum().values) / 2
date5_s = (dates_values27_s17.resample('h').sum().values + dates_values19_s03.resample('h').sum().values) / 2
date6_s = (dates_values28_s17.resample('h').sum().values + dates_values20_s03.resample('h').sum().values) / 2
date7_s = (dates_values29_s17.resample('h').sum().values + dates_values21_s03.resample('h').sum().values) / 2

mean_over_weekdays_s = (date1_s + date2_s + date3_s + date4_s + date5_s + date6_s + date7_s) / 7
mean_over_weekdays_s_normalized = mean_over_weekdays_s/mean_over_weekdays_s.sum()


date1_f = (dates_values23_f17.resample('h').sum().values + dates_values15_f03.resample('h').sum().values) / 2
date2_f = (dates_values24_f17.resample('h').sum().values + dates_values16_f03.resample('h').sum().values) / 2
date3_f = (dates_values25_f17.resample('h').sum().values + dates_values17_f03.resample('h').sum().values) / 2
date4_f = (dates_values26_f17.resample('h').sum().values + dates_values18_f03.resample('h').sum().values) / 2
date5_f = (dates_values27_f17.resample('h').sum().values + dates_values19_f03.resample('h').sum().values) / 2
date6_f = (dates_values28_f17.resample('h').sum().values + dates_values20_f03.resample('h').sum().values) / 2
date7_f = (dates_values29_f17.resample('h').sum().values + dates_values21_f03.resample('h').sum().values) / 2

mean_over_weekdays_f = (date1_f + date2_f + date3_f + date4_f + date5_f + date6_f + date7_f) / 7
mean_over_weekdays_f_normalized = mean_over_weekdays_f/mean_over_weekdays_f.sum()

# %%
plt.figure(figsize=(16,6))

plt.plot(mean_over_weekdays_s_normalized, label="sampled data")
plt.plot(mean_over_weekdays_f_normalized, label="filtered data")
plt.legend()
plt.title('Tweets collected from Sampled API vs Filtered API by hour (mean over week / normalized values) ', fontsize=14)
plt.ylabel('number of tweets per hour')
plt.xlabel('hour')
plt.axis([0, 24, 0, 0.1])

#plt.show()
plt.savefig("streaming_stats/sampled-by-hour-over-week-mean-normalized.png", transparent=True)

# %%
data = {'monday': dates_values15_s03.resample('h').sum().values,
        'tuesday':dates_values16_s03.resample('h').sum().values, 
        'wednesday': dates_values17_s03.resample('h').sum().values, 
        'thursday': dates_values18_s03.resample('h').sum().values,
        'friday': dates_values19_s03.resample('h').sum().values, 
        'saturday': dates_values20_s03.resample('h').sum().values, 
        'sunday': dates_values21_s03.resample('h').sum().values}
df_03_days = pd.DataFrame(data=data)
df_03_days

# %% [markdown]
# ## Comparing Normalized Tweet Collection by Week Day

# %%
week_s03 = tweetsS03['created_at'][(tweetsS03['extracted'] == False) & (tweetsS03['created_at'].dt.year == 2018) & (tweetsS03['created_at'].dt.week == 3)].value_counts()
week_s17 = tweetsS17['created_at'][(tweetsS17['extracted'] == False) & (tweetsS17['created_at'].dt.year == 2018) & (tweetsS17['created_at'].dt.week == 17)].value_counts()

week_f03 = tweetsF03['created_at'][(tweetsF03['extracted'] == False) & (tweetsF03['created_at'].dt.year == 2018) & (tweetsF03['created_at'].dt.week == 3)].value_counts()
week_f17 = tweetsF17['created_at'][(tweetsF17['extracted'] == False) & (tweetsF17['created_at'].dt.year == 2018) & (tweetsF17['created_at'].dt.week == 17)].value_counts()



plt.figure(figsize=(16,6))
plt.plot((((week_s03.resample("D").sum().values + week_s17.resample("D").sum().values) ) / (week_s03.resample("D").sum().values.sum() + week_s17.resample("D").sum().values.sum())), label="sampled data" )
plt.plot( (((week_f03.resample("D").sum().values + week_f17.resample("D").sum().values) ) / (week_f03.resample("D").sum().values.sum() + week_f17.resample("D").sum().values.sum())), label="filtered data" )

plt.legend()
plt.title('Tweets collected from Sampled API vs Filtered API by day (mean over week / normalized values) ', fontsize=14)
weekdays = ['monday', 'tuesday','wednesday','thursday','friday','saturday','sunday']
plt.xticks([0,1,2,3,4,5,6], weekdays)
# Out:
# ([<matplotlib.axis.XTick at 0x1de53a162e8>,
# ...
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# ### Comparing Normalized Tweet Collection by Week Day - Calendar Week 03

# %%
week_s03 = tweetsS03['created_at'][(tweetsS03['extracted'] == False) & (tweetsS03['created_at'].dt.year == 2018) & (tweetsS03['created_at'].dt.week == 3)].value_counts()

week_f03 = tweetsF03['created_at'][(tweetsF03['extracted'] == False) & (tweetsF03['created_at'].dt.year == 2018) & (tweetsF03['created_at'].dt.week == 3)].value_counts()



plt.figure(figsize=(16,6))
plt.plot((((week_s03.resample("D").sum().values) ) / (week_s03.resample("D").sum().values.sum() )), label="sampled data" )
plt.plot( (((week_f03.resample("D").sum().values) ) / (week_f03.resample("D").sum().values.sum())), label="filtered data" )

plt.legend()
plt.title('Tweets collected from Sampled API vs Filtered API by day (mean over week / normalized values) on Calendar Week 03', fontsize=14)
weekdays = ['monday', 'tuesday','wednesday','thursday','friday','saturday','sunday']
plt.xticks([0,1,2,3,4,5,6], weekdays)
# Out:
# ([<matplotlib.axis.XTick at 0x1de009fecf8>,
# ...
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# ### Comparing Normalized Tweet Collection by Week Day - Calendar Week 17

# %%
week_s17 = tweetsS17['created_at'][(tweetsS17['extracted'] == False) & (tweetsS17['created_at'].dt.year == 2018) & (tweetsS17['created_at'].dt.week == 17)].value_counts()

week_f17 = tweetsF17['created_at'][(tweetsF17['extracted'] == False) & (tweetsF17['created_at'].dt.year == 2018) & (tweetsF17['created_at'].dt.week == 17)].value_counts()



plt.figure(figsize=(16,6))
plt.plot(((( week_s17.resample("D").sum().values) ) / ( week_s17.resample("D").sum().values.sum())), label="sampled data" )
plt.plot( ((( week_f17.resample("D").sum().values) ) / (week_f17.resample("D").sum().values.sum())), label="filtered data" )

plt.legend()
plt.title('Tweets collected from Sampled API vs Filtered API by day (mean over week / normalized values) on Calendar Week 17', fontsize=14)
weekdays = ['monday', 'tuesday','wednesday','thursday','friday','saturday','sunday']
plt.xticks([0,1,2,3,4,5,6], weekdays)
# Out:
# ([<matplotlib.axis.XTick at 0x1de538b73c8>,
# ...
#  <a list of 7 Text xticklabel objects>)
