# %% [markdown]
# # Third Party Service Comparison (Sampled vs Filtered)

# %%
import psycopg2
import pandas as pd
import config
from matplotlib import pylab as plt
import seaborn as sns
import numpy as np
from IPython.display import display, HTML
import re


#color_palette = sns.color_palette(palette='muted', n_colors=None, desat=.75)
#sns.set(context='notebook', palette=color_palette, style='whitegrid', font='sans-serif', font_scale=1.5, color_codes=False, rc=None)
pd.set_option('display.max_colwidth', -1)
table_styles = [{'selector': 'td',
                 'props': [('min-width', '100px'), ('text-align', 'center')]},
                {'selector': 'tr',
                 'props': [('border-bottom', '1px dotted black')]},
                {'selector': 'th',
                 'props': [('text-align', 'center')]}
               ]

# %matplotlib inline

directory = "url_top_lists/"
stream = "comparison"

# %% [markdown]
# ## Util Methods

# %%
def compareRows(row, df_to_compare, column_name):
    comparison_row = df_to_compare.loc[df_to_compare[column_name] == row[column_name]]
    if comparison_row.empty:
        comparison = " - "
    else:
        percentage_dif = row['percentage'] - comparison_row['percentage'].values[0]
        difference = "(%s. / %.3f%% / %.3f%%)" % (comparison_row['rank'].values[0], comparison_row['percentage'].values[0], percentage_dif)
        if comparison_row['rank'].values[0] == row['rank']:
            comparison = " = <br>" + difference
        else:
            if comparison_row['rank'].values[0] > row['rank']:
                comparison = " v <br>" + difference
            else:
                comparison = " ^ <br>" + difference
    return comparison

def getOpacity(val):
    value = abs(float(re.findall(r"[-+]?\d*\.\d+|\d+", val.split("/")[2])[0]))
    if value < 0.005:
        return 1
    if value < 0.01:
        return 0.95
    if value < 0.05:
        return 0.8
    if value < 0.1:
        return 0.7
    if value < 0.5:
        return 0.6
    if value < 1:
        return 0.5
    if value < 10:
        return 0.3
    if value < 40:
        return 0.2
    if value < 80:
        return 0.1
    if value < 100:
        return 0.05

def colorComparisonField(val):
    
    if isinstance(val, str):
        if ' ^ ' in val or ' v ' in val:
            return 'background-color: rgba(246, 185, 59, %s)' %getOpacity(val)
        if ' = ' in val:
            return 'background-color: rgba(184, 233, 148, %s)' %getOpacity(val)
        if ' - ' in val and len(val) == 3:
            return 'background-color: #e55039' 
    return ''

def generateRankingDataframe(series, attribute_name):
    size = series.sum()
    rank = []
    parameter = []
    count = []
    percentage = []

    i = 1
    for index, value in series.iteritems():
        rank.append(i)
        parameter.append(index)
        count.append(value)
        percentage.append((value/size)*100)
        i += 1

    data = {'rank': rank, attribute_name: parameter, 'value': count, 'percentage': percentage}
    return pd.DataFrame(data=data)

def generateComparisonDataframes(df1, df2, column_name, size):
    compare_list = []
    for index, row in df1.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df2, column_name))

    data = {'rank': df1['rank'][:size], column_name: df1[column_name][:size], 'value': df1['value'][:size], 'percentage': df1['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df1_compared = pd.DataFrame(data=data)
    df1_compared.set_index(keys='rank', inplace=True)
    
    compare_list = []
    for index, row in df2.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df1, column_name))

    data = {'rank': df2['rank'][:size], column_name: df2[column_name][:size], 'value': df2['value'][:size], 'percentage': df2['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df2_compared = pd.DataFrame(data=data)
    df2_compared.set_index(keys='rank', inplace=True)
    
    return df1_compared, df2_compared

def getPrettyComparisonDataframe(df, title):
    s = df.style.applymap(colorComparisonField)
    s.set_caption(title)
    s.set_table_styles(table_styles)
    return s

# %%
conn = None
try:
    # read connection parameters
    paramsS17 = config.cfgAzureS17()
    paramsS03 = config.cfgAzureS03()

    paramsF17 = config.cfgAzureF17()
    paramsF03 = config.cfgAzureF03()
    
    # connect to the PostgreSQL server
    print('Connecting to the PostgreSQL database...')
    connS17 = psycopg2.connect(**paramsS17)
    connS03 = psycopg2.connect(**paramsS03)
    
    connF17 = psycopg2.connect(**paramsF17)
    connF03 = psycopg2.connect(**paramsF03)

    # create a cursor
    curS17 = connS17.cursor()
    curS03 = connS03.cursor()
    
    curF17 = connF17.cursor()
    curF03 = connF03.cursor()

    # execute a statement
    print('PostgreSQL database version:')
    
    curS17.execute('SELECT version()')
    curS03.execute('SELECT version()')
    curF17.execute('SELECT version()')
    curF03.execute('SELECT version()')
    
    # display the PostgreSQL database server version
    db_version_curS17 = curS17.fetchone()
    db_version_curS03 = curS03.fetchone()
    db_version_curF17 = curF17.fetchone()
    db_version_curF03 = curF03.fetchone()
    
    print(db_version_curS17)
    print(db_version_curS03)
    print(db_version_curF17)
    print(db_version_curF03)

    # close the communication with the PostgreSQL
    curS17.close()
    curS03.close()
    curF17.close()
    curF03.close()

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)

# %% [markdown]
# ## Query URLs

# %% [markdown]
# ### Calendar Week 03 - Sampled

# %%
#tweets03 = pd.read_sql_query("SELECT * FROM tweets_info;", conn, parse_dates=['created_at'] )
#tweets03['created_at'] = tweets['created_at'].dt.tz_localize("UTC").dt.tz_convert("Europe/Berlin")
tweetsS03 = pd.read_sql_query("SELECT source FROM tweets_info;", connS03 )

print("Number of Tweets: %s" %len(tweetsS03))
tweetsS03.head()
# Out:
# Number of Tweets: 123680
#                                                                             source
# 0  <a href="http://autotweety.net" rel="nofollow">autotweety.net</a>
# 1  <a href="http://instagram.com" rel="nofollow">Instagram</a>
# 2  <a href="http://www.rp-online.de" rel="nofollow">RP ONLINE - Wermelskirchen</a>
# 3  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 4  <a href="http://luxviral.com" rel="nofollow">twitterappmila</a>

# %% [markdown]
# empty icards possible

# %% [markdown]
# ### Calendar Week 17 - Sampled

# %%
tweetsS17 = pd.read_sql_query("SELECT source FROM tweets_info;", connS17 )

print("Number of Tweets: %s" %len(tweetsS17))
tweetsS17.head()
# Out:
# Number of Tweets: 112003
#                                                                                          source
# 0  <a href="http://saratoga-weather.org/scripts-TweetWX.php#TweetWX" rel="nofollow">TweetWX</a>
# 1  <a href="http://www.rasputin.de/" rel="nofollow">rasputin</a>
# 2  <a href="http://arduino-tweet.appspot.com/" rel="nofollow">Arduino</a>
# 3  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>

# %% [markdown]
# ## concat to complete Sampled Dataframe

# %%
tweetsS = tweetsS03.append(tweetsS17)
print(len(tweetsS))
# Out:
# 235683

# %% [markdown]
# ### Calendar Week 03 - Filtered

# %%
tweetsF03 = pd.read_sql_query("SELECT source FROM tweets_info;", connF03 )

print("Number of Tweets: %s" %len(tweetsF03))
tweetsF03.head()
# Out:
# Number of Tweets: 8010674
#                                                                                source
# 0  <a href="http://bitcoinge.pw/" rel="nofollow">Marie Hubbard</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="https://socialorga.pontimania.de" rel="nofollow">postman4wobus</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>

# %% [markdown]
# ### Calendar Week 17 - Filtered

# %%
tweetsF17 = pd.read_sql_query("SELECT source FROM tweets_info;", connF17 )

print("Number of Tweets: %s" %len(tweetsF17))
tweetsF17.head()
# Out:
# Number of Tweets: 7269347
#                                                                                source
# 0  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>
# 1  <a href="http://www.tweetauto.com" rel="nofollow">autocarloader</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="https://skildust.com" rel="nofollow">Awoo Ebook Bot</a>
# 4  <a href="https://klaus-uwe.me/" rel="nofollow">Twitools by Kumi</a>

# %% [markdown]
# ### Concat to complete Filtered Dataframe

# %%
tweetsF = tweetsF03.append(tweetsF17)
print(len(tweetsF))
# Out:
# 15280021

# %% [markdown]
# ## Sources

# %% [markdown]
# ### Sources - Sampled x Filtered

# %%
attribute = 'source'
column_name = 'source'
    
df_sampled = generateRankingDataframe(tweetsS[attribute].value_counts(), column_name)
df_filtered = generateRankingDataframe(tweetsF[attribute].value_counts(), column_name)

df_sampled_comparison, df_filtered_comparison = generateComparisonDataframes(df_sampled, df_filtered, column_name, 50)

# %%
display(HTML(df_sampled_comparison.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>difference (rank / percentage / diff)</th>
#       <th>percentage</th>
#       <th>source</th>
#       <th>value</th>
#     </tr>
#     <tr>
#       <th>rank</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>  = &lt;br&gt;(1. / 31.793% / -2.382%)</td>
#       <td> 29.410691</td>
#       <td> &lt;a href="http://twitter.com/download/android" rel="nofollow"&gt;Twitter for Android&lt;/a&gt;</td>
#       <td> 69316</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>  = &lt;br&gt;(2. / 20.916% / 1.045%)</td>
#       <td> 21.960430</td>
#       <td> &lt;a href="http://twitter.com" rel="nofollow"&gt;Twitter Web Client&lt;/a&gt;</td>
#       <td> 51757</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>  = &lt;br&gt;(3. / 19.166% / 1.198%)</td>
#       <td> 20.363794</td>
#       <td> &lt;a href="http://twitter.com/download/iphone" rel="nofollow"&gt;Twitter for iPhone&lt;/a&gt;</td>
#       <td> 47994</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>  = &lt;br&gt;(4. / 2.737% / 0.573%)</td>
#       <td> 3.310379</td>
#       <td> &lt;a href="https://about.twitter.com/products/tweetdeck" rel="nofollow"&gt;TweetDeck&lt;/a&gt;</td>
#       <td> 7802</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>  v &lt;br&gt;(6. / 2.358% / -0.119%)</td>
#       <td> 2.239024</td>
#       <td> &lt;a href="https://mobile.twitter.com" rel="nofollow"&gt;Twitter Lite&lt;/a&gt;</td>
#       <td> 5277</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>  ^ &lt;br&gt;(5. / 2.370% / -0.138%)</td>
#       <td> 2.232660</td>
#       <td> &lt;a href="http://twitter.com/#!/download/ipad" rel="nofollow"&gt;Twitter for iPad&lt;/a&gt;</td>
#       <td> 5262</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>  v &lt;br&gt;(9. / 1.591% / 0.233%)</td>
#       <td> 1.823636</td>
#       <td> &lt;a href="https://ifttt.com" rel="nofollow"&gt;IFTTT&lt;/a&gt;</td>
#       <td> 4298</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>  ^ &lt;br&gt;(7. / 2.086% / -0.477%)</td>
#       <td> 1.608517</td>
#       <td> &lt;a href="http://www.google.com/" rel="nofollow"&gt;Google&lt;/a&gt;</td>
#       <td> 3791</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>  ^ &lt;br&gt;(8. / 1.796% / -0.207%)</td>
#       <td> 1.588574</td>
#       <td> &lt;a href="http://www.facebook.com/twitter" rel="nofollow"&gt;Facebook&lt;/a&gt;</td>
#       <td> 3744</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>  = &lt;br&gt;(10. / 1.070% / -0.056%)</td>
#       <td> 1.013225</td>
#       <td> &lt;a href="https://dlvrit.com/" rel="nofollow"&gt;dlvr.it&lt;/a&gt;</td>
#       <td> 2388</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>  = &lt;br&gt;(11. / 0.906% / -0.132%)</td>
#       <td> 0.773497</td>
#       <td> &lt;a href="http://tapbots.com/tweetbot" rel="nofollow"&gt;Tweetbot for iΟS&lt;/a&gt;</td>
#       <td> 1823</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>  = &lt;br&gt;(12. / 0.771% / -0.009%)</td>
#       <td> 0.761616</td>
#       <td> &lt;a href="http://publicize.wp.com/" rel="nofollow"&gt;WordPress.com&lt;/a&gt;</td>
#       <td> 1795</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>  = &lt;br&gt;(13. / 0.479% / 0.188%)</td>
#       <td> 0.666573</td>
#       <td> &lt;a href="http://www.hootsuite.com" rel="nofollow"&gt;Hootsuite&lt;/a&gt;</td>
#       <td> 1571</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>  v &lt;br&gt;(15. / 0.411% / 0.013%)</td>
#       <td> 0.424299</td>
#       <td> &lt;a href="http://instagram.com" rel="nofollow"&gt;Instagram&lt;/a&gt;</td>
#       <td> 1000</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>  v &lt;br&gt;(17. / 0.258% / 0.162%)</td>
#       <td> 0.420480</td>
#       <td> &lt;a href="http://bufferapp.com" rel="nofollow"&gt;Buffer&lt;/a&gt;</td>
#       <td> 991</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>  ^ &lt;br&gt;(14. / 0.467% / -0.072%)</td>
#       <td> 0.395446</td>
#       <td> &lt;a href="http://www.twitter.com" rel="nofollow"&gt;Twitter for Windows&lt;/a&gt;</td>
#       <td> 932</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>  ^ &lt;br&gt;(16. / 0.258% / 0.122%)</td>
#       <td> 0.380172</td>
#       <td> &lt;a href="http://twittbot.net/" rel="nofollow"&gt;twittbot.net&lt;/a&gt;</td>
#       <td> 896</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>  = &lt;br&gt;(18. / 0.202% / 0.001%)</td>
#       <td> 0.203239</td>
#       <td> &lt;a href="http://tapbots.com/software/tweetbot/mac" rel="nofollow"&gt;Tweetbot for Mac&lt;/a&gt;</td>
#       <td> 479</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>  = &lt;br&gt;(19. / 0.185% / 0.002%)</td>
#       <td> 0.186691</td>
#       <td> &lt;a href="https://mobile.twitter.com" rel="nofollow"&gt;Mobile Web (M2)&lt;/a&gt;</td>
#       <td> 440</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>  v &lt;br&gt;(75. / 0.031% / 0.145%)</td>
#       <td> 0.175235</td>
#       <td> &lt;a href="https://studio.twitter.com" rel="nofollow"&gt;Media Studio&lt;/a&gt;</td>
#       <td> 413</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>  v &lt;br&gt;(24. / 0.139% / 0.022%)</td>
#       <td> 0.160809</td>
#       <td> &lt;a href="http://www.ajaymatharu.com/" rel="nofollow"&gt;Tweet Old Post&lt;/a&gt;</td>
#       <td> 379</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>  v &lt;br&gt;(23. / 0.141% / 0.008%)</td>
#       <td> 0.149353</td>
#       <td> &lt;a href="https://www.echobox.com" rel="nofollow"&gt;Echobox Social&lt;/a&gt;</td>
#       <td> 352</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>  ^ &lt;br&gt;(20. / 0.171% / -0.028%)</td>
#       <td> 0.142564</td>
#       <td> &lt;a href="http://paper.li" rel="nofollow"&gt;Paper.li&lt;/a&gt;</td>
#       <td> 336</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>  v &lt;br&gt;(56. / 0.040% / 0.101%)</td>
#       <td> 0.141291</td>
#       <td> &lt;a href="http://www.socialflow.com" rel="nofollow"&gt;SocialFlow&lt;/a&gt;</td>
#       <td> 333</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>  v &lt;br&gt;(26. / 0.139% / -0.001%)</td>
#       <td> 0.137473</td>
#       <td> &lt;a href="https://socialorga.pontimania.de" rel="nofollow"&gt;postman4wobus&lt;/a&gt;</td>
#       <td> 324</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>  v &lt;br&gt;(30. / 0.125% / 0.000%)</td>
#       <td> 0.124744</td>
#       <td> &lt;a href="https://zapier.com/" rel="nofollow"&gt;Zapier.com&lt;/a&gt;</td>
#       <td> 294</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>  v &lt;br&gt;(29. / 0.127% / -0.015%)</td>
#       <td> 0.112015</td>
#       <td> &lt;a href="http://www.tweetcaster.com" rel="nofollow"&gt;TweetCaster for Android&lt;/a&gt;</td>
#       <td> 264</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>  ^ &lt;br&gt;(22. / 0.153% / -0.049%)</td>
#       <td> 0.103529</td>
#       <td> &lt;a href="http://tweetoo.de" rel="nofollow"&gt;TweeToo.de&lt;/a&gt;</td>
#       <td> 244</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>  ^ &lt;br&gt;(21. / 0.155% / -0.057%)</td>
#       <td> 0.098013</td>
#       <td> &lt;a href="http://www.game-insight.com/" rel="nofollow"&gt;Paradise Island 2&lt;/a&gt;</td>
#       <td> 231</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>  - </td>
#       <td> 0.097164</td>
#       <td> &lt;a href="http://www.uctec.com/" rel="nofollow"&gt;Tw-Engine&lt;/a&gt;</td>
#       <td> 229</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>  v &lt;br&gt;(47. / 0.053% / 0.044%)</td>
#       <td> 0.096316</td>
#       <td> &lt;a href="https://swat.io/" rel="nofollow"&gt;Swat.io&lt;/a&gt;</td>
#       <td> 227</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>  = &lt;br&gt;(32. / 0.117% / -0.022%)</td>
#       <td> 0.095467</td>
#       <td> &lt;a href="http://www.samruston.co.uk" rel="nofollow"&gt;Flamingo for Android&lt;/a&gt;</td>
#       <td> 225</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>  = &lt;br&gt;(33. / 0.109% / -0.018%)</td>
#       <td> 0.091649</td>
#       <td> &lt;a href="http://www.twitter.com" rel="nofollow"&gt;Twitter for Windows Phone&lt;/a&gt;</td>
#       <td> 216</td>
#     </tr>

# %%
s = getPrettyComparisonDataframe(df_sampled_comparison, "Sources - Sampled Data (compared to Filtered Data)")
s
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-effb4f8b6dd0> in <module>()
# ----> 1 s = getPrettyComparisonDataframe(df_sampled_comparison, "Sources - Sampled Data (compared to Filtered Data)")
#       2 s
#
# <ipython-input-6-45606d24997a> in getPrettyComparisonDataframe(df, title)
#      93
#      94 def getPrettyComparisonDataframe(df, title):
# ---> 95     s = df.style.applymap(colorComparisonField)
#      96     s.set_caption(title)
#      97     s.set_table_styles(table_styles)
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'style'

# %%
display(df_filtered_comparison)
# Out:
#      difference (rank / percentage / diff)  percentage  \
# rank
# 1      = <br>(1. / 29.411% / 2.382%)        31.793170
# 2      = <br>(2. / 21.960% / -1.045%)       20.915580
# 3      = <br>(3. / 20.364% / -1.198%)       19.165798
# 4      = <br>(4. / 3.310% / -0.573%)        2.736881
# 5      v <br>(6. / 2.233% / 0.138%)         2.370239
# 6      ^ <br>(5. / 2.239% / 0.119%)         2.357706
# 7      v <br>(8. / 1.609% / 0.477%)         2.085854
# 8      v <br>(9. / 1.589% / 0.207%)         1.796018
# 9      ^ <br>(7. / 1.824% / -0.233%)        1.590986
# 10     = <br>(10. / 1.013% / 0.056%)        1.069671
# 11     = <br>(11. / 0.773% / 0.132%)        0.905948
# 12     = <br>(12. / 0.762% / 0.009%)        0.771026
# 13     = <br>(13. / 0.667% / -0.188%)       0.478906
# 14     v <br>(16. / 0.395% / 0.072%)        0.467231
# 15     ^ <br>(14. / 0.424% / -0.013%)       0.411393
# 16     v <br>(17. / 0.380% / -0.122%)       0.258422
# 17     ^ <br>(15. / 0.420% / -0.162%)       0.258239
# 18     = <br>(18. / 0.203% / -0.001%)       0.202408
# 19     = <br>(19. / 0.187% / -0.002%)       0.184699
# 20     v <br>(23. / 0.143% / 0.028%)        0.170517
# 21     v <br>(29. / 0.098% / 0.057%)        0.155104
# 22     v <br>(28. / 0.104% / 0.049%)        0.152886
# 23     ^ <br>(22. / 0.149% / -0.008%)       0.141053
# 24     ^ <br>(21. / 0.161% / -0.022%)       0.139103
# 25     v <br>(34. / 0.090% / 0.049%)        0.138959
# 26     ^ <br>(25. / 0.137% / 0.001%)        0.138691
# 27     v <br>(37. / 0.079% / 0.052%)        0.131256
# 28     v <br>(35. / 0.089% / 0.041%)        0.130006
# 29     ^ <br>(27. / 0.112% / 0.015%)        0.127146
# 30     ^ <br>(26. / 0.125% / -0.000%)       0.124516
# 31     v <br>(36. / 0.085% / 0.034%)        0.118370
# 32     = <br>(32. / 0.095% / 0.022%)        0.117389
# 33     = <br>(33. / 0.092% / 0.018%)        0.109457
# 34     v <br>(38. / 0.079% / 0.021%)        0.100085
# 35     v <br>(47. / 0.055% / 0.028%)        0.082807
# 36     v <br>(40. / 0.074% / 0.003%)        0.077382
# 37     v <br>(39. / 0.076% / -0.000%)       0.075890
# 38     v <br>(52. / 0.048% / 0.028%)        0.075766
# 39     v <br>(41. / 0.063% / 0.011%)        0.074555
# 40     v <br>(42. / 0.060% / 0.012%)        0.071492
# 41     v <br>(48. / 0.055% / 0.015%)        0.070052
# 42     v <br>(46. / 0.055% / 0.014%)        0.068770
# 43     v <br>(44. / 0.059% / 0.007%)        0.065726
# 44     v <br>(54. / 0.045% / 0.020%)        0.065314
# 45     v <br>(58. / 0.040% / 0.025%)        0.064915
# 46     ^ <br>(45. / 0.056% / 0.000%)        0.056080
# 47     ^ <br>(31. / 0.096% / -0.044%)       0.052598
# 48     v <br>(51. / 0.048% / 0.001%)        0.049758
# 49     v <br>(83. / 0.027% / 0.022%)        0.049313
# 50     v <br>(59. / 0.039% / 0.008%)        0.046989
#
#                                                                                                      source  \
# rank
# 1     <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 2     <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 3     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4     <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>
# 5     <a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>
# 6     <a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>
# 7     <a href="http://www.google.com/" rel="nofollow">Google</a>
# 8     <a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>
# 9     <a href="https://ifttt.com" rel="nofollow">IFTTT</a>
# 10    <a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>
# 11    <a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>
# 12    <a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>
# 13    <a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>
# 14    <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows</a>
# 15    <a href="http://instagram.com" rel="nofollow">Instagram</a>
# 16    <a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>
# 17    <a href="http://bufferapp.com" rel="nofollow">Buffer</a>
# 18    <a href="http://tapbots.com/software/tweetbot/mac" rel="nofollow">Tweetbot for Mac</a>
# 19    <a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M2)</a>
# 20    <a href="http://paper.li" rel="nofollow">Paper.li</a>
# 21    <a href="http://www.game-insight.com/" rel="nofollow">Paradise Island 2</a>
# 22    <a href="http://tweetoo.de" rel="nofollow">TweeToo.de</a>
# 23    <a href="https://www.echobox.com" rel="nofollow">Echobox Social</a>
# 24    <a href="http://www.ajaymatharu.com/" rel="nofollow">Tweet Old Post</a>
# 25    <a href="http://ask.fm/" rel="nofollow">Ask.fm</a>
# 26    <a href="https://socialorga.pontimania.de" rel="nofollow">postman4wobus</a>
# 27    <a href="http://www.benzinpreis-aktuell.de" rel="nofollow">Spritpreise</a>
# 28    <a href="http://www.miet-check.de" rel="nofollow">mietcheck</a>
# 29    <a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>
# 30    <a href="https://zapier.com/" rel="nofollow">Zapier.com</a>
# 31    <a href="https://github.com/mariotaku/twidere/" rel="nofollow">Twidere for Android #7</a>
# 32    <a href="http://www.samruston.co.uk" rel="nofollow">Flamingo for Android</a>
# 33    <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# 34    <a href="http://twibble.io" rel="nofollow">Twibble.io</a>
# 35    <a href="http://mvilla.it/fenix" rel="nofollow">Fenix 2</a>
# 36    <a href="https://www.socialoomph.com" rel="nofollow">SocialOomph</a>
# 37    <a href="http://itunes.apple.com/us/app/twitter/id409789998?mt=12" rel="nofollow">Twitter for Mac</a>
# 38    <a href="http://www.germanpersonnel.de" rel="nofollow">peRsy Jobs 2.0</a>
# 39    <a href="http://share.radionomy.com" rel="nofollow">Share.Radionomy.com</a>
# 40    <a href="http://twitterrific.com" rel="nofollow">Twitterrific</a>
# 41    <a href="https://www.xing.com/" rel="nofollow">XING</a>
# 42    <a href="http://klinkerapps.com" rel="nofollow">Talon Android</a>
# 43    <a href="http://cheapbotsdonequick.com" rel="nofollow">Cheap Bots, Done Quick!</a>
# 44    <a href="https://favstar.fm" rel="nofollow">Favstar.FM</a>
# 45    <a href="http://foursquare.com" rel="nofollow">Foursquare</a>
# 46    <a href="http://www.echofon.com/" rel="nofollow">Echofon</a>
# 47    <a href="https://swat.io/" rel="nofollow">Swat.io</a>
# 48    <a href="https://app.socialhub.io/" rel="nofollow">SocialHub by maloon</a>
# 49    <a href="http://www.gute-banken.de/" rel="nofollow">gutebanken</a>
# 50    <a href="http://bitcoinge.pw/" rel="nofollow">Marie Hubbard</a>
#
#         value
# rank
# 1     4858003
# 2     3195905
# 3     2928538
# 4     418196
# 5     362173
# 6     360258
# 7     318719
# 8     274432
# 9     243103
# 10    163446
# 11    138429
# 12    117813
# 13    73177
# 14    71393
# 15    62861
# 16    39487
# 17    39459
# 18    30928
# 19    28222
# 20    26055
# 21    23700
# 22    23361
# 23    21553
# 24    21255
# 25    21233
# 26    21192
# 27    20056
# 28    19865
# 29    19428
# 30    19026
# 31    18087
# 32    17937
# 33    16725
# 34    15293
# 35    12653
# 36    11824
# 37    11596
# 38    11577
# 39    11392
# 40    10924
# 41    10704
# 42    10508
# 43    10043
# 44    9980
# 45    9919
# 46    8569
# 47    8037
# 48    7603
# 49    7535
# 50    7180

# %%
s = getPrettyComparisonDataframe(df_filtered_comparison, "Sources - Filtered Data (compared to Sampled Data)")
s
# Out:
# <style  type="text/css" >
#     #T_4d50caca_6a39_11e8_ad2a_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3 th {
#           text-align: center;
#     }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row5_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row7_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row8_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row9_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row10_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row11_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row12_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row13_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row14_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row15_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row16_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row17_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row19_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row20_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row21_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row22_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_4d50caca_6a39_11e8_ad2a_642737c470c3row24_col3 {
#             background-color:  rgba(246, 185, 59, 0.6);
#         }</style>
# <table id="T_4d50caca_6a39_11e8_ad2a_642737c470c3" ><caption>CW 03 - Top Level Domains - Filtered Data (compared to Sampled Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Top Level Domain</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_4d50caca_6a39_11e8_ad2a_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row0_col0" class="data row0 col0" >youtube.com</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row0_col1" class="data row0 col1" >178108</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row0_col2" class="data row0 col2" >15.6365</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 14.026% / 1.611%)</td>
#     </tr>    <tr>
#         <th id="T_4d50caca_6a39_11e8_ad2a_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row1_col0" class="data row1 col0" >welt.de</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row1_col1" class="data row1 col1" >34424</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row1_col2" class="data row1 col2" >3.02215</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row1_col3" class="data row1 col3" > = <br>(2. / 3.302% / -0.280%)</td>
#     </tr>    <tr>
#         <th id="T_4d50caca_6a39_11e8_ad2a_642737c470c3level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row2_col0" class="data row2 col0" >spiegel.de</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row2_col1" class="data row2 col1" >26553</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row2_col2" class="data row2 col2" >2.33114</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row2_col3" class="data row2 col3" > = <br>(3. / 2.346% / -0.015%)</td>
#     </tr>    <tr>
#         <th id="T_4d50caca_6a39_11e8_ad2a_642737c470c3level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row3_col0" class="data row3 col0" >focus.de</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row3_col1" class="data row3 col1" >26392</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row3_col2" class="data row3 col2" >2.31701</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row3_col3" class="data row3 col3" > = <br>(4. / 2.146% / 0.171%)</td>
#     </tr>    <tr>
#         <th id="T_4d50caca_6a39_11e8_ad2a_642737c470c3level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row4_col0" class="data row4 col0" >google.com</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row4_col1" class="data row4 col1" >21592</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row4_col2" class="data row4 col2" >1.89561</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row4_col3" class="data row4 col3" > v <br>(14. / 0.847% / 1.049%)</td>
#     </tr>    <tr>
#         <th id="T_4d50caca_6a39_11e8_ad2a_642737c470c3level0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row5_col0" class="data row5 col0" >bild.de</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row5_col1" class="data row5 col1" >21184</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row5_col2" class="data row5 col2" >1.85979</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row5_col3" class="data row5 col3" > ^ <br>(5. / 2.043% / -0.183%)</td>
#     </tr>    <tr>
#         <th id="T_4d50caca_6a39_11e8_ad2a_642737c470c3level0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row6_col0" class="data row6 col0" >faz.net</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row6_col1" class="data row6 col1" >20311</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row6_col2" class="data row6 col2" >1.78314</td>
#         <td id="T_4d50caca_6a39_11e8_ad2a_642737c470c3row6_col3" class="data row6 col3" > ^ <br>(6. / 1.791% / -0.008%)</td>
#     </tr>    <tr>

# %% [markdown]
# ## Top Services

# %%
for index, row in df_sampled_comparison.iterrows():
    print(str(index), "%.3f%%" %row['percentage'],  row['source'].split(">")[1].split("<")[0], str(row['source'].split("\"")[1]), sep="\t")
# Out:
# 1	29.411%	Twitter for Android	http://twitter.com/download/android
# 2	21.960%	Twitter Web Client	http://twitter.com
# 3	20.364%	Twitter for iPhone	http://twitter.com/download/iphone
# 4	3.310%	TweetDeck	https://about.twitter.com/products/tweetdeck
# 5	2.239%	Twitter Lite	https://mobile.twitter.com
# 6	2.233%	Twitter for iPad	http://twitter.com/#!/download/ipad
# 7	1.824%	IFTTT	https://ifttt.com
# 8	1.609%	Google	http://www.google.com/
# 9	1.589%	Facebook	http://www.facebook.com/twitter
# 10	1.013%	dlvr.it	https://dlvrit.com/
# 11	0.773%	Tweetbot for iΟS	http://tapbots.com/tweetbot
# 12	0.762%	WordPress.com	http://publicize.wp.com/
# 13	0.667%	Hootsuite	http://www.hootsuite.com
# 14	0.424%	Instagram	http://instagram.com
# 15	0.420%	Buffer	http://bufferapp.com
# 16	0.395%	Twitter for Windows	http://www.twitter.com
# 17	0.380%	twittbot.net	http://twittbot.net/
# 18	0.203%	Tweetbot for Mac	http://tapbots.com/software/tweetbot/mac
# 19	0.187%	Mobile Web (M2)	https://mobile.twitter.com
# 20	0.175%	Media Studio	https://studio.twitter.com
# 21	0.161%	Tweet Old Post	http://www.ajaymatharu.com/
# 22	0.149%	Echobox Social	https://www.echobox.com
# 23	0.143%	Paper.li	http://paper.li
# 24	0.141%	SocialFlow	http://www.socialflow.com
# 25	0.137%	postman4wobus	https://socialorga.pontimania.de
# 26	0.125%	Zapier.com	https://zapier.com/
# 27	0.112%	TweetCaster for Android	http://www.tweetcaster.com
# 28	0.104%	TweeToo.de	http://tweetoo.de
# 29	0.098%	Paradise Island 2	http://www.game-insight.com/
# 30	0.097%	Tw-Engine	http://www.uctec.com/
# 31	0.096%	Swat.io	https://swat.io/
# 32	0.095%	Flamingo for Android	http://www.samruston.co.uk
# 33	0.092%	Twitter for Windows Phone	http://www.twitter.com
# 34	0.090%	Ask.fm	http://ask.fm/
# 35	0.089%	mietcheck	http://www.miet-check.de
# 36	0.085%	Twidere for Android #7	https://github.com/mariotaku/twidere/
# 37	0.079%	Spritpreise	http://www.benzinpreis-aktuell.de
# 38	0.079%	Twibble.io	http://twibble.io
# 39	0.076%	Twitter for Mac	http://itunes.apple.com/us/app/twitter/id409789998?mt=12
# 40	0.074%	SocialOomph	https://www.socialoomph.com
# 41	0.063%	Share.Radionomy.com	http://share.radionomy.com
# 42	0.060%	Twitterrific	http://twitterrific.com
# 43	0.060%	Curious Cat	https://curiouscat.me
# 44	0.059%	Cheap Bots, Done Quick!	http://cheapbotsdonequick.com
# 45	0.056%	Echofon	http://www.echofon.com/
# 46	0.055%	Talon Android	http://klinkerapps.com
# 47	0.055%	Fenix 2	http://mvilla.it/fenix
# 48	0.055%	XING	https://www.xing.com/
# 49	0.053%	PLANI-PICK	http://ck.plani.co.kr
# 50	0.051%	KippoTweeter	http://www.mayhemiclabs.com
