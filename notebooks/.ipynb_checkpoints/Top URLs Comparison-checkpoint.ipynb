# %% [markdown]
# # Shared URL Comparison

# %%
import psycopg2
import pandas as pd
import config
from matplotlib import pylab as plt
import seaborn as sns
import numpy as np
from IPython.display import display, HTML
import re


color_palette = sns.color_palette(palette='muted', n_colors=None, desat=.75)
sns.set(context='notebook', palette=color_palette, style='whitegrid', font='sans-serif', font_scale=1.5, color_codes=False, rc=None)
pd.set_option('display.max_colwidth', -1)
table_styles = [{'selector': 'td',
                 'props': [('min-width', '100px'), ('text-align', 'center')]},
                {'selector': 'tr',
                 'props': [('border-bottom', '1px dotted black')]},
                {'selector': 'th',
                 'props': [('text-align', 'center')]}
               ]

# %matplotlib inline

directory = "url_top_lists/"
stream = "comparison"

# %% [markdown]
# ## Util Methods

# %%
def compareRows(row, df_to_compare, column_name):
    comparison_row = df_to_compare.loc[df_to_compare[column_name] == row[column_name]]
    if comparison_row.empty:
        comparison = " - "
    else:
        percentage_dif = row['percentage'] - comparison_row['percentage'].values[0]
        difference = "(%s. / %.3f%% / %.3f%%)" % (comparison_row['rank'].values[0], comparison_row['percentage'].values[0], percentage_dif)
        if comparison_row['rank'].values[0] == row['rank']:
            comparison = " = <br>" + difference
        else:
            if comparison_row['rank'].values[0] > row['rank']:
                comparison = " v <br>" + difference
            else:
                comparison = " ^ <br>" + difference
    return comparison

def getOpacity(val):
    value = abs(float(re.findall(r"[-+]?\d*\.\d+|\d+", val.split("/")[2])[0]))
    if value < 0.005:
        return 1
    if value < 0.01:
        return 0.95
    if value < 0.05:
        return 0.8
    if value < 0.1:
        return 0.7
    if value < 0.5:
        return 0.6
    if value < 1:
        return 0.5
    if value < 10:
        return 0.3
    if value < 40:
        return 0.2
    if value < 80:
        return 0.1
    if value < 100:
        return 0.05

def colorComparisonField(val):
    
    if isinstance(val, str):
        if ' ^ ' in val or ' v ' in val:
            return 'background-color: rgba(246, 185, 59, %s)' %getOpacity(val)
        if ' = ' in val:
            return 'background-color: rgba(184, 233, 148, %s)' %getOpacity(val)
        if ' - ' in val and len(val) == 3:
            return 'background-color: #e55039' 
    return ''

def generateRankingDataframe(series, attribute_name):
    size = series.sum()
    rank = []
    parameter = []
    count = []
    percentage = []

    i = 1
    for index, value in series.iteritems():
        rank.append(i)
        parameter.append(index)
        count.append(value)
        percentage.append((value/size)*100)
        i += 1

    data = {'rank': rank, attribute_name: parameter, 'value': count, 'percentage': percentage}
    return pd.DataFrame(data=data)

def generateComparisonDataframes(df1, df2, column_name, size):
    compare_list = []
    for index, row in df1.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df2, column_name))

    data = {'rank': df1['rank'][:size], column_name: df1[column_name][:size], 'value': df1['value'][:size], 'percentage': df1['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df1_compared = pd.DataFrame(data=data)
    df1_compared.set_index(keys='rank', inplace=True)
    
    compare_list = []
    for index, row in df2.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df1, column_name))

    data = {'rank': df2['rank'][:size], column_name: df2[column_name][:size], 'value': df2['value'][:size], 'percentage': df2['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df2_compared = pd.DataFrame(data=data)
    df2_compared.set_index(keys='rank', inplace=True)
    
    return df1_compared, df2_compared

def getPrettyComparisonDataframe(df, title):
    s = df.style.applymap(colorComparisonField)
    s.set_caption(title)
    s.set_table_styles(table_styles)
    return s

# %%
conn = None
try:
    # read connection parameters
    paramsS17 = config.cfgAzureS17()
    paramsS03 = config.cfgAzureS03()

    paramsF17 = config.cfgAzureF17()
    paramsF03 = config.cfgAzureF03()
    
    # connect to the PostgreSQL server
    print('Connecting to the PostgreSQL database...')
    connS17 = psycopg2.connect(**paramsS17)
    connS03 = psycopg2.connect(**paramsS03)
    
    connF17 = psycopg2.connect(**paramsF17)
    connF03 = psycopg2.connect(**paramsF03)

    # create a cursor
    curS17 = connS17.cursor()
    curS03 = connS03.cursor()
    
    curF17 = connF17.cursor()
    curF03 = connF03.cursor()

    # execute a statement
    print('PostgreSQL database version:')
    
    curS17.execute('SELECT version()')
    curS03.execute('SELECT version()')
    curF17.execute('SELECT version()')
    curF03.execute('SELECT version()')
    
    # display the PostgreSQL database server version
    db_version_curS17 = curS17.fetchone()
    db_version_curS03 = curS03.fetchone()
    db_version_curF17 = curF17.fetchone()
    db_version_curF03 = curF03.fetchone()
    
    print(db_version_curS17)
    print(db_version_curS03)
    print(db_version_curF17)
    print(db_version_curF03)

    # close the communication with the PostgreSQL
    curS17.close()
    curS03.close()
    curF17.close()
    curF03.close()

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)

# %% [markdown]
# ## Query URLs

# %% [markdown]
# ### Calendar Week 03 - Sampled

# %%
#tweets03 = pd.read_sql_query("SELECT * FROM tweets_info;", conn, parse_dates=['created_at'] )
#tweets03['created_at'] = tweets['created_at'].dt.tz_localize("UTC").dt.tz_convert("Europe/Berlin")
tweetsS03 = pd.read_sql_query("SELECT * FROM tweets_urls;", connS03 )

print("Number of Tweets: %s" %len(tweetsS03))
tweetsS03.head()
# Out:
# Number of Tweets: 40339
#              tweet_id  \
# 0  953585808631631872
# 1  952676758066728960
# 2  952676816820621314
# 3  952676760390336512
# 4  952677085230915589
#
#                                                             short_url  \
# 0  https://twitter.com/Zockerli/status/953370777017094144
# 1  http://bit.ly/2D8B0mK
# 2  http://youtu.be/xo1eqTeG5DY?a
# 3  http://on.wusa9.com/2D0gSit
# 4  https://www.refcrime.info/de/Crime/Show/74471?tkn=EA05559E0B0B10F0
#
#                                                                                                                           resolved_url  \
# 0  https://twitter.com/Zockerli/status/953370777017094144
# 1  http://dalyaakota.ru/mghnfgnrtgfgnfgbfbrgdfnfgf/6733
# 2  https://www.youtube.com/watch?v=xo1eqTeG5DY&feature=youtu.be&a
# 3  https://www.wusa9.com/article/news/nation-world/amazon-ceo-and-his-wife-donate-33m-scholarship-grant-for-daca-students/65-507939971
# 4  https://www.refcrime.info/de/Crime/Show/74471?tkn=EA05559E0B0B10F0
#
#    response_code                      domain top_level_domain  is_twitter_url  \
# 0  200.0          https://twitter.com/        twitter.com      True
# 1 NaN             http://dalyaakota.ru/       dalyaakota.ru    False
# 2  200.0          https://www.youtube.com/    youtube.com      False
# 3  200.0          https://www.wusa9.com/      wusa9.com        False
# 4  200.0          https://www.refcrime.info/  refcrime.info    False
#
#   is_media  is_processed  failed
# 0  False    True          False
# 1  None     True          True
# 2  False    True          False
# 3  False    True          False
# 4  False    True          False

# %% [markdown]
# ### Calendar Week 17 - Sampled

# %%
tweetsS17 = pd.read_sql_query("SELECT * FROM tweets_urls;", connS17 )

print("Number of Tweets: %s" %len(tweetsS17))
tweetsS17.head()
# Out:
# Number of Tweets: 35687
#              tweet_id  \
# 0  989097603664138240
# 1  988175933659021318
# 2  988176164358361088
# 3  988176403412766720
# 4  988176415995592704
#
#                                                                   short_url  \
# 0  http://arte.tv/abgedreht
# 1  https://twitter.com/piersmorgan/status/987388203593322496
# 2  https://www.journal.koeln/pol-ham-fahrradfahrer-verletzt-sich-bei-sturz/
# 3  http://www.radionomy.com/erika1
# 4  https://twitter.com/JanLatten/status/988161845205913600
#
#                                                                resolved_url  \
# 0  https://www.arte.tv/de/videos/RC-014033/abgedreht/
# 1  https://twitter.com/piersmorgan/status/987388203593322496
# 2  https://www.journal.koeln/pol-ham-fahrradfahrer-verletzt-sich-bei-sturz/
# 3  https://www.radionomy.com/en/radio/erika1
# 4  https://twitter.com/JanLatten/status/988161845205913600
#
#    response_code                      domain top_level_domain  is_twitter_url  \
# 0  200.0          https://www.arte.tv/        arte.tv          False
# 1  200.0          https://twitter.com/        twitter.com      True
# 2  200.0          https://www.journal.koeln/  journal.koeln    False
# 3  200.0          https://www.radionomy.com/  radionomy.com    False
# 4  200.0          https://twitter.com/        twitter.com      True
#
#   is_media  is_processed  failed
# 0  False    True          False
# 1  False    True          False
# 2  False    True          False
# 3  False    True          False
# 4  False    True          False

# %% [markdown]
# ### Calendar Week 03 - Filtered

# %%
tweetsF03 = pd.read_sql_query("SELECT * FROM tweets_urls;", connF03 )

print("Number of Tweets: %s" %len(tweetsF03))
tweetsF03.head()
# Out:
# Number of Tweets: 2411523
#              tweet_id  \
# 0  953683515803099138
# 1  954032649353465856
# 2  954032649483554816
# 3  954032649315655680
# 4  954032649487527938
#
#                                                                                                                                             short_url  \
# 0  http://www.hda-koeln.de
# 1  https://www.amazon.de/diesem-hei%C3%9Fen-Sommer-Eva-Maria-Farohi-ebook/dp/B075KHFTJW/ref=la_B00YYC9ZUG_1_10?s=books&ie=UTF8&qid=1505325422&sr=1-10
# 2  https://fb.me/P063el3s
# 3  http://dlvr.it/QBmbks
# 4  http://dlvr.it/QBmbkh
#
#                                                                                                                                                                                                                                                                                                                                                                                                         resolved_url  \
# 0  http://www.hda-koeln.de/
# 1  https://www.amazon.de/diesem-hei%C3%9Fen-Sommer-Eva-Maria-Farohi-ebook/dp/B075KHFTJW/ref=la_B00YYC9ZUG_1_10?s=books&ie=UTF8&qid=1505325422&sr=1-10
# 2  https://www.facebook.com/hellwegradio/posts/1824843810872037
# 3  https://www.amateurseite.com/index.php?fsk=16&mediagallery_id=4113344&utm_source=dlvr.it&utm_medium=twitter&geoip_cc=DE&geoip_lat=51.0500&geoip_lon=13.7500&main=mediagallery&page=view_video&template=page_view_video&wm=6460&ts=rss&prm=rev&pr=Stripbunnies
# 4  https://news.google.com/?sa=t&fd=R&ct2=de&usg=AFQjCNE-JoIbC8dsXduut9q4Oxp_EUQnbg&clid=c3a7d30bb8a4878e06b80cf16b898331&cid=52780764023198&ei=tc9gWtj6E5PthQGj-YaQAQ&url=http://www.abendzeitung-muenchen.de/inhalt.videodreh-in-thailand-unfall-in-thailand-marc-terenzi-zeigt-seine-verletzungen.7b7c38da-15eb-4652-b5fb-6806bde81bae.html&utm_source=dlvr.it&utm_medium=twitter&taa=1&hl=en-US&gl=US&ceid=US:en
#
#    response_code                         domain  top_level_domain  \
# 0  200.0          http://www.hda-koeln.de/       hda-koeln.de
# 1  503.0          https://www.amazon.de/         amazon.de
# 2  200.0          https://www.facebook.com/      facebook.com
# 3  200.0          https://www.amateurseite.com/  amateurseite.com
# 4  200.0          https://news.google.com/       google.com
#
#    is_twitter_url is_media  is_processed  failed
# 0  False           False    True          False
# 1  False           False    True          False
# 2  False           False    True          False
# 3  False           False    True          False
# 4  False           False    True          False

# %% [markdown]
# ### Calendar Week 17 - Filtered

# %%
tweetsF17 = pd.read_sql_query("SELECT * FROM tweets_urls;", connF17 )

print("Number of Tweets: %s" %len(tweetsF17))
tweetsF17.head()
# Out:
# Number of Tweets: 2107279
#              tweet_id  \
# 0  988437985363406853
# 1  988437986797916160
# 2  988437989712957440
# 3  988437989704568832
# 4  988437990732128256
#
#                                                                                                                               short_url  \
# 0  https://www.facebook.com/nadjashah/posts/10215947002527277
# 1  https://www.facebook.com/StageSchoolHamburg/posts/1934173349947359
# 2  http://www.faz.net/aktuell/rhein-main/frankfurt/frankfurter-gutleutviertel-landgericht-erlaubt-drohende-zwangsraeumung-15556433.html
# 3  http://vera-lengsfeld.de/2018/04/22/buergerprotest-ueberall-wie-lange-wird-das-noch-verschwiegen/
# 4  https://ift.tt/2Jm4wnp
#
#                                                                                                                                                                                                                                                                                   resolved_url  \
# 0  https://www.facebook.com/nadjashah/posts/10215947002527277
# 1  https://www.facebook.com/StageSchoolHamburg/posts/1934173349947359
# 2  http://www.faz.net/aktuell/rhein-main/frankfurt/frankfurter-gutleutviertel-landgericht-erlaubt-drohende-zwangsraeumung-15556433.html
# 3  http://vera-lengsfeld.de/2018/04/22/buergerprotest-ueberall-wie-lange-wird-das-noch-verschwiegen/
# 4  https://news.google.com/?sa=t&fd=R&ct2=de&usg=AFQjCNFSz3Yf_fDFIytLtnNe8JNGM2BPZg&clid=c3a7d30bb8a4878e06b80cf16b898331&ei=O_rdWqDIHNCT3QHCyJDQAg&url=https://www.waz.de/kultur/fuer-silke-j-raebiger-ist-es-das-letzte-frauen-filmfestival-id214100661.html&taa=1&hl=en-US&gl=US&ceid=US:en
#
#    response_code                     domain   top_level_domain  \
# 0  200.0          https://www.facebook.com/  facebook.com
# 1  200.0          https://www.facebook.com/  facebook.com
# 2  200.0          http://www.faz.net/        faz.net
# 3  200.0          http://vera-lengsfeld.de/  vera-lengsfeld.de
# 4  200.0          https://news.google.com/   google.com
#
#    is_twitter_url is_media  is_processed  failed
# 0  False           False    True          False
# 1  False           False    True          False
# 2  False           False    True          False
# 3  False           False    True          False
# 4  False           False    True          False

# %% [markdown]
# ## Comparing Top Short URLs shared

# %% [markdown]
# ### Calendar Week 03 - Short URL - Sampled x Filtered

# %%
attribute = 'short_url'
column_name = 'short url'
    
df_sampled = generateRankingDataframe(tweetsS03[attribute].value_counts(), column_name)
df_filtered = generateRankingDataframe(tweetsF03[attribute].value_counts(), column_name)

df_sampled_comparison, df_filtered_comparison = generateComparisonDataframes(df_sampled, df_filtered, column_name, 50)

# %%
s = getPrettyComparisonDataframe(df_sampled_comparison, "CW 03 - Short URLs - Sampled Data (compared to Filtered Data)")
s
# Out:
# <style  type="text/css" >
#     #T_6aa30358_73e0_11e8_ac1d_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3 th {
#           text-align: center;
#     }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.6);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.6);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row3_col3 {
#             background-color:  #e55039;
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row5_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row7_col3 {
#             background-color:  #e55039;
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row8_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row9_col3 {
#             background-color:  #e55039;
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row10_col3 {
#             background-color:  #e55039;
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row11_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row12_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row13_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row14_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row15_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row16_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row17_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row19_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row20_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row21_col3 {
#             background-color:  #e55039;
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row22_col3 {
#             background-color:  #e55039;
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row24_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row25_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row26_col3 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row27_col3 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row28_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row29_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row30_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row31_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row32_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row33_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row34_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row35_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row36_col3 {
#             background-color:  rgba(184, 233, 148, 0.95);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row37_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row38_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row39_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row40_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row41_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row42_col3 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row43_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row44_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row45_col3 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row46_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row47_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row48_col3 {
#             background-color:  rgba(246, 185, 59, 0.95);
#         }    #T_6aa30358_73e0_11e8_ac1d_642737c470c3row49_col3 {
#             background-color:  rgba(246, 185, 59, 0.8);
#         }</style>
# <table id="T_6aa30358_73e0_11e8_ac1d_642737c470c3" ><caption>CW 03 - Short URLs - Sampled Data (compared to Filtered Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >short url</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6aa30358_73e0_11e8_ac1d_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_6aa30358_73e0_11e8_ac1d_642737c470c3row0_col0" class="data row0 col0" >http://youtu.be/Dw-2hh6G_D8?a</td>
#         <td id="T_6aa30358_73e0_11e8_ac1d_642737c470c3row0_col1" class="data row0 col1" >68</td>
#         <td id="T_6aa30358_73e0_11e8_ac1d_642737c470c3row0_col2" class="data row0 col2" >0.168571</td>
#         <td id="T_6aa30358_73e0_11e8_ac1d_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 0.275% / -0.106%)</td>
#     </tr>    <tr>
#         <th id="T_6aa30358_73e0_11e8_ac1d_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_6aa30358_73e0_11e8_ac1d_642737c470c3row1_col0" class="data row1 col0" >http://www.dwd.de</td>
#         <td id="T_6aa30358_73e0_11e8_ac1d_642737c470c3row1_col1" class="data row1 col1" >52</td>
#         <td id="T_6aa30358_73e0_11e8_ac1d_642737c470c3row1_col2" class="data row1 col2" >0.128908</td>
#         <td id="T_6aa30358

# %% [markdown]
# ## Comparing Top URLs shared

# %% [markdown]
# ### Calendar Week 03 - Sampled x Filtered

# %%
top_urls_S03 = tweetsS03['resolved_url'].value_counts()
top_urls_F03 = tweetsF03['resolved_url'].value_counts()

# %%
top_urls_S03_sum = top_urls_S03.sum()
top_urls_S03_rank = []
top_urls_S03_url = []
top_urls_S03_count = []
top_urls_S03_percentage = []

i = 1
for index, value in top_urls_S03.iteritems():
    top_urls_S03_rank.append(i)
    top_urls_S03_url.append(index)
    top_urls_S03_count.append(value)
    top_urls_S03_percentage.append((value/top_urls_S03_sum)*100)
    i += 1
    
data = {'rank': top_urls_S03_rank,'url':top_urls_S03_url, 'value': top_urls_S03_count, 'percentage': top_urls_S03_percentage}
df_top_urls_S03 = pd.DataFrame(data=data)
display(HTML(df_top_urls_S03[:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>url</th>
#       <th>value</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>https://twitter.com/account/suspended</td>
#       <td>183</td>
#       <td>0.453655</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>https://www.youtube.com/watch?v=Dw-2hh6G_D8&amp;feature=youtu.be&amp;a</td>
#       <td>68</td>
#       <td>0.168571</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>https://www.dwd.de/</td>
#       <td>52</td>
#       <td>0.128908</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>http://www.deutschlandfunk.de/dlf24-startseite.1441.de.html</td>
#       <td>50</td>
#       <td>0.123950</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>https://pi2.17bullets.com/tw_post.php?messageId=achievement&amp;values=&amp;locale=en_US</td>
#       <td>50</td>
#       <td>0.123950</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>http://www.blackpinkyg.com/</td>
#       <td>48</td>
#       <td>0.118992</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>http://www.messe.tv/</td>
#       <td>41</td>
#       <td>0.101639</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>http://www.the-sz.com/products/vbbinfo/?f=3</td>
#       <td>34</td>
#       <td>0.084286</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>http://der-x-code.com/</td>
#       <td>33</td>
#       <td>0.081807</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>https://farm5.staticflickr.com/4632/25898289958_0b5d369677_o.jpg</td>
#       <td>31</td>
#       <td>0.076849</td>
#     </tr>
#   </tbody>
# </table>

# %%
top_urls_F03_sum = top_urls_F03.sum()
top_urls_F03_rank = []
top_urls_F03_url = []
top_urls_F03_count = []
top_urls_F03_percentage = []

i = 1
for index, value in top_urls_F03.iteritems():
    top_urls_F03_rank.append(i)
    top_urls_F03_url.append(index)
    top_urls_F03_count.append(value)
    top_urls_F03_percentage.append((value/top_urls_F03_sum)*100)
    i += 1
    
data = {'rank': top_urls_F03_rank,'url':top_urls_F03_url, 'value': top_urls_F03_count, 'percentage': top_urls_F03_percentage}
df_top_urls_F03 = pd.DataFrame(data=data)
display(HTML(df_top_urls_F03[:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>url</th>
#       <th>value</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>https://twitter.com/account/suspended</td>
#       <td>8470</td>
#       <td>0.351230</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>https://www.youtube.com/watch?v=Dw-2hh6G_D8&amp;feature=youtu.be&amp;a</td>
#       <td>6623</td>
#       <td>0.274640</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>https://www.dwd.de/</td>
#       <td>6571</td>
#       <td>0.272483</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>https://pi2.17bullets.com/tw_post.php?messageId=achievement&amp;values=&amp;locale=en_US</td>
#       <td>5323</td>
#       <td>0.220732</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>http://www.messe.tv/</td>
#       <td>3471</td>
#       <td>0.143934</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>http://www.the-sz.com/products/vbbinfo/?f=3</td>
#       <td>2973</td>
#       <td>0.123283</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>https://www.emma-care.de/blog/teufelskralle-fuers-pferd-was-ist-das</td>
#       <td>2454</td>
#       <td>0.101761</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>https://sec.help.ch</td>
#       <td>2315</td>
#       <td>0.095997</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>https://www.facebook.com/CODECODE1111111111/</td>
#       <td>2229</td>
#       <td>0.092431</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>http://der-x-code.com/</td>
#       <td>2057</td>
#       <td>0.085299</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_list = []
for index, row in df_top_urls_S03.iterrows():
    if row['rank'] <= 50:
        compare_list.append(compareRows(row, df_top_urls_F03))
                    
                
data = {'rank': top_urls_S03_rank[:50],'url':top_urls_S03_url[:50], 'value': top_urls_S03_count[:50], 'percentage': top_urls_S03_percentage[:50],
        'difference (rank / percentage / diff)': compare_list}
df_top_urls_S03_F03_comparison = pd.DataFrame(data=data)
df_top_urls_S03_F03_comparison.set_index(keys='rank', inplace=True)
df_top_urls_S03_F03_comparison.style.applymap(colorComparisonField)

s = df_top_urls_S03_F03_comparison.style.applymap(colorComparisonField)
s.set_caption("Calendar Week 03: Sampled URLs x Filtered URLs ")
s.set_table_styles(table_styles)
# Out:
# <style  type="text/css" >
#     #T_f2e0c762_6a30_11e8_add4_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_f2e0c762_6a30_11e8_add4_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_f2e0c762_6a30_11e8_add4_642737c470c3 th {
#           text-align: center;
#     }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row3_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row5_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row7_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row8_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row9_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row10_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row11_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row12_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row13_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row14_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row15_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row16_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row17_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row19_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row20_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row21_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row22_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row24_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row25_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row26_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row27_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row28_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row29_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row30_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row31_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row32_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row33_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row34_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row35_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row36_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row37_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row38_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row39_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row40_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row41_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row42_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row43_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row44_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row45_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row46_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row47_col3 {
#             background-color:  #e55039;
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row48_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_f2e0c762_6a30_11e8_add4_642737c470c3row49_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }</style>
# <table id="T_f2e0c762_6a30_11e8_add4_642737c470c3" ><caption>Calendar Week 03: Sampled URLs x Filtered URLs </caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >url</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f2e0c762_6a30_11e8_add4_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_f2e0c762_6a30_11e8_add4_642737c470c3row0_col0" class="data row0 col0" >https://twitter.com/account/suspended</td>
#         <td id="T_f2e0c762_6a30_11e8_add4_642737c470c3row0_col1" class="data row0 col1" >183</td>
#         <td id="T_f2e0c762_6a30_11e8_add4_642737c470c3row0_col2" class="data row0 col2" >0.453655</td>
#         <td id="T_f2e0c762_6a30_11e8_add4_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 0.351% / 0.102%)</td>
#     </tr>    <tr>
#         <th id="T_f2e0c762_6a30_11e8_add4_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_f2e0c762_6a30_11e8_add4_642737c470c3row1_col0" class="data row1 col0" >https://www.youtube.com/watch?v=Dw-2hh6G_D8&feature=youtu.be&a</td>
#         <td id="T_f2e0c762_6a30_11e8_add4_642737c470c3row1_col1" class="data row1 col1" >68</td>
#         <td id="T_f2e0c762_6a30_11e8_add4_642737c470c3row1_col2" class="data row1 col2" >0.168571</td>
#         <td id="T_f2e0c762_6a30_11e8_add4_642737c470c3row1_col3" class="data row1 col3" > = <br>(2. / 0.27

# %%
compare_list = []
for index, row in df_top_urls_F03.iterrows():
    if row['rank'] <= 50:
        compare_list.append(compareRows(row, df_top_urls_S03))
                    
                
data = {'rank': top_urls_F03_rank[:50],'url':top_urls_F03_url[:50], 'value': top_urls_F03_count[:50], 'percentage': top_urls_F03_percentage[:50],
        'difference (rank / percentage / diff)': compare_list}
df_top_urls_F03_S03_comparison = pd.DataFrame(data=data)
df_top_urls_F03_S03_comparison.set_index(keys='rank', inplace=True)
df_top_urls_F03_S03_comparison.style.applymap(colorComparisonField)

s = df_top_urls_F03_S03_comparison.style.applymap(colorComparisonField)
s.set_caption("Calendar Week 03: Filtered URLs x Sampled URLs ")
s.set_table_styles(table_styles)
# Out:
# <style  type="text/css" >
#     #T_44cbdd12_6a31_11e8_9570_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_44cbdd12_6a31_11e8_9570_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_44cbdd12_6a31_11e8_9570_642737c470c3 th {
#           text-align: center;
#     }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row3_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row5_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row7_col3 {
#             background-color:  #e55039;
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row8_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row9_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row10_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row11_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row12_col3 {
#             background-color:  #e55039;
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row13_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row14_col3 {
#             background-color:  #e55039;
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row15_col3 {
#             background-color:  #e55039;
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row16_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row17_col3 {
#             background-color:  #e55039;
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row19_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row20_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row21_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row22_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row24_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row25_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row26_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row27_col3 {
#             background-color:  #e55039;
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row28_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row29_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row30_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row31_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row32_col3 {
#             background-color:  #e55039;
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row33_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row34_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row35_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row36_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row37_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row38_col3 {
#             background-color:  #e55039;
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row39_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row40_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row41_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row42_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row43_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row44_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row45_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row46_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row47_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row48_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_44cbdd12_6a31_11e8_9570_642737c470c3row49_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }</style>
# <table id="T_44cbdd12_6a31_11e8_9570_642737c470c3" ><caption>Calendar Week 03: Filtered URLs x Sampled URLs </caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >url</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_44cbdd12_6a31_11e8_9570_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_44cbdd12_6a31_11e8_9570_642737c470c3row0_col0" class="data row0 col0" >https://twitter.com/account/suspended</td>
#         <td id="T_44cbdd12_6a31_11e8_9570_642737c470c3row0_col1" class="data row0 col1" >8470</td>
#         <td id="T_44cbdd12_6a31_11e8_9570_642737c470c3row0_col2" class="data row0 col2" >0.35123</td>
#         <td id="T_44cbdd12_6a31_11e8_9570_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 0.454% / -0.102%)</td>
#     </tr>    <tr>
#         <th id="T_44cbdd12_6a31_11e8_9570_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_44cbdd12_6a31_11e8_9570_642737c470c3row1_col0" class="data row1 col0" >https://www.youtube.com/watch?v=Dw-2hh6G_D8&feature=youtu.be&a</td>
#         <td id="T_44cbdd12_6a31_11e8_9570_642737c470c3row1_col1" class="data row1 col1" >6623</td>
#         <td id="T_44cbdd12_6a31_11e8_9570_642737c470c3row1_col2" class="data row1 col2" >0.27464</td>
#         <td id="T_44cbdd

# %% [markdown]
# ### Calendar Week 17 - Sampled x Filtered

# %%
top_urls_S03 = tweetsS17['resolved_url'].value_counts()
top_urls_F03 = tweetsF17['resolved_url'].value_counts()

# %%
top_urls_S03_sum = top_urls_S03.sum()
top_urls_S03_rank = []
top_urls_S03_url = []
top_urls_S03_count = []
top_urls_S03_percentage = []

i = 1
for index, value in top_urls_S03.iteritems():
    top_urls_S03_rank.append(i)
    top_urls_S03_url.append(index)
    top_urls_S03_count.append(value)
    top_urls_S03_percentage.append((value/top_urls_S03_sum)*100)
    i += 1
    
data = {'rank': top_urls_S03_rank,'url':top_urls_S03_url, 'value': top_urls_S03_count, 'percentage': top_urls_S03_percentage}
df_top_urls_S03 = pd.DataFrame(data=data)
display(HTML(df_top_urls_S03[:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>url</th>
#       <th>value</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>https://www.dwd.de/</td>
#       <td>60</td>
#       <td>0.168128</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>https://www.ffd365.de</td>
#       <td>57</td>
#       <td>0.159722</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>https://pi2.17bullets.com/tw_post.php?messageId=achievement&amp;values=&amp;locale=en_US</td>
#       <td>56</td>
#       <td>0.156920</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>http://susanne-ulrike-maria-albrecht.over-blog.de/</td>
#       <td>53</td>
#       <td>0.148513</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>https://twitter.com/buzzfeedfrance/status/988362712513171456</td>
#       <td>47</td>
#       <td>0.131701</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>https://twitter.com/Markus_Soeder/status/988768341820170240</td>
#       <td>43</td>
#       <td>0.120492</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>https://www.youtube.com/watch?v=F-eMt3SrfFU&amp;feature=youtu.be</td>
#       <td>37</td>
#       <td>0.103679</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>https://www.youtube.com/watch?v=tBWJ3bvJuT0&amp;feature=youtu.be</td>
#       <td>36</td>
#       <td>0.100877</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>https://www.linkedin.com/</td>
#       <td>36</td>
#       <td>0.100877</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>http://tv.naver.com/v/3097997</td>
#       <td>36</td>
#       <td>0.100877</td>
#     </tr>
#   </tbody>
# </table>

# %%
top_urls_F03_sum = top_urls_F03.sum()
top_urls_F03_rank = []
top_urls_F03_url = []
top_urls_F03_count = []
top_urls_F03_percentage = []

i = 1
for index, value in top_urls_F03.iteritems():
    top_urls_F03_rank.append(i)
    top_urls_F03_url.append(index)
    top_urls_F03_count.append(value)
    top_urls_F03_percentage.append((value/top_urls_F03_sum)*100)
    i += 1
    
data = {'rank': top_urls_F03_rank,'url':top_urls_F03_url, 'value': top_urls_F03_count, 'percentage': top_urls_F03_percentage}
df_top_urls_F03 = pd.DataFrame(data=data)
display(HTML(df_top_urls_F03[:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>url</th>
#       <th>value</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>https://sec.help.ch</td>
#       <td>5615</td>
#       <td>0.266457</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>https://pi2.17bullets.com/tw_post.php?messageId=achievement&amp;values=&amp;locale=en_US</td>
#       <td>5088</td>
#       <td>0.241449</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>https://www.ffd365.de</td>
#       <td>4791</td>
#       <td>0.227355</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>https://www.dwd.de/</td>
#       <td>4566</td>
#       <td>0.216678</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>http://www.gooni168.tv/sellpanties/item/haushalts-sklave-in/</td>
#       <td>3474</td>
#       <td>0.164857</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>https://www.linkedin.com/</td>
#       <td>2935</td>
#       <td>0.139279</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>http://www.the-sz.com/products/vbbinfo/?f=3</td>
#       <td>2739</td>
#       <td>0.129978</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>https://www.miet-check.de/</td>
#       <td>2420</td>
#       <td>0.114840</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>https://mobile.twitter.com/Markus_Soeder/status/988768341820170240</td>
#       <td>2282</td>
#       <td>0.108291</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>https://www.radionomy.com/en/radio/erika1</td>
#       <td>2186</td>
#       <td>0.103736</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_list = []
for index, row in df_top_urls_S03.iterrows():
    if row['rank'] <= 50:
        compare_list.append(compareRows(row, df_top_urls_F03))
                    
                
data = {'rank': top_urls_S03_rank[:50],'url':top_urls_S03_url[:50], 'value': top_urls_S03_count[:50], 'percentage': top_urls_S03_percentage[:50],
        'difference (rank / percentage / diff)': compare_list}
df_top_urls_S03_F03_comparison = pd.DataFrame(data=data)
df_top_urls_S03_F03_comparison.set_index(keys='rank', inplace=True)
df_top_urls_S03_F03_comparison.style.applymap(colorComparisonField)

s = df_top_urls_S03_F03_comparison.style.applymap(colorComparisonField)
s.set_caption("Calendar Week 17: Sampled URLs x Filtered URLs ")
s.set_table_styles(table_styles)
# Out:
# <style  type="text/css" >
#     #T_752c6c86_6a31_11e8_800e_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_752c6c86_6a31_11e8_800e_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_752c6c86_6a31_11e8_800e_642737c470c3 th {
#           text-align: center;
#     }    #T_752c6c86_6a31_11e8_800e_642737c470c3row0_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row1_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row2_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row3_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row5_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row7_col3 {
#             background-color:  #e55039;
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row8_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row9_col3 {
#             background-color:  #e55039;
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row10_col3 {
#             background-color:  #e55039;
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row11_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row12_col3 {
#             background-color:  #e55039;
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row13_col3 {
#             background-color:  #e55039;
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row14_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row15_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row16_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row17_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row19_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row20_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row21_col3 {
#             background-color:  #e55039;
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row22_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row24_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row25_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row26_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row27_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row28_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row29_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row30_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row31_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row32_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row33_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row34_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row35_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row36_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row37_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row38_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row39_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row40_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row41_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row42_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row43_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row44_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row45_col3 {
#             background-color:  #e55039;
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row46_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row47_col3 {
#             background-color:  #e55039;
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row48_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_752c6c86_6a31_11e8_800e_642737c470c3row49_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }</style>
# <table id="T_752c6c86_6a31_11e8_800e_642737c470c3" ><caption>Calendar Week 17: Sampled URLs x Filtered URLs </caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >url</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_752c6c86_6a31_11e8_800e_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_752c6c86_6a31_11e8_800e_642737c470c3row0_col0" class="data row0 col0" >https://www.dwd.de/</td>
#         <td id="T_752c6c86_6a31_11e8_800e_642737c470c3row0_col1" class="data row0 col1" >60</td>
#         <td id="T_752c6c86_6a31_11e8_800e_642737c470c3row0_col2" class="data row0 col2" >0.168128</td>
#         <td id="T_752c6c86_6a31_11e8_800e_642737c470c3row0_col3" class="data row0 col3" > v <br>(4. / 0.217% / -0.049%)</td>
#     </tr>    <tr>
#         <th id="T_752c6c86_6a31_11e8_800e_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_752c6c86_6a31_11e8_800e_642737c470c3row1_col0" class="data row1 col0" >https://www.ffd365.de</td>
#         <td id="T_752c6c86_6a31_11e8_800e_642737c470c3row1_col1" class="data row1 col1" >57</td>
#         <td id="T_752c6c86_6a31_11e8_800e_642737c470c3row1_col2" class="data row1 col2" >0.159722</td>
#         <td id="T_752c6c86_6a31_11e8_800e_642737c470c3row1_col3" class="d

# %%
compare_list = []
for index, row in df_top_urls_F03.iterrows():
    if row['rank'] <= 50:
        compare_list.append(compareRows(row, df_top_urls_S03))
                    
                
data = {'rank': top_urls_F03_rank[:50],'url':top_urls_F03_url[:50], 'value': top_urls_F03_count[:50], 'percentage': top_urls_F03_percentage[:50],
        'difference (rank / percentage / diff)': compare_list}
df_top_urls_F03_S03_comparison = pd.DataFrame(data=data)
df_top_urls_F03_S03_comparison.set_index(keys='rank', inplace=True)
df_top_urls_F03_S03_comparison.style.applymap(colorComparisonField)

s = df_top_urls_F03_S03_comparison.style.applymap(colorComparisonField)
s.set_caption("Calendar Week 17: Filtered URLs x Sampled URLs ")
s.set_table_styles(table_styles)
# Out:
# <style  type="text/css" >
#     #T_b73c829a_6a31_11e8_9a38_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_b73c829a_6a31_11e8_9a38_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_b73c829a_6a31_11e8_9a38_642737c470c3 th {
#           text-align: center;
#     }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row0_col3 {
#             background-color:  #e55039;
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row1_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row2_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row3_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row5_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row7_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row8_col3 {
#             background-color:  #e55039;
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row9_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row10_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row11_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row12_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row13_col3 {
#             background-color:  #e55039;
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row14_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row15_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row16_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row17_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row19_col3 {
#             background-color:  #e55039;
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row20_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row21_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row22_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row24_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row25_col3 {
#             background-color:  #e55039;
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row26_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row27_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row28_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row29_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row30_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row31_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row32_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row33_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row34_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row35_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row36_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row37_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row38_col3 {
#             background-color:  #e55039;
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row39_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row40_col3 {
#             background-color:  #e55039;
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row41_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row42_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row43_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row44_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row45_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row46_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row47_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row48_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_b73c829a_6a31_11e8_9a38_642737c470c3row49_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }</style>
# <table id="T_b73c829a_6a31_11e8_9a38_642737c470c3" ><caption>Calendar Week 17: Filtered URLs x Sampled URLs </caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >url</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b73c829a_6a31_11e8_9a38_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_b73c829a_6a31_11e8_9a38_642737c470c3row0_col0" class="data row0 col0" >https://sec.help.ch</td>
#         <td id="T_b73c829a_6a31_11e8_9a38_642737c470c3row0_col1" class="data row0 col1" >5615</td>
#         <td id="T_b73c829a_6a31_11e8_9a38_642737c470c3row0_col2" class="data row0 col2" >0.266457</td>
#         <td id="T_b73c829a_6a31_11e8_9a38_642737c470c3row0_col3" class="data row0 col3" > - </td>
#     </tr>    <tr>
#         <th id="T_b73c829a_6a31_11e8_9a38_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_b73c829a_6a31_11e8_9a38_642737c470c3row1_col0" class="data row1 col0" >https://pi2.17bullets.com/tw_post.php?messageId=achievement&values=&locale=en_US</td>
#         <td id="T_b73c829a_6a31_11e8_9a38_642737c470c3row1_col1" class="data row1 col1" >5088</td>
#         <td id="T_b73c829a_6a31_11e8_9a38_642737c470c3row1_col2" class="data row1 col2" >0.241449</td>
#         <td id="T_b73

# %% [markdown]
# ## Comparing Top Level Domains shared

# %% [markdown]
# ### Calendar Week 03: Top Level Domains

# %%
top_urls_S03 = tweetsS03['top_level_domain'].value_counts()
top_urls_F03 = tweetsF03['top_level_domain'].value_counts()

# %%
top_urls_S03_sum = top_urls_S03.sum()
top_urls_S03_rank = []
top_urls_S03_url = []
top_urls_S03_count = []
top_urls_S03_percentage = []

i = 1
for index, value in top_urls_S03.iteritems():
    top_urls_S03_rank.append(i)
    top_urls_S03_url.append(index)
    top_urls_S03_count.append(value)
    top_urls_S03_percentage.append((value/top_urls_S03_sum)*100)
    i += 1
    
data = {'rank': top_urls_S03_rank,'url':top_urls_S03_url, 'value': top_urls_S03_count, 'percentage': top_urls_S03_percentage}
df_top_urls_S03 = pd.DataFrame(data=data)
display(HTML(df_top_urls_S03[:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>url</th>
#       <th>value</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>twitter.com</td>
#       <td>6362</td>
#       <td>15.780727</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>youtube.com</td>
#       <td>3262</td>
#       <td>8.091281</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>facebook.com</td>
#       <td>1000</td>
#       <td>2.480466</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>instagram.com</td>
#       <td>727</td>
#       <td>1.803299</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>welt.de</td>
#       <td>688</td>
#       <td>1.706561</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>spiegel.de</td>
#       <td>470</td>
#       <td>1.165819</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>focus.de</td>
#       <td>377</td>
#       <td>0.935136</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>amazon.de</td>
#       <td>372</td>
#       <td>0.922733</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>google.com</td>
#       <td>338</td>
#       <td>0.838398</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>bild.de</td>
#       <td>336</td>
#       <td>0.833437</td>
#     </tr>
#   </tbody>
# </table>

# %%
top_urls_F03_sum = top_urls_F03.sum()
top_urls_F03_rank = []
top_urls_F03_url = []
top_urls_F03_count = []
top_urls_F03_percentage = []

i = 1
for index, value in top_urls_F03.iteritems():
    top_urls_F03_rank.append(i)
    top_urls_F03_url.append(index)
    top_urls_F03_count.append(value)
    top_urls_F03_percentage.append((value/top_urls_F03_sum)*100)
    i += 1
    
data = {'rank': top_urls_F03_rank,'url':top_urls_F03_url, 'value': top_urls_F03_count, 'percentage': top_urls_F03_percentage}
df_top_urls_F03 = pd.DataFrame(data=data)
display(HTML(df_top_urls_F03[:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>url</th>
#       <th>value</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>twitter.com</td>
#       <td>348905</td>
#       <td>14.474755</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>youtube.com</td>
#       <td>233498</td>
#       <td>9.686953</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>facebook.com</td>
#       <td>65092</td>
#       <td>2.700422</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>instagram.com</td>
#       <td>39391</td>
#       <td>1.634184</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>google.com</td>
#       <td>36688</td>
#       <td>1.522047</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>welt.de</td>
#       <td>31993</td>
#       <td>1.327269</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>spiegel.de</td>
#       <td>26804</td>
#       <td>1.111997</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>amazon.de</td>
#       <td>22972</td>
#       <td>0.953022</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>focus.de</td>
#       <td>22507</td>
#       <td>0.933731</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>twitch.tv</td>
#       <td>20801</td>
#       <td>0.862955</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_list = []
for index, row in df_top_urls_S03.iterrows():
    if row['rank'] <= 50:
        compare_list.append(compareRows(row, df_top_urls_F03))
                    
                
data = {'rank': top_urls_S03_rank[:50],'url':top_urls_S03_url[:50], 'value': top_urls_S03_count[:50], 'percentage': top_urls_S03_percentage[:50],
        'difference (rank / percentage / diff)': compare_list}
df_top_urls_S03_F03_comparison = pd.DataFrame(data=data)
df_top_urls_S03_F03_comparison.set_index(keys='rank', inplace=True)
df_top_urls_S03_F03_comparison.style.applymap(colorComparisonField)

s = df_top_urls_S03_F03_comparison.style.applymap(colorComparisonField)
s.set_caption("Calendar Week 03: Sampled TLDs x Filtered TLDs ")
s.set_table_styles(table_styles)
# Out:
# <style  type="text/css" >
#     #T_bc6314da_6a31_11e8_a860_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_bc6314da_6a31_11e8_a860_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_bc6314da_6a31_11e8_a860_642737c470c3 th {
#           text-align: center;
#     }    #T_bc6314da_6a31_11e8_a860_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.2);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.2);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row5_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row8_col3 {
#             background-color:  rgba(246, 185, 59, 0.25);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row9_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row10_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row11_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row12_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row13_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row14_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row15_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row16_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row17_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row19_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row20_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row21_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row22_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row24_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row25_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row26_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row27_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row28_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row29_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row30_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row31_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row32_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row33_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row34_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row35_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row36_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row37_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row38_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row39_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row40_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row41_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row42_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row43_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row44_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row45_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row46_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row47_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row48_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_bc6314da_6a31_11e8_a860_642737c470c3row49_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }</style>
# <table id="T_bc6314da_6a31_11e8_a860_642737c470c3" ><caption>Calendar Week 03: Sampled TLDs x Filtered TLDs </caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >url</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_bc6314da_6a31_11e8_a860_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_bc6314da_6a31_11e8_a860_642737c470c3row0_col0" class="data row0 col0" >twitter.com</td>
#         <td id="T_bc6314da_6a31_11e8_a860_642737c470c3row0_col1" class="data row0 col1" >6362</td>
#         <td id="T_bc6314da_6a31_11e8_a860_642737c470c3row0_col2" class="data row0 col2" >15.7807</td>
#         <td id="T_bc6314da_6a31_11e8_a860_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 14.475% / 1.306%)</td>
#     </tr>    <tr>
#         <th id="T_bc6314da_6a31_11e8_a860_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_bc6314da_6a31_11e8_a860_642737c470c3row1_col0" class="data row1 col0" >youtube.com</td>
#         <td id="T_bc6314da_6a31_11e8_a860_642737c470c3row1_col1" class="data row1 col1" >3262</td>
#         <td id="T_bc6314da_6a31_11e8_a860_642737c470

# %%
compare_list = []
for index, row in df_top_urls_F03.iterrows():
    if row['rank'] <= 50:
        compare_list.append(compareRows(row, df_top_urls_S03))
                    
                
data = {'rank': top_urls_F03_rank[:50],'url':top_urls_F03_url[:50], 'value': top_urls_F03_count[:50], 'percentage': top_urls_F03_percentage[:50],
        'difference (rank / percentage)': compare_list}
df_top_urls_F03_S03_comparison = pd.DataFrame(data=data)
df_top_urls_F03_S03_comparison.set_index(keys='rank', inplace=True)
df_top_urls_F03_S03_comparison.style.applymap(colorComparisonField)

s = df_top_urls_F03_S03_comparison.style.applymap(colorComparisonField)
s.set_caption("Calendar Week 03: Filtered TLDs x Sampled TLDs ")
s.set_table_styles(table_styles)
# Out:
# <style  type="text/css" >
#     #T_c0a5eb34_6a31_11e8_be73_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3 th {
#           text-align: center;
#     }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.2);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.2);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.25);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row5_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row8_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row9_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row10_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row11_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row12_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row13_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row14_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row15_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row16_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row17_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row19_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row20_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row21_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row22_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row24_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row25_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row26_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row27_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row28_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row29_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row30_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row31_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row32_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row33_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row34_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row35_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row36_col3 {
#             background-color:  rgba(246, 185, 59, 1);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row37_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row38_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row39_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row40_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row41_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row42_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row43_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row44_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row45_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row46_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row47_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row48_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c0a5eb34_6a31_11e8_be73_642737c470c3row49_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }</style>
# <table id="T_c0a5eb34_6a31_11e8_be73_642737c470c3" ><caption>Calendar Week 03: Filtered TLDs x Sampled TLDs </caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >url</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c0a5eb34_6a31_11e8_be73_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_c0a5eb34_6a31_11e8_be73_642737c470c3row0_col0" class="data row0 col0" >twitter.com</td>
#         <td id="T_c0a5eb34_6a31_11e8_be73_642737c470c3row0_col1" class="data row0 col1" >348905</td>
#         <td id="T_c0a5eb34_6a31_11e8_be73_642737c470c3row0_col2" class="data row0 col2" >14.4748</td>
#         <td id="T_c0a5eb34_6a31_11e8_be73_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 15.781% / -1.306%)</td>
#     </tr>    <tr>
#         <th id="T_c0a5eb34_6a31_11e8_be73_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_c0a5eb34_6a31_11e8_be73_642737c470c3row1_col0" class="data row1 col0" >youtube.com</td>
#         <td id="T_c0a5eb34_6a31_11e8_be73_642737c470c3row1_col1" class="data row1 col1" >233498</td>
#         <td id="T_c0a5eb34_6a31_11e8_be73_642737c470c3r

# %% [markdown]
# ### Calendar Week 17: Top Level Domains

# %%
top_urls_S03 = tweetsS17['top_level_domain'].value_counts()
top_urls_F03 = tweetsF17['top_level_domain'].value_counts()

# %%
top_urls_S03_sum = top_urls_S03.sum()
top_urls_S03_rank = []
top_urls_S03_url = []
top_urls_S03_count = []
top_urls_S03_percentage = []

i = 1
for index, value in top_urls_S03.iteritems():
    top_urls_S03_rank.append(i)
    top_urls_S03_url.append(index)
    top_urls_S03_count.append(value)
    top_urls_S03_percentage.append((value/top_urls_S03_sum)*100)
    i += 1
    
data = {'rank': top_urls_S03_rank,'url':top_urls_S03_url, 'value': top_urls_S03_count, 'percentage': top_urls_S03_percentage}
df_top_urls_S03 = pd.DataFrame(data=data)
display(HTML(df_top_urls_S03[:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>url</th>
#       <th>value</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>twitter.com</td>
#       <td>6192</td>
#       <td>17.357179</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>youtube.com</td>
#       <td>2961</td>
#       <td>8.300163</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>facebook.com</td>
#       <td>884</td>
#       <td>2.477995</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>instagram.com</td>
#       <td>805</td>
#       <td>2.256545</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>welt.de</td>
#       <td>534</td>
#       <td>1.496888</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>spiegel.de</td>
#       <td>430</td>
#       <td>1.205360</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>amazon.de</td>
#       <td>334</td>
#       <td>0.936256</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>twitch.tv</td>
#       <td>318</td>
#       <td>0.891406</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>focus.de</td>
#       <td>291</td>
#       <td>0.815720</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>wordpress.com</td>
#       <td>261</td>
#       <td>0.731625</td>
#     </tr>
#   </tbody>
# </table>

# %%
top_urls_F03_sum = top_urls_F03.sum()
top_urls_F03_rank = []
top_urls_F03_url = []
top_urls_F03_count = []
top_urls_F03_percentage = []

i = 1
for index, value in top_urls_F03.iteritems():
    top_urls_F03_rank.append(i)
    top_urls_F03_url.append(index)
    top_urls_F03_count.append(value)
    top_urls_F03_percentage.append((value/top_urls_F03_sum)*100)
    i += 1
    
data = {'rank': top_urls_F03_rank,'url':top_urls_F03_url, 'value': top_urls_F03_count, 'percentage': top_urls_F03_percentage}
df_top_urls_F03 = pd.DataFrame(data=data)
display(HTML(df_top_urls_F03[:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>url</th>
#       <th>value</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>twitter.com</td>
#       <td>339597</td>
#       <td>16.119779</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>youtube.com</td>
#       <td>205700</td>
#       <td>9.764040</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>facebook.com</td>
#       <td>57313</td>
#       <td>2.720498</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>instagram.com</td>
#       <td>41411</td>
#       <td>1.965672</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>amazon.de</td>
#       <td>26290</td>
#       <td>1.247917</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>spiegel.de</td>
#       <td>24238</td>
#       <td>1.150514</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>welt.de</td>
#       <td>22878</td>
#       <td>1.085959</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>twitch.tv</td>
#       <td>21044</td>
#       <td>0.998904</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>google.com</td>
#       <td>19676</td>
#       <td>0.933968</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>focus.de</td>
#       <td>15926</td>
#       <td>0.755965</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_list = []
for index, row in df_top_urls_S03.iterrows():
    if row['rank'] <= 50:
        compare_list.append(compareRows(row, df_top_urls_F03))
                    
                
data = {'rank': top_urls_S03_rank[:50],'url':top_urls_S03_url[:50], 'value': top_urls_S03_count[:50], 'percentage': top_urls_S03_percentage[:50],
        'difference (rank / percentage)': compare_list}
df_top_urls_S03_F03_comparison = pd.DataFrame(data=data)
df_top_urls_S03_F03_comparison.set_index(keys='rank', inplace=True)
df_top_urls_S03_F03_comparison.style.applymap(colorComparisonField)

s = df_top_urls_S03_F03_comparison.style.applymap(colorComparisonField)
s.set_caption("Calendar Week 17: Sampled TLDs x Filtered TLDs ")
s.set_table_styles(table_styles)
# Out:
# <style  type="text/css" >
#     #T_c3a87510_6a31_11e8_8402_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_c3a87510_6a31_11e8_8402_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_c3a87510_6a31_11e8_8402_642737c470c3 th {
#           text-align: center;
#     }    #T_c3a87510_6a31_11e8_8402_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.2);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.2);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row5_col3 {
#             background-color:  rgba(184, 233, 148, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row8_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row9_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row10_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row11_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row12_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row13_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row14_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row15_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row16_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row17_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row19_col3 {
#             background-color:  rgba(184, 233, 148, 0.85);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row20_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row21_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row22_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row24_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row25_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row26_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row27_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row28_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row29_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row30_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row31_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row32_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row33_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row34_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row35_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row36_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row37_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row38_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row39_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row40_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row41_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row42_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row43_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row44_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row45_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row46_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row47_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row48_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c3a87510_6a31_11e8_8402_642737c470c3row49_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }</style>
# <table id="T_c3a87510_6a31_11e8_8402_642737c470c3" ><caption>Calendar Week 17: Sampled TLDs x Filtered TLDs </caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >url</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c3a87510_6a31_11e8_8402_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_c3a87510_6a31_11e8_8402_642737c470c3row0_col0" class="data row0 col0" >twitter.com</td>
#         <td id="T_c3a87510_6a31_11e8_8402_642737c470c3row0_col1" class="data row0 col1" >6192</td>
#         <td id="T_c3a87510_6a31_11e8_8402_642737c470c3row0_col2" class="data row0 col2" >17.3572</td>
#         <td id="T_c3a87510_6a31_11e8_8402_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 16.120% / 1.237%)</td>
#     </tr>    <tr>
#         <th id="T_c3a87510_6a31_11e8_8402_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_c3a87510_6a31_11e8_8402_642737c470c3row1_col0" class="data row1 col0" >youtube.com</td>
#         <td id="T_c3a87510_6a31_11e8_8402_642737c470c3row1_col1" class="data row1 col1" >2961</td>
#         <td id="T_c3a87510_6a31_11e8_8402_642737c4

# %%
compare_list = []
for index, row in df_top_urls_F03.iterrows():
    if row['rank'] <= 50:
        compare_list.append(compareRows(row, df_top_urls_S03))
                    
                
data = {'rank': top_urls_F03_rank[:50],'url':top_urls_F03_url[:50], 'value': top_urls_F03_count[:50], 'percentage': top_urls_F03_percentage[:50],
        'difference (rank / percentage / diff)': compare_list}
df_top_urls_F03_S03_comparison = pd.DataFrame(data=data)
df_top_urls_F03_S03_comparison.set_index(keys='rank', inplace=True)
df_top_urls_F03_S03_comparison.style.applymap(colorComparisonField)

s = df_top_urls_F03_S03_comparison.style.applymap(colorComparisonField)
s.set_caption("Calendar Week 17: Filtered TLDs x Sampled TLDs ")
s.set_table_styles(table_styles)
# Out:
# <style  type="text/css" >
#     #T_c8cab566_6a31_11e8_8909_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_c8cab566_6a31_11e8_8909_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_c8cab566_6a31_11e8_8909_642737c470c3 th {
#           text-align: center;
#     }    #T_c8cab566_6a31_11e8_8909_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.2);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.2);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row4_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row5_col3 {
#             background-color:  rgba(184, 233, 148, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row6_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row8_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row9_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row10_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row11_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row12_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row13_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row14_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row15_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row16_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row17_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row18_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row19_col3 {
#             background-color:  rgba(184, 233, 148, 0.85);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row20_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row21_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row22_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row23_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row24_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row25_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row26_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row27_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row28_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row29_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row30_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row31_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row32_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row33_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row34_col3 {
#             background-color:  rgba(246, 185, 59, 0.85);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row35_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row36_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row37_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row38_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row39_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row40_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row41_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row42_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row43_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row44_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row45_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row46_col3 {
#             background-color:  rgba(246, 185, 59, 0.4);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row47_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row48_col3 {
#             background-color:  rgba(246, 185, 59, 0.55);
#         }    #T_c8cab566_6a31_11e8_8909_642737c470c3row49_col3 {
#             background-color:  rgba(246, 185, 59, 0.7);
#         }</style>
# <table id="T_c8cab566_6a31_11e8_8909_642737c470c3" ><caption>Calendar Week 17: Filtered TLDs x Sampled TLDs </caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >url</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c8cab566_6a31_11e8_8909_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_c8cab566_6a31_11e8_8909_642737c470c3row0_col0" class="data row0 col0" >twitter.com</td>
#         <td id="T_c8cab566_6a31_11e8_8909_642737c470c3row0_col1" class="data row0 col1" >339597</td>
#         <td id="T_c8cab566_6a31_11e8_8909_642737c470c3row0_col2" class="data row0 col2" >16.1198</td>
#         <td id="T_c8cab566_6a31_11e8_8909_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 17.357% / -1.237%)</td>
#     </tr>    <tr>
#         <th id="T_c8cab566_6a31_11e8_8909_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_c8cab566_6a31_11e8_8909_642737c470c3row1_col0" class="data row1 col0" >youtube.com</td>
#         <td id="T_c8cab566_6a31_11e8_8909_642737c470c3row1_col1" class="data row1 col1" >205700</td>
#         <td id="T_c8cab566_6a31_11e8_890
