# %% [markdown]
# # Top URLs shared (Sampled Streaming Data)

# %%
import psycopg2
import pandas as pd
import config
from matplotlib import pylab as plt
import seaborn as sns
import numpy as np

color_palette = sns.color_palette(palette='muted', n_colors=None, desat=.75)
sns.set(context='notebook', palette=color_palette, style='whitegrid', font='sans-serif', font_scale=1.5, color_codes=False, rc=None)

# %matplotlib inline

directory = "url_top_lists/"
stream = "sampled"

# %%
conn = None
try:
    # read connection parameters
    params = config.cfgAzureS17()
    
    paramsS03 = config.cfgAzureS03()

    # connect to the PostgreSQL server
    print('Connecting to the PostgreSQL database...')
    connS17 = psycopg2.connect(**params)
    
    connS03 = psycopg2.connect(**paramsS03)

    # create a cursor
    curS17 = connS17.cursor()
    curS03 = connS03.cursor()

    # execute a statement
    print('PostgreSQL database version:')
    curS17.execute('SELECT version()')
    curS03.execute('SELECT version()')
    # display the PostgreSQL database server version
    db_version_curS17 = curS17.fetchone()
    db_version_curS03 = curS03.fetchone()
    print(db_version_curS17)
    print(db_version_curS03)

    # close the communication with the PostgreSQL
    curS17.close()
    curS03.close()

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)

# %%
#tweets03 = pd.read_sql_query("SELECT * FROM tweets_info;", conn, parse_dates=['created_at'] )
#tweets03['created_at'] = tweets['created_at'].dt.tz_localize("UTC").dt.tz_convert("Europe/Berlin")
tweets03 = pd.read_sql_query("SELECT * FROM tweets_urls;", connS03 )

print("Number of Tweets: %s" %len(tweets03))
tweets03.head()
# Out:
# Number of Tweets: 40339
#              tweet_id                                          short_url  \
# 0  953585808631631872  https://twitter.com/Zockerli/status/9533707770...
# 1  952676758066728960                              http://bit.ly/2D8B0mK
# 2  952676816820621314                      http://youtu.be/xo1eqTeG5DY?a
# 3  952676760390336512                        http://on.wusa9.com/2D0gSit
# 4  952677085230915589  https://www.refcrime.info/de/Crime/Show/74471?...
#
#                                         resolved_url  response_code  \
# 0  https://twitter.com/Zockerli/status/9533707770...          200.0
# 1  http://dalyaakota.ru/mghnfgnrtgfgnfgbfbrgdfnfg...            NaN
# 2  https://www.youtube.com/watch?v=xo1eqTeG5DY&fe...          200.0
# 3  https://www.wusa9.com/article/news/nation-worl...          200.0
# 4  https://www.refcrime.info/de/Crime/Show/74471?...          200.0
#
#                        domain top_level_domain  is_twitter_url is_media  \
# 0        https://twitter.com/      twitter.com            True    False
# 1       http://dalyaakota.ru/    dalyaakota.ru           False     None
# 2    https://www.youtube.com/      youtube.com           False    False
# 3      https://www.wusa9.com/        wusa9.com           False    False
# 4  https://www.refcrime.info/    refcrime.info           False    False
#
#    is_processed  failed
# 0          True   False
# 1          True    True
# 2          True   False
# 3          True   False
# 4          True   False

# %%
#tweets03 = pd.read_sql_query("SELECT * FROM tweets_info;", conn, parse_dates=['created_at'] )
#tweets03['created_at'] = tweets['created_at'].dt.tz_localize("UTC").dt.tz_convert("Europe/Berlin")
tweets17 = pd.read_sql_query("SELECT * FROM tweets_urls;", connS17 )

print("Number of Tweets: %s" %len(tweets17))
tweets17.head()
# Out:
# Number of Tweets: 35687
#              tweet_id                                          short_url  \
# 0  989097603664138240                           http://arte.tv/abgedreht
# 1  988175933659021318  https://twitter.com/piersmorgan/status/9873882...
# 2  988176164358361088  https://www.journal.koeln/pol-ham-fahrradfahre...
# 3  988176403412766720                    http://www.radionomy.com/erika1
# 4  988176415995592704  https://twitter.com/JanLatten/status/988161845...
#
#                                         resolved_url  response_code  \
# 0  https://www.arte.tv/de/videos/RC-014033/abgedr...          200.0
# 1  https://twitter.com/piersmorgan/status/9873882...          200.0
# 2  https://www.journal.koeln/pol-ham-fahrradfahre...          200.0
# 3          https://www.radionomy.com/en/radio/erika1          200.0
# 4  https://twitter.com/JanLatten/status/988161845...          200.0
#
#                        domain top_level_domain  is_twitter_url is_media  \
# 0        https://www.arte.tv/          arte.tv           False    False
# 1        https://twitter.com/      twitter.com            True    False
# 2  https://www.journal.koeln/    journal.koeln           False    False
# 3  https://www.radionomy.com/    radionomy.com           False    False
# 4        https://twitter.com/      twitter.com            True    False
#
#    is_processed  failed
# 0          True   False
# 1          True   False
# 2          True   False
# 3          True   False
# 4          True   False

# %%
top_urls_03 = tweets03['resolved_url'].value_counts()

plt.figure(figsize=(16,12))

print(top_urls_03[:50])
ax = sns.barplot(y=top_urls_03[:50].index, x=top_urls_03[:50])
ax.set_title("Top URLs shared - Sampled Stream (Calendar Week 03)")

plt.savefig(directory + stream + "/sampled-top-urls-shared-03.png", transparent=True)
# Out:
# https://twitter.com/account/suspended                                                                                                                                                       183
# https://www.youtube.com/watch?v=Dw-2hh6G_D8&feature=youtu.be&a                                                                                                                               68
# https://www.dwd.de/                                                                                                                                                                          52
# http://www.deutschlandfunk.de/dlf24-startseite.1441.de.html                                                                                                                                  50
# https://pi2.17bullets.com/tw_post.php?messageId=achievement&values=&locale=en_US                                                                                                             50
# http://www.blackpinkyg.com/                                                                                                                                                                  48
# http://www.messe.tv/                                                                                                                                                                         41
# http://www.the-sz.com/products/vbbinfo/?f=3                                                                                                                                                  34
# http://der-x-code.com/                                                                                                                                                                       33
# http://wx3.sinaimg.cn/large/a157f83bly1fnk017dgu2j20zk0qogoh.jpg                                                                                                                             31
# https://farm5.staticflickr.com/4658/27991711159_fca7ac03bb_o.jpg                                                                                                                             31
# https://farm5.staticflickr.com/4632/25898289958_0b5d369677_o.jpg                                                                                                                             31
# https://www.instagram.com/p/BeGyLOHn6YR/?taken-by=exopassion12                                                                                                                               31
# https://www.emma-care.de/blog/teufelskralle-fuers-pferd-was-ist-das                                                                                                                          30
# https://www.radionomy.com/en/radio/erika1                                                                                                                                                    27
# https://www.purzel-video.com/                                                                                                                                                                24
# http://streaming.radionomy.com/Radio-Jodlerwirt1                                                                                                                                             24
# https://tiny.cc/32n9ly                                                                                                                                                                       24
# http://www.radio-jodlerwirt.de/                                                                                                                                                              23
# https://fcbayern.com/goretzka                                                                                                                                                                22
# https://www.facebook.com/CODECODE1111111111/                                                                                                                                                 21
# https://codepen.io/CODECODE42/details/KyJRQe/                                                                                                                                                21
# https://shop.windsor-verlag.com/cgi-sys/suspendedpage.cgi                                                                                                                                    20
# https://www.campact.de/campact/unterstuetzen/kampagne-beendet/                                                                                                                               20
# https://www.linkedin.com/                                                                                                                                                                    20
# https://www.amazon.com/Shally-Vintage-Bracelet-Tassel-Bohemia/dp/B0753D9LQ4/ref=sr_1_2?s=apparel&ie=UTF8&qid=1514463817&sr=1-2&nodeID=7147440011&psd=1&keywords=coin+bracelets+for+women     20
# https://wearline.co/?s=Fila&post_type=product                                                                                                                                                20
# http://www.flirt.21.com/                                                                                                                                                                     20
# https://www.timesofisrael.com/stabbing-victim-pulls-knife-out-of-own-neck-kills-terrorist/                                                                                                   20
# https://tiny.cc/13n9ly                                                                                                                                                                       19
# https://www.g5e.com/games/the_secret_society_hidden_mystery_ios                                                                                                                              19
# http://on4us.eu/up1sn/                                                                                                                                                                       19
# http://www.es-wird-morgen.de/                                                                                                                                                                19
# https://tiny.cc/n3n9ly                                                                                                                                                                       19
# http://webradio.m945.de/                                                                                                                                                                     19
# https://www.etsy.com/listing/565882262/gifts-jack-daniels-sefe-jack-daniels-box?ref=shop_home_active_1                                                                                       18
# https://tiny.cc/u2n9ly                                                                                                                                                                       18
# https://erlangenheute.wordpress.com/2018/01/17/mehrere-schlaegereien-in-erlangen/                                                                                                            18
# https://twitter.com/cducsubt/status/953263646997729280                                                                                                                                       15
# https://store.playstation.com/de-de/home/games                                                                                                                                               15
# https://twitter.com/hrfernsehen/status/952936461569003521                                                                                                                                    14
# https://cams.com/katie71?pid=g866508.subkatie71                                                                                                                                              14
# https://www.youtube.com/results?search_query=sehun+solo                                                                                                                                      14
# https://www.youtube.com/results?search_query=sehun+fancam                                                                                                                                    14
# https://web.de/magazine/reise/blog/melbourne-funktioniert-verkehrskonzept-gerade-32728516                                                                                                    14
# https://www.youtube.com/results?search_query=sehun+focus                                                                                                                                     14
# https://tinyurl.com/                                                                                                                                                                         13
# https://juergenfritz.com/2018/01/18/fluchtursachen-bekaemfen-merkel-weg/                                                                                                                     13
# http://www.lumlux-art.com/                                                                                                                                                                   13
# https://vxme.net/dirtysabi/                                                                                                                                                                  13
# Name: resolved_url, dtype: int64

# %%
top_urls_17 = tweets17['resolved_url'].value_counts()

plt.figure(figsize=(16,12))

print(top_urls_17[:50])
ax = sns.barplot(y=top_urls_17[:50].index, x=top_urls_17[:50])
ax.set_title("Top URLs shared - Sampled Stream (Calendar Week 17)")

plt.savefig(directory + stream + "/sampled-top-urls-shared-17.png", transparent=True)
# Out:
# https://www.dwd.de/                                                                                                  60
# https://www.ffd365.de                                                                                                57
# https://pi2.17bullets.com/tw_post.php?messageId=achievement&values=&locale=en_US                                     56
# http://susanne-ulrike-maria-albrecht.over-blog.de/                                                                   53
# https://twitter.com/buzzfeedfrance/status/988362712513171456                                                         47
# https://twitter.com/Markus_Soeder/status/988768341820170240                                                          43
# https://www.youtube.com/watch?v=F-eMt3SrfFU&feature=youtu.be                                                         37
# https://www.youtube.com/watch?v=tBWJ3bvJuT0&feature=youtu.be                                                         36
# https://www.instagram.com/p/BiFEczinLfJ/                                                                             36
# https://www.linkedin.com/                                                                                            36
# http://tv.naver.com/v/3097997                                                                                        36
# http://www.gooni168.tv/sellpanties/item/haushalts-sklave-in/                                                         34
# https://www.youtube.com/watch?v=tzni9QRNMEU&feature=youtu.be                                                         33
# http://tv.naver.com/v/3122852                                                                                        33
# https://www.tagesschau.de/                                                                                           28
# http://www.deutschlandfunk.de/dlf24-startseite.1441.de.html                                                          27
# http://www.the-sz.com/products/vbbinfo/?f=3                                                                          27
# http://www.achgut.com/artikel/die_enthauptung_der_hamburger_justiz                                                   25
# https://twitter.com/account/suspended                                                                                25
# https://www.radioking.com/play/reborn-webradio                                                                       23
# https://twitter.com/senatemajldr/status/989199961731551232                                                           23
# http://wx3.sinaimg.cn/large/a157f83bly1fqtogxp7nwj22kw3vcnpd.jpg                                                     22
# https://twitter.com/markus_soeder/status/988768341820170240                                                          22
# https://www.radionomy.com/en/radio/erika1                                                                            20
# http://www.chatgate24.com/                                                                                           19
# http://www.bravo.de/bts-die-k-pop-stars-deutschland-377553.html                                                      19
# https://www.miet-check.de/                                                                                           19
# http://www.the-sz.com/products/vbbinfo/?f=4                                                                          18
# http://www.spiegel.de/spiegel/unispiegel/fh-dortmund-bietet-neuen-studiengang-fluechtlingshilfe-an-a-1196053.html    18
# http://www.gooni168.tv/sellpanties/item/slip-sklave/                                                                 18
# http://newgenradio.com/                                                                                              18
# https://www.ticketmaster.de/artist/bts-tickets/958687                                                                17
# https://play.google.com/store/apps/details?id=com.fgcos.crossword_de_kreuzwortratsel                                 17
# https://twitter.com/tagesschau/status/988770475399696384                                                             17
# http://www.flirt.21.com/                                                                                             16
# http://streaming.radionomy.com/Radio-Jodlerwirt1                                                                     16
# http://www.kreditvergleich.ws/                                                                                       15
# http://www.my-dirty-hobby.com/profil/2801014-LAUREEN-PINK                                                            15
# http://www.radio-jodlerwirt.de/                                                                                      15
# https://play.google.com/store/apps/details?id=com.g5e.secretsociety                                                  14
# http://homepage.mrslove.com/usa1.php?x=X-xxxroad-com                                                                 14
# http://homepage.mrslove.com/usa1.php?x=X-LITOVE-4-date                                                               14
# http://stores.ebay.de/Graf-von-Eychendorf-Antiquitaten                                                               14
# https://twitter.com/zeitonline/status/988656113385123841                                                             14
# https://store.playstation.com/de-de/home/games                                                                       13
# https://twitter.com/mihle_h/status/989805482553602048                                                                13
# http://www.gooni168.tv/sellpanties/item/clone-deine-pussy-busen-po/                                                  13
# https://www.youtube.com/user/videodeutschland/videos                                                                 12
# http://www.passion-fm.de/                                                                                            12
# https://www.welt.de/vermischtes/article732888/Wenn-der-Cousin-mit-der-Cousine-schlaeft.html                          12
# Name: resolved_url, dtype: int64

# %%
top_urls_03 = tweets03['top_level_domain'].value_counts()

plt.figure(figsize=(16,12))
print(top_urls_03[:50])
ax = sns.barplot(y=top_urls_03[:50].index, x=top_urls_03[:50])
ax.set_title("Top Level Domains from URLs shared - Sampled Stream (Calendar Week 03)")

plt.savefig(directory + stream + "/sampled-top-tld-shared-03.png", transparent=True)
# Out:
# twitter.com                 6362
# youtube.com                 3262
# facebook.com                1000
# instagram.com                727
# welt.de                      688
# spiegel.de                   470
# focus.de                     377
# amazon.de                    372
# google.com                   338
# bild.de                      336
# twitch.tv                    311
# faz.net                      289
# wordpress.com                264
# sueddeutsche.de              248
# zeit.de                      229
# presseportal.de              221
# tagesschau.de                197
# miet-check.de                190
# benzinpreis-aktuell.de       187
# pressebank.de                183
# heise.de                     174
# paper.li                     174
# ask.fm                       171
# tagesspiegel.de              162
# n-tv.de                      147
# epochtimes.de                133
# derstandard.at               132
# philosophia-perennis.com     128
# handelsblatt.com             120
# bestbet4u.com                116
# persy.jobs                   114
# tichyseinblick.de            111
# nzz.ch                       106
# ebay.de                      103
# rp-online.de                  98
# curiouscat.me                 92
# amazon.com                    91
# journalistenwatch.com         91
# deutschlandfunk.de            89
# gutscheinstadt.de             89
# tiny.cc                       86
# badbadbad.de                  80
# webmasterplan.com             80
# tumblr.com                    79
# taz.de                        79
# wdr.de                        77
# der-postillon.com             77
# deutscher-warndienst.de       77
# rt.com                        77
# ebay.com                      76
# Name: top_level_domain, dtype: int64

# %%
top_urls_17 = tweets17['top_level_domain'].value_counts()

plt.figure(figsize=(16,12))

print(top_urls_17[:50])
ax = sns.barplot(y=top_urls_17[:50].index, x=top_urls_17[:50])
ax.set_title("Top Level Domains from URLs shared - Sampled Stream (Calendar Week 17)")

plt.savefig(directory + stream + "/sampled-top-tld-shared-17.png", transparent=True)
# Out:
# twitter.com                 6192
# youtube.com                 2961
# facebook.com                 884
# instagram.com                805
# welt.de                      534
# spiegel.de                   430
# amazon.de                    334
# twitch.tv                    318
# focus.de                     291
# wordpress.com                261
# bild.de                      258
# faz.net                      256
# zeit.de                      219
# sueddeutsche.de              216
# google.com                   206
# tagesschau.de                205
# presseportal.de              181
# paper.li                     178
# tagesspiegel.de              173
# heise.de                     141
# n-tv.de                      138
# epochtimes.de                127
# favstar.fm                   126
# journalistenwatch.com        111
# sinaimg.cn                   106
# handelsblatt.com             100
# over-blog.de                  99
# taz.de                        94
# rt.com                        94
# ebay.de                       91
# tichyseinblick.de             86
# journal.koeln                 80
# parapsychologie.club          78
# nzz.ch                        78
# help.ch                       77
# philosophia-perennis.com      77
# derstandard.at                76
# der-postillon.com             76
# naver.com                     75
# jungefreiheit.de              75
# rp-online.de                  74
# zdf.de                        73
# deutschlandfunk.de            73
# ffd365.de                     73
# ebay.com                      72
# social-booster.de             70
# stern.de                      70
# orf.at                        69
# morgenpost.de                 69
# curiouscat.me                 68
# Name: top_level_domain, dtype: int64

# %%
top_urls_03 = tweets03['domain'].value_counts()

plt.figure(figsize=(16,12))

print(top_urls_03[:50])
ax = sns.barplot(y=top_urls_03[:50].index, x=top_urls_03[:50])
ax.set_title("Top Domains from URLs shared - Sampled Stream (Calendar Week 17)")

plt.savefig(directory + stream + "/sampled-top-domains-shared-17.png", transparent=True)
# Out:
# https://twitter.com/                   6352
# https://www.youtube.com/               3247
# https://www.facebook.com/               892
# https://www.instagram.com/              708
# https://www.welt.de/                    671
# http://www.spiegel.de/                  447
# https://www.amazon.de/                  370
# https://www.focus.de/                   368
# https://www.twitch.tv/                  286
# https://www.bild.de/                    273
# http://www.faz.net/                     260
# http://www.sueddeutsche.de/             242
# https://www.presseportal.de/            221
# https://www.zeit.de/                    219
# https://www.miet-check.de/              190
# https://www.benzinpreis-aktuell.de/     187
# https://www.pressebank.de/              183
# http://www.tagesschau.de/               177
# https://ask.fm/                         171
# https://www.heise.de/                   167
# https://paper.li/                       159
# https://www.tagesspiegel.de/            144
# https://www.n-tv.de/                    142
# https://derstandard.at/                 128
# https://philosophia-perennis.com/       128
# https://www.google.com/                 124
# http://www.bestbet4u.com/               116
# http://www.handelsblatt.com/            114
# http://www.epochtimes.de/               111
# https://www.tichyseinblick.de/          104
# https://www.google.com:443/             103
# https://www.nzz.ch/                      99
# https://rp-online.de/                    98
# https://curiouscat.me/                   92
# https://www.journalistenwatch.com/       91
# https://www.amazon.com/                  91
# http://www.deutschlandfunk.de/           89
# https://gutscheinstadt.de/               89
# http://www.ebay.de/                      87
# https://tiny.cc/                         86
# https://www.persy.jobs/                  84
# https://badbadbad.de/                    80
# http://www.der-postillon.com/            77
# http://www.deutscher-warndienst.de/      77
# https://www1.wdr.de/                     76
# https://deutsch.rt.com/                  75
# https://www.wunschimmo.de/               75
# https://jungefreiheit.de/                71
# https://partners.webmasterplan.com/      71
# https://soundcloud.com/                  71
# Name: domain, dtype: int64

# %%
top_urls_17 = tweets17['domain'].value_counts()

plt.figure(figsize=(16,12))

print(top_urls_17[:50])
ax = sns.barplot(y=top_urls_17[:50].index, x=top_urls_17[:50])
ax.set_title("Top Domains from URLs shared - Sampled Stream (Calendar Week 17)")

plt.savefig(directory + stream + "/sampled-top-domains-shared-17.png", transparent=True)
# Out:
# https://twitter.com/                                  6180
# https://www.youtube.com/                              2947
# https://www.facebook.com/                              837
# https://www.instagram.com/                             770
# https://www.welt.de/                                   521
# http://www.spiegel.de/                                 407
# https://www.amazon.de/                                 332
# https://www.twitch.tv/                                 306
# https://www.focus.de/                                  279
# http://www.faz.net/                                    234
# https://www.bild.de/                                   210
# https://www.zeit.de/                                   209
# http://www.sueddeutsche.de/                            194
# https://www.presseportal.de/                           181
# https://paper.li/                                      169
# http://www.tagesschau.de/                              150
# https://www.tagesspiegel.de/                           145
# https://www.heise.de/                                  139
# https://www.n-tv.de/                                   133
# https://www.epochtimes.de/                             127
# http://de.favstar.fm/                                  123
# https://www.journalistenwatch.com/                     111
# http://susanne-ulrike-maria-albrecht.over-blog.de/      99
# https://deutsch.rt.com/                                 93
# http://www.handelsblatt.com/                            93
# https://www.tichyseinblick.de/                          86
# https://www.journal.koeln/                              80
# https://philosophia-perennis.com/                       77
# https://jungefreiheit.de/                               75
# https://www.google.com/                                 75
# http://tv.naver.com/                                    73
# https://www.ffd365.de/                                  73
# http://www.deutschlandfunk.de/                          73
# http://www.rp-online.de/                                73
# https://www.zdf.de/                                     71
# https://derstandard.at/                                 70
# https://www.morgenpost.de/                              69
# https://curiouscat.me/                                  68
# http://www.gooni168.tv/                                 67
# https://www.tag24.de/                                   66
# https://www.nzz.ch/                                     66
# https://www.stern.de/                                   64
# http://www.pi-news.net/                                 63
# https://www.dwd.de/                                     63
# https://pi2.17bullets.com/                              63
# https://play.google.com/                                62
# https://soundcloud.com/                                 61
# https://www.br.de/                                      60
# https://itunes.apple.com/                               59
# http://www.fr.de/                                       59
# Name: domain, dtype: int64
