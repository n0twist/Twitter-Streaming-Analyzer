# %% [markdown]
# # Tweet Variation Data Comparison (Sampled vs Filtered)

# %%
import psycopg2
import pandas as pd
import config
from matplotlib import pylab as plt
import seaborn as sns
import numpy as np
from IPython.display import display, HTML
import re


color_palette = sns.color_palette(palette='muted', n_colors=None, desat=.75)
sns.set(context='notebook', palette=color_palette, style='whitegrid', font='sans-serif', font_scale=1.5, color_codes=False, rc=None)
pd.set_option('display.max_colwidth', -1)
table_styles = [{'selector': 'td',
                 'props': [('min-width', '100px'), ('text-align', 'center')]},
                {'selector': 'tr',
                 'props': [('border-bottom', '1px dotted black')]},
                {'selector': 'th',
                 'props': [('text-align', 'center')]}
               ]

# %matplotlib inline

directory = "url_top_lists/"
stream = "comparison"

# %% [markdown]
# ## Util Methods

# %%
def compareRows(row, df_to_compare, column_name):
    comparison_row = df_to_compare.loc[df_to_compare[column_name] == row[column_name]]
    if comparison_row.empty:
        comparison = " - "
    else:
        percentage_dif = row['percentage'] - comparison_row['percentage'].values[0]
        difference = "(%s. / %.3f%% / %.3f%%)" % (comparison_row['rank'].values[0], comparison_row['percentage'].values[0], percentage_dif)
        if comparison_row['rank'].values[0] == row['rank']:
            comparison = " = <br>" + difference
        else:
            if comparison_row['rank'].values[0] > row['rank']:
                comparison = " v <br>" + difference
            else:
                comparison = " ^ <br>" + difference
    return comparison

def getOpacity(val):
    value = abs(float(re.findall(r"[-+]?\d*\.\d+|\d+", val.split("/")[2])[0]))
    if value < 0.005:
        return 1
    if value < 0.01:
        return 0.95
    if value < 0.05:
        return 0.8
    if value < 0.1:
        return 0.7
    if value < 0.5:
        return 0.6
    if value < 1:
        return 0.5
    if value < 10:
        return 0.3
    if value < 40:
        return 0.2
    if value < 80:
        return 0.1
    if value < 100:
        return 0.05

def colorComparisonField(val):
    
    if isinstance(val, str):
        if ' ^ ' in val or ' v ' in val:
            return 'background-color: rgba(246, 185, 59, %s)' %getOpacity(val)
        if ' = ' in val:
            return 'background-color: rgba(184, 233, 148, %s)' %getOpacity(val)
        if ' - ' in val and len(val) == 3:
            return 'background-color: #e55039' 
    return ''

def generateRankingDataframe(series, attribute_name):
    size = series.sum()
    rank = []
    parameter = []
    count = []
    percentage = []

    i = 1
    for index, value in series.iteritems():
        rank.append(i)
        parameter.append(index)
        count.append(value)
        percentage.append((value/size)*100)
        i += 1

    data = {'rank': rank, attribute_name: parameter, 'value': count, 'percentage': percentage}
    return pd.DataFrame(data=data)

def generateComparisonDataframes(df1, df2, column_name, size):
    compare_list = []
    for index, row in df1.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df2, column_name))

    data = {'rank': df1['rank'][:size], column_name: df1[column_name][:size], 'value': df1['value'][:size], 'percentage': df1['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df1_compared = pd.DataFrame(data=data)
    df1_compared.set_index(keys='rank', inplace=True)
    
    compare_list = []
    for index, row in df2.iterrows():
        if row['rank'] <= size:
            compare_list.append(compareRows(row, df1, column_name))

    data = {'rank': df2['rank'][:size], column_name: df2[column_name][:size], 'value': df2['value'][:size], 'percentage': df2['percentage'][:size],
            'difference (rank / percentage / diff)': compare_list}
    
    df2_compared = pd.DataFrame(data=data)
    df2_compared.set_index(keys='rank', inplace=True)
    
    return df1_compared, df2_compared

def getPrettyComparisonDataframe(df, title):
    s = df.style.applymap(colorComparisonField)
    s.set_caption(title)
    s.set_table_styles(table_styles)
    return s

  
def getIdentifier(retweet_option, quote_option, reply_option, icard_option):
    identifier = ""
    if retweet_option:
        identifier += "1 "
    else:
        identifier += "0 "
    if quote_option:
        identifier += "1 "
    else:
        identifier += "0 "
    if reply_option:
        identifier += "1 "
    else:
        identifier += "0 "
    if icard_option:
        identifier += "1 "
    else:
        identifier += "0 "
    
    return identifier

def generateTweetsVariationDataframe(dataframe):
    is_retweet = [False, True]
    is_quote = [False, True]
    is_reply = [False, True]
    has_icard = [False, True]
    
    identifier_list = []
    value_list = []
    
    for retweet_option in is_retweet:
        for quote_option in is_quote:
            for reply_option in is_reply:
                for icard_option in has_icard:
                    identifier_list.append(getIdentifier(retweet_option, quote_option, reply_option, icard_option))
                    if icard_option:
                        data_set = dataframe[(dataframe['is_retweet'] == retweet_option) & 
                                             (dataframe['is_quote'] == quote_option) & 
                                             (dataframe['is_reply'] == reply_option) & 
                                             (dataframe['has_icard'] == icard_option) & (dataframe['response_code'] != None)]
                        value_list.append(len(data_set))
                    else:
                        data_set = dataframe[(dataframe['is_retweet'] == retweet_option) & 
                                             (dataframe['is_quote'] == quote_option) & 
                                             (dataframe['is_reply'] == reply_option) & 
                                             (dataframe['has_icard'] == icard_option)]
                        value_list.append(len(data_set))
                        
    data = {'combination': identifier_list, "value": value_list}
    df = pd.DataFrame(data=data)
    
    return df.sort_values("value", ascending=False).set_index("combination")

# %%
conn = None
try:
    # read connection parameters
    paramsS17 = config.cfgAzureS17()
    paramsS03 = config.cfgAzureS03()

    paramsF17 = config.cfgAzureF17()
    paramsF03 = config.cfgAzureF03()
    
    # connect to the PostgreSQL server
    print('Connecting to the PostgreSQL database...')
    connS17 = psycopg2.connect(**paramsS17)
    connS03 = psycopg2.connect(**paramsS03)
    
    connF17 = psycopg2.connect(**paramsF17)
    connF03 = psycopg2.connect(**paramsF03)

    # create a cursor
    curS17 = connS17.cursor()
    curS03 = connS03.cursor()
    
    curF17 = connF17.cursor()
    curF03 = connF03.cursor()

    # execute a statement
    print('PostgreSQL database version:')
    
    curS17.execute('SELECT version()')
    curS03.execute('SELECT version()')
    curF17.execute('SELECT version()')
    curF03.execute('SELECT version()')
    
    # display the PostgreSQL database server version
    db_version_curS17 = curS17.fetchone()
    db_version_curS03 = curS03.fetchone()
    db_version_curF17 = curF17.fetchone()
    db_version_curF03 = curF03.fetchone()
    
    print(db_version_curS17)
    print(db_version_curS03)
    print(db_version_curF17)
    print(db_version_curF03)

    # close the communication with the PostgreSQL
    curS17.close()
    curS03.close()
    curF17.close()
    curF03.close()

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)
# ('PostgreSQL 9.6.7, compiled by Visual C++ build 1800, 64-bit',)

# %% [markdown]
# ## Query URLs

# %% [markdown]
# ### Calendar Week 03 - Sampled

# %%
tweetsS03 = pd.read_sql_query('''SELECT id, is_retweet, is_quote, is_reply, tc.has_icard, tc.response_code FROM tweets_info as ti 
                                 INNER JOIN tweets_icards as tc ON ti.id = tc.tweet_id;''', connS03 )

print("Number of Tweets: %s" %len(tweetsS03))
tweetsS03.head()
# Out:
# Number of Tweets: 123680
#                    id  is_retweet  is_quote  is_reply  has_icard  \
# 0  952676745496354816  False       False     False     False
# 1  952676816820621314  False       False     False     True
# 2  952676816820555776  False       False     False     True
# 3  952676825183944705  False       False     False     False
# 4  952676971980513281  True        False     False     False
#
#    response_code
# 0 NaN
# 1  200.0
# 2  200.0
# 3 NaN
# 4 NaN

# %% [markdown]
# ### Calendar Week 17 - Sampled

# %%
tweetsS17 = pd.read_sql_query('''SELECT id, is_retweet, is_quote, is_reply, tc.has_icard, tc.response_code FROM tweets_info as ti 
                                 INNER JOIN tweets_icards as tc ON ti.id = tc.tweet_id;''', connS17 )

print("Number of Tweets: %s" %len(tweetsS17))
tweetsS17.head()
# Out:
# Number of Tweets: 112002
#                    id  is_retweet  is_quote  is_reply has_icard  response_code
# 0  988175619098861568  False       False     False     False    NaN
# 1  988175627453952002  False       False     False     False    NaN
# 2  988175778474020868  False       False     False     True      200.0
# 3  988175828801540097  False       False     False     False    NaN
# 4  987388203593322496  False       False     False     False    NaN

# %% [markdown]
# ## Sampled Concatination

# %%
frames = [tweetsS03, tweetsS17]
tweetsS = pd.concat(frames)

# %% [markdown]
# ### Calendar Week 03 - Filtered

# %%
tweetsF03 = pd.read_sql_query('''SELECT id, is_retweet, is_quote, is_reply, tc.has_icard, tc.response_code FROM tweets_info as ti 
                                 INNER JOIN tweets_icards as tc ON ti.id = tc.tweet_id;''', connF03 )

print("Number of Tweets: %s" %len(tweetsF03))
tweetsF03.head()
# Out:
# Number of Tweets: 8010674
#                    id  is_retweet  is_quote  is_reply  has_icard  \
# 0  952676704803262465  False       False     True      False
# 1  952676814618529793  False       False     False     True
# 2  952676815331627008  False       False     False     True
# 3  952676829881667586  False       False     False     True
# 4  952676875805093889  False       False     False     True
#
#    response_code
# 0 NaN
# 1  200.0
# 2  200.0
# 3  200.0
# 4  200.0

# %% [markdown]
# ### Calendar Week 17 - Filtered

# %%
tweetsF17 = pd.read_sql_query('''SELECT id, is_retweet, is_quote, is_reply, tc.has_icard, tc.response_code FROM tweets_info as ti 
                                 INNER JOIN tweets_icards as tc ON ti.id = tc.tweet_id;''', connF17 )

print("Number of Tweets: %s" %len(tweetsF17))
tweetsF17.head()
# Out:
# Number of Tweets: 7269345
#                    id  is_retweet  is_quote  is_reply  has_icard  \
# 0  989558776553443329  True        False     False     False
# 1  989558800460996609  False       False     True      False
# 2  988872048591212550  True        False     False     False
# 3  989887974476255232  False       False     False     False
# 4  989558823542312960  False       False     False     False
#
#    response_code
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %% [markdown]
# ## Filtered Concatination

# %%
frames = [tweetsF03, tweetsF17]
tweetsF = pd.concat(frames)

# %% [markdown]
# ## Tweet Variations

# %% [markdown]
# ### Calendar Week 03 - Tweet Variations - Sampled x Filtered

# %%
column_name = 'is_retweet, is_quote, is_reply, has_icard'
    
df_sampled = generateRankingDataframe(generateTweetsVariationDataframe(tweetsS03).squeeze(), column_name)
df_filtered = generateRankingDataframe(generateTweetsVariationDataframe(tweetsF03).squeeze(), column_name)

df_sampled_comparison, df_filtered_comparison = generateComparisonDataframes(df_sampled, df_filtered, column_name, 25)

# %%
s = getPrettyComparisonDataframe(df_sampled_comparison, "CW 03 - Tweet Variations - Sampled Data (compared to Filtered Data)")
s
# Out:
# <style  type="text/css" >
#     #T_79ec0582_6e58_11e8_be81_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_79ec0582_6e58_11e8_be81_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_79ec0582_6e58_11e8_be81_642737c470c3 th {
#           text-align: center;
#     }    #T_79ec0582_6e58_11e8_be81_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row4_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row5_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row6_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row8_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row9_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row10_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row11_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row12_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row13_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row14_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_79ec0582_6e58_11e8_be81_642737c470c3row15_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }</style>
# <table id="T_79ec0582_6e58_11e8_be81_642737c470c3" ><caption>CW 03 - Tweet Variations - Sampled Data (compared to Filtered Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >is_retweet, is_quote, is_reply, has_icard</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_79ec0582_6e58_11e8_be81_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row0_col0" class="data row0 col0" >0 0 0 0 </td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row0_col1" class="data row0 col1" >44894</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row0_col2" class="data row0 col2" >36.2985</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 27.799% / 8.500%)</td>
#     </tr>    <tr>
#         <th id="T_79ec0582_6e58_11e8_be81_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row1_col0" class="data row1 col0" >0 0 1 0 </td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row1_col1" class="data row1 col1" >26984</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row1_col2" class="data row1 col2" >21.8176</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row1_col3" class="data row1 col3" > = <br>(2. / 26.581% / -4.763%)</td>
#     </tr>    <tr>
#         <th id="T_79ec0582_6e58_11e8_be81_642737c470c3level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row2_col0" class="data row2 col0" >1 0 0 0 </td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row2_col1" class="data row2 col1" >24055</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row2_col2" class="data row2 col2" >19.4494</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row2_col3" class="data row2 col3" > = <br>(3. / 24.228% / -4.779%)</td>
#     </tr>    <tr>
#         <th id="T_79ec0582_6e58_11e8_be81_642737c470c3level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row3_col0" class="data row3 col0" >0 0 0 1 </td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row3_col1" class="data row3 col1" >14585</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row3_col2" class="data row3 col2" >11.7925</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row3_col3" class="data row3 col3" > = <br>(4. / 9.562% / 2.231%)</td>
#     </tr>    <tr>
#         <th id="T_79ec0582_6e58_11e8_be81_642737c470c3level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row4_col0" class="data row4 col0" >1 0 0 1 </td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row4_col1" class="data row4 col1" >5238</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row4_col2" class="data row4 col2" >4.23512</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row4_col3" class="data row4 col3" > = <br>(5. / 5.490% / -1.255%)</td>
#     </tr>    <tr>
#         <th id="T_79ec0582_6e58_11e8_be81_642737c470c3level0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row5_col0" class="data row5 col0" >0 1 0 0 </td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row5_col1" class="data row5 col1" >4727</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row5_col2" class="data row5 col2" >3.82196</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row5_col3" class="data row5 col3" > = <br>(6. / 3.006% / 0.816%)</td>
#     </tr>    <tr>
#         <th id="T_79ec0582_6e58_11e8_be81_642737c470c3level0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row6_col0" class="data row6 col0" >1 1 0 0 </td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row6_col1" class="data row6 col1" >2300</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row6_col2" class="data row6 col2" >1.85964</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row6_col3" class="data row6 col3" > = <br>(7. / 2.602% / -0.742%)</td>
#     </tr>    <tr>
#         <th id="T_79ec0582_6e58_11e8_be81_642737c470c3level0_row7" class="row_heading level0 row7" >8</th>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row7_col0" class="data row7 col0" >0 0 1 1 </td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row7_col1" class="data row7 col1" >658</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row7_col2" class="data row7 col2" >0.532018</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row7_col3" class="data row7 col3" > = <br>(8. / 0.514% / 0.018%)</td>
#     </tr>    <tr>
#         <th id="T_79ec0582_6e58_11e8_be81_642737c470c3level0_row8" class="row_heading level0 row8" >9</th>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row8_col0" class="data row8 col0" >0 1 1 0 </td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row8_col1" class="data row8 col1" >152</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row8_col2" class="data row8 col2" >0.122898</td>
#         <td id="T_79ec0582_6e58_11e8_be81_642737c470c3row8_col3" class="data row8 col3" > = <br>(9. / 0.

# %%
s = getPrettyComparisonDataframe(df_filtered_comparison, "CW 03 - Tweet Variations - Filtered Data (compared to Sampled Data)")
s
# Out:
# <style  type="text/css" >
#     #T_8aebe2ee_6e58_11e8_9db7_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3 th {
#           text-align: center;
#     }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row0_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row1_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row4_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row5_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row6_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row8_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row9_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row10_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row11_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row12_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row13_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row14_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8aebe2ee_6e58_11e8_9db7_642737c470c3row15_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }</style>
# <table id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3" ><caption>CW 03 - Top Level Domains - Filtered Data (compared to Sampled Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >is_retweet, is_quote, is_reply, has_icard</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row0_col0" class="data row0 col0" >0 0 0 0 </td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row0_col1" class="data row0 col1" >2226852</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row0_col2" class="data row0 col2" >27.7986</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row0_col3" class="data row0 col3" > = <br>(1. / 36.299% / -8.500%)</td>
#     </tr>    <tr>
#         <th id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row1_col0" class="data row1 col0" >0 0 1 0 </td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row1_col1" class="data row1 col1" >2129316</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row1_col2" class="data row1 col2" >26.581</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row1_col3" class="data row1 col3" > = <br>(2. / 21.818% / 4.763%)</td>
#     </tr>    <tr>
#         <th id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row2_col0" class="data row2 col0" >1 0 0 0 </td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row2_col1" class="data row2 col1" >1940857</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row2_col2" class="data row2 col2" >24.2284</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row2_col3" class="data row2 col3" > = <br>(3. / 19.449% / 4.779%)</td>
#     </tr>    <tr>
#         <th id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row3_col0" class="data row3 col0" >0 0 0 1 </td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row3_col1" class="data row3 col1" >765982</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row3_col2" class="data row3 col2" >9.56202</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row3_col3" class="data row3 col3" > = <br>(4. / 11.793% / -2.231%)</td>
#     </tr>    <tr>
#         <th id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row4_col0" class="data row4 col0" >1 0 0 1 </td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row4_col1" class="data row4 col1" >439766</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row4_col2" class="data row4 col2" >5.48975</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row4_col3" class="data row4 col3" > = <br>(5. / 4.235% / 1.255%)</td>
#     </tr>    <tr>
#         <th id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3level0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row5_col0" class="data row5 col0" >0 1 0 0 </td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row5_col1" class="data row5 col1" >240814</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row5_col2" class="data row5 col2" >3.00616</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row5_col3" class="data row5 col3" > = <br>(6. / 3.822% / -0.816%)</td>
#     </tr>    <tr>
#         <th id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3level0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row6_col0" class="data row6 col0" >1 1 0 0 </td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row6_col1" class="data row6 col1" >208435</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row6_col2" class="data row6 col2" >2.60197</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row6_col3" class="data row6 col3" > = <br>(7. / 1.860% / 0.742%)</td>
#     </tr>    <tr>
#         <th id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3level0_row7" class="row_heading level0 row7" >8</th>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row7_col0" class="data row7 col0" >0 0 1 1 </td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row7_col1" class="data row7 col1" >41148</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row7_col2" class="data row7 col2" >0.513665</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row7_col3" class="data row7 col3" > = <br>(8. / 0.532% / -0.018%)</td>
#     </tr>    <tr>
#         <th id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3level0_row8" class="row_heading level0 row8" >9</th>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row8_col0" class="data row8 col0" >0 1 1 0 </td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row8_col1" class="data row8 col1" >10088</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row8_col2" class="data row8 col2" >0.125932</td>
#         <td id="T_8aebe2ee_6e58_11e8_9db7_642737c470c3row8_col3" class="data row8 col3

# %% [markdown]
# ### Calendar Week 17 - Tweet Variations - Sampled x Filtered

# %%
column_name = 'is_retweet, is_quote, is_reply, has_icard'
    
df_sampled = generateRankingDataframe(generateTweetsVariationDataframe(tweetsS17).squeeze(), column_name)
df_filtered = generateRankingDataframe(generateTweetsVariationDataframe(tweetsF17).squeeze(), column_name)

df_sampled_comparison, df_filtered_comparison = generateComparisonDataframes(df_sampled, df_filtered, column_name, 25)

# %%
s = getPrettyComparisonDataframe(df_sampled_comparison, "CW 17 - Tweets Variations - Sampled Data (compared to Filtered Data)")
s
# Out:
# <style  type="text/css" >
#     #T_87ca021e_6f3a_11e8_b03c_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3 th {
#           text-align: center;
#     }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row0_col3 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row1_col3 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row4_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row5_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row6_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row8_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row9_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row10_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row11_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row12_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row13_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row14_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_87ca021e_6f3a_11e8_b03c_642737c470c3row15_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }</style>
# <table id="T_87ca021e_6f3a_11e8_b03c_642737c470c3" ><caption>CW 17 - Tweets Variations - Sampled Data (compared to Filtered Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >is_retweet, is_quote, is_reply, has_icard</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_87ca021e_6f3a_11e8_b03c_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row0_col0" class="data row0 col0" >0 0 0 0 </td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row0_col1" class="data row0 col1" >82095</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row0_col2" class="data row0 col2" >34.8334</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row0_col3" class="data row0 col3" > v <br>(2. / 26.312% / 8.521%)</td>
#     </tr>    <tr>
#         <th id="T_87ca021e_6f3a_11e8_b03c_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row1_col0" class="data row1 col0" >0 0 1 0 </td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row1_col1" class="data row1 col1" >52583</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row1_col2" class="data row1 col2" >22.3113</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row1_col3" class="data row1 col3" > ^ <br>(1. / 27.166% / -4.855%)</td>
#     </tr>    <tr>
#         <th id="T_87ca021e_6f3a_11e8_b03c_642737c470c3level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row2_col0" class="data row2 col0" >1 0 0 0 </td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row2_col1" class="data row2 col1" >44424</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row2_col2" class="data row2 col2" >18.8494</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row2_col3" class="data row2 col3" > = <br>(3. / 23.887% / -5.037%)</td>
#     </tr>    <tr>
#         <th id="T_87ca021e_6f3a_11e8_b03c_642737c470c3level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row3_col0" class="data row3 col0" >0 0 0 1 </td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row3_col1" class="data row3 col1" >29692</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row3_col2" class="data row3 col2" >12.5985</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row3_col3" class="data row3 col3" > = <br>(4. / 10.048% / 2.551%)</td>
#     </tr>    <tr>
#         <th id="T_87ca021e_6f3a_11e8_b03c_642737c470c3level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row4_col0" class="data row4 col0" >1 0 0 1 </td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row4_col1" class="data row4 col1" >11182</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row4_col2" class="data row4 col2" >4.74459</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row4_col3" class="data row4 col3" > = <br>(5. / 6.074% / -1.329%)</td>
#     </tr>    <tr>
#         <th id="T_87ca021e_6f3a_11e8_b03c_642737c470c3level0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row5_col0" class="data row5 col0" >0 1 0 0 </td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row5_col1" class="data row5 col1" >9340</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row5_col2" class="data row5 col2" >3.96302</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row5_col3" class="data row5 col3" > = <br>(6. / 3.123% / 0.840%)</td>
#     </tr>    <tr>
#         <th id="T_87ca021e_6f3a_11e8_b03c_642737c470c3level0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row6_col0" class="data row6 col0" >1 1 0 0 </td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row6_col1" class="data row6 col1" >4347</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row6_col2" class="data row6 col2" >1.84446</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row6_col3" class="data row6 col3" > = <br>(7. / 2.579% / -0.735%)</td>
#     </tr>    <tr>
#         <th id="T_87ca021e_6f3a_11e8_b03c_642737c470c3level0_row7" class="row_heading level0 row7" >8</th>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row7_col0" class="data row7 col0" >0 0 1 1 </td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row7_col1" class="data row7 col1" >1491</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row7_col2" class="data row7 col2" >0.63264</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row7_col3" class="data row7 col3" > = <br>(8. / 0.574% / 0.059%)</td>
#     </tr>    <tr>
#         <th id="T_87ca021e_6f3a_11e8_b03c_642737c470c3level0_row8" class="row_heading level0 row8" >9</th>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row8_col0" class="data row8 col0" >0 1 1 0 </td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row8_col1" class="data row8 col1" >289</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row8_col2" class="data row8 col2" >0.122624</td>
#         <td id="T_87ca021e_6f3a_11e8_b03c_642737c470c3row8_col3" class="data row8 col3" > = <br>(9.

# %%
writer = pd.ExcelWriter('output.xlsx')
s.to_excel(writer,'Sheet1')
writer.save()
# Out:
# c:\users\bender\appdata\local\programs\python\python36\lib\site-packages\pandas\io\formats\excel.py:312: CSSWarning: Unhandled color format: 'rgba(246, 185, 59, 0.3)'
#   CSSWarning)
# c:\users\bender\appdata\local\programs\python\python36\lib\site-packages\pandas\io\formats\excel.py:312: CSSWarning: Unhandled color format: 'rgba(184, 233, 148, 0.3)'
#   CSSWarning)
# c:\users\bender\appdata\local\programs\python\python36\lib\site-packages\pandas\io\formats\excel.py:312: CSSWarning: Unhandled color format: 'rgba(184, 233, 148, 0.5)'
#   CSSWarning)
# c:\users\bender\appdata\local\programs\python\python36\lib\site-packages\pandas\io\formats\excel.py:312: CSSWarning: Unhandled color format: 'rgba(184, 233, 148, 0.7)'
#   CSSWarning)
# c:\users\bender\appdata\local\programs\python\python36\lib\site-packages\pandas\io\formats\excel.py:312: CSSWarning: Unhandled color format: 'rgba(184, 233, 148, 0.8)'
#   CSSWarning)
# c:\users\bender\appdata\local\programs\python\python36\lib\site-packages\pandas\io\formats\excel.py:312: CSSWarning: Unhandled color format: 'rgba(184, 233, 148, 1)'
#   CSSWarning)

# %%
s = getPrettyComparisonDataframe(df_filtered_comparison, "CW 17 - Tweet Variations - Filtered Data (compared to Sampled Data)")
s
# Out:
# <style  type="text/css" >
#     #T_8e15c6b4_6e5c_11e8_b196_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3 th {
#           text-align: center;
#     }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row0_col3 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row1_col3 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row4_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row5_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row6_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.6);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row8_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row9_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row10_col3 {
#             background-color:  rgba(184, 233, 148, 0.95);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row11_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row12_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row13_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row14_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_8e15c6b4_6e5c_11e8_b196_642737c470c3row15_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }</style>
# <table id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3" ><caption>CW 17 - Top Level Domains - Filtered Data (compared to Sampled Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >is_retweet, is_quote, is_reply, has_icard</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row0_col0" class="data row0 col0" >0 0 1 0 </td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row0_col1" class="data row0 col1" >2021622</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row0_col2" class="data row0 col2" >27.8102</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row0_col3" class="data row0 col3" > v <br>(2. / 22.856% / 4.954%)</td>
#     </tr>    <tr>
#         <th id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row1_col0" class="data row1 col0" >0 0 0 0 </td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row1_col1" class="data row1 col1" >1793640</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row1_col2" class="data row1 col2" >24.674</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row1_col3" class="data row1 col3" > ^ <br>(1. / 33.215% / -8.541%)</td>
#     </tr>    <tr>
#         <th id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row2_col0" class="data row2 col0" >1 0 0 0 </td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row2_col1" class="data row2 col1" >1709043</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row2_col2" class="data row2 col2" >23.5103</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row2_col3" class="data row2 col3" > = <br>(3. / 18.187% / 5.324%)</td>
#     </tr>    <tr>
#         <th id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row3_col0" class="data row3 col0" >0 0 0 1 </td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row3_col1" class="data row3 col1" >769333</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row3_col2" class="data row3 col2" >10.5833</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row3_col3" class="data row3 col3" > = <br>(4. / 13.489% / -2.905%)</td>
#     </tr>    <tr>
#         <th id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row4_col0" class="data row4 col0" >1 0 0 1 </td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row4_col1" class="data row4 col1" >488297</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row4_col2" class="data row4 col2" >6.71721</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row4_col3" class="data row4 col3" > = <br>(5. / 5.307% / 1.410%)</td>
#     </tr>    <tr>
#         <th id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3level0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row5_col0" class="data row5 col0" >0 1 0 0 </td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row5_col1" class="data row5 col1" >236404</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row5_col2" class="data row5 col2" >3.25207</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row5_col3" class="data row5 col3" > = <br>(6. / 4.119% / -0.867%)</td>
#     </tr>    <tr>
#         <th id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3level0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row6_col0" class="data row6 col0" >1 1 0 0 </td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row6_col1" class="data row6 col1" >185651</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row6_col2" class="data row6 col2" >2.55389</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row6_col3" class="data row6 col3" > = <br>(7. / 1.828% / 0.726%)</td>
#     </tr>    <tr>
#         <th id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3level0_row7" class="row_heading level0 row7" >8</th>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row7_col0" class="data row7 col0" >0 0 1 1 </td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row7_col1" class="data row7 col1" >46550</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row7_col2" class="data row7 col2" >0.64036</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row7_col3" class="data row7 col3" > = <br>(8. / 0.744% / -0.103%)</td>
#     </tr>    <tr>
#         <th id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3level0_row8" class="row_heading level0 row8" >9</th>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row8_col0" class="data row8 col0" >0 1 1 0 </td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row8_col1" class="data row8 col1" >10111</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row8_col2" class="data row8 col2" >0.139091</td>
#         <td id="T_8e15c6b4_6e5c_11e8_b196_642737c470c3row8_col3" class="data row8 co

# %% [markdown]
# ### Calendar Weeks - Tweet Variations - Sampled x Filtered

# %%
column_name = 'is_retweet, is_quote, is_reply, has_icard'
    
df_sampled = generateRankingDataframe(generateTweetsVariationDataframe(tweetsS).squeeze(), column_name)
df_filtered = generateRankingDataframe(generateTweetsVariationDataframe(tweetsF).squeeze(), column_name)

df_sampled_comparison, df_filtered_comparison = generateComparisonDataframes(df_sampled, df_filtered, column_name, 25)

# %%
s = getPrettyComparisonDataframe(df_sampled_comparison, "Tweets Variations - Sampled Data (compared to Filtered Data)")
s
# Out:
# <style  type="text/css" >
#     #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3 th {
#           text-align: center;
#     }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row0_col3 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row1_col3 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row4_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row5_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row6_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row8_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row9_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row10_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row11_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row12_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row13_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row14_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row15_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }</style>
# <table id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3" ><caption>Tweets Variations - Sampled Data (compared to Filtered Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >is_retweet, is_quote, is_reply, has_icard</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row0_col0" class="data row0 col0" >0 0 0 0 </td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row0_col1" class="data row0 col1" >82095</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row0_col2" class="data row0 col2" >34.8334</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row0_col3" class="data row0 col3" > v <br>(2. / 26.312% / 8.521%)</td>
#     </tr>    <tr>
#         <th id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row1_col0" class="data row1 col0" >0 0 1 0 </td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row1_col1" class="data row1 col1" >52583</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row1_col2" class="data row1 col2" >22.3113</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row1_col3" class="data row1 col3" > ^ <br>(1. / 27.166% / -4.855%)</td>
#     </tr>    <tr>
#         <th id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row2_col0" class="data row2 col0" >1 0 0 0 </td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row2_col1" class="data row2 col1" >44424</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row2_col2" class="data row2 col2" >18.8494</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row2_col3" class="data row2 col3" > = <br>(3. / 23.887% / -5.037%)</td>
#     </tr>    <tr>
#         <th id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row3_col0" class="data row3 col0" >0 0 0 1 </td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row3_col1" class="data row3 col1" >29692</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row3_col2" class="data row3 col2" >12.5985</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row3_col3" class="data row3 col3" > = <br>(4. / 10.048% / 2.551%)</td>
#     </tr>    <tr>
#         <th id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row4_col0" class="data row4 col0" >1 0 0 1 </td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row4_col1" class="data row4 col1" >11182</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row4_col2" class="data row4 col2" >4.74459</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row4_col3" class="data row4 col3" > = <br>(5. / 6.074% / -1.329%)</td>
#     </tr>    <tr>
#         <th id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3level0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row5_col0" class="data row5 col0" >0 1 0 0 </td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row5_col1" class="data row5 col1" >9340</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row5_col2" class="data row5 col2" >3.96302</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row5_col3" class="data row5 col3" > = <br>(6. / 3.123% / 0.840%)</td>
#     </tr>    <tr>
#         <th id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3level0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row6_col0" class="data row6 col0" >1 1 0 0 </td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row6_col1" class="data row6 col1" >4347</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row6_col2" class="data row6 col2" >1.84446</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row6_col3" class="data row6 col3" > = <br>(7. / 2.579% / -0.735%)</td>
#     </tr>    <tr>
#         <th id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3level0_row7" class="row_heading level0 row7" >8</th>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row7_col0" class="data row7 col0" >0 0 1 1 </td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row7_col1" class="data row7 col1" >1491</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row7_col2" class="data row7 col2" >0.63264</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row7_col3" class="data row7 col3" > = <br>(8. / 0.574% / 0.059%)</td>
#     </tr>    <tr>
#         <th id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3level0_row8" class="row_heading level0 row8" >9</th>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row8_col0" class="data row8 col0" >0 1 1 0 </td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row8_col1" class="data row8 col1" >289</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row8_col2" class="data row8 col2" >0.122624</td>
#         <td id="T_1ca3cf78_6f40_11e8_bb4c_642737c470c3row8_col3" class="data row8 col3" > = <br>(9. / 0.132

# %%
s = getPrettyComparisonDataframe(df_filtered_comparison, "Tweet Variations - Filtered Data (compared to Sampled Data)")
s
# Out:
# <style  type="text/css" >
#     #T_1a163680_6f40_11e8_9242_642737c470c3 td {
#           min-width: 100px;
#           text-align: center;
#     }    #T_1a163680_6f40_11e8_9242_642737c470c3 tr {
#           border-bottom: 1px dotted black;
#     }    #T_1a163680_6f40_11e8_9242_642737c470c3 th {
#           text-align: center;
#     }    #T_1a163680_6f40_11e8_9242_642737c470c3row0_col3 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row1_col3 {
#             background-color:  rgba(246, 185, 59, 0.3);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row2_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row3_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row4_col3 {
#             background-color:  rgba(184, 233, 148, 0.3);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row5_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row6_col3 {
#             background-color:  rgba(184, 233, 148, 0.5);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row7_col3 {
#             background-color:  rgba(184, 233, 148, 0.7);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row8_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row9_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row10_col3 {
#             background-color:  rgba(184, 233, 148, 0.8);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row11_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row12_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row13_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row14_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }    #T_1a163680_6f40_11e8_9242_642737c470c3row15_col3 {
#             background-color:  rgba(184, 233, 148, 1);
#         }</style>
# <table id="T_1a163680_6f40_11e8_9242_642737c470c3" ><caption>Tweet Variations - Filtered Data (compared to Sampled Data)</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >is_retweet, is_quote, is_reply, has_icard</th>
#         <th class="col_heading level0 col1" >value</th>
#         <th class="col_heading level0 col2" >percentage</th>
#         <th class="col_heading level0 col3" >difference (rank / percentage / diff)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_1a163680_6f40_11e8_9242_642737c470c3level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row0_col0" class="data row0 col0" >0 0 1 0 </td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row0_col1" class="data row0 col1" >4150938</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row0_col2" class="data row0 col2" >27.1658</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row0_col3" class="data row0 col3" > v <br>(2. / 22.311% / 4.855%)</td>
#     </tr>    <tr>
#         <th id="T_1a163680_6f40_11e8_9242_642737c470c3level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row1_col0" class="data row1 col0" >0 0 0 0 </td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row1_col1" class="data row1 col1" >4020492</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row1_col2" class="data row1 col2" >26.3121</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row1_col3" class="data row1 col3" > ^ <br>(1. / 34.833% / -8.521%)</td>
#     </tr>    <tr>
#         <th id="T_1a163680_6f40_11e8_9242_642737c470c3level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row2_col0" class="data row2 col0" >1 0 0 0 </td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row2_col1" class="data row2 col1" >3649900</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row2_col2" class="data row2 col2" >23.8868</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row2_col3" class="data row2 col3" > = <br>(3. / 18.849% / 5.037%)</td>
#     </tr>    <tr>
#         <th id="T_1a163680_6f40_11e8_9242_642737c470c3level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row3_col0" class="data row3 col0" >0 0 0 1 </td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row3_col1" class="data row3 col1" >1535315</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row3_col2" class="data row3 col2" >10.0479</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row3_col3" class="data row3 col3" > = <br>(4. / 12.598% / -2.551%)</td>
#     </tr>    <tr>
#         <th id="T_1a163680_6f40_11e8_9242_642737c470c3level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row4_col0" class="data row4 col0" >1 0 0 1 </td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row4_col1" class="data row4 col1" >928063</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row4_col2" class="data row4 col2" >6.0737</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row4_col3" class="data row4 col3" > = <br>(5. / 4.745% / 1.329%)</td>
#     </tr>    <tr>
#         <th id="T_1a163680_6f40_11e8_9242_642737c470c3level0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row5_col0" class="data row5 col0" >0 1 0 0 </td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row5_col1" class="data row5 col1" >477218</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row5_col2" class="data row5 col2" >3.12315</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row5_col3" class="data row5 col3" > = <br>(6. / 3.963% / -0.840%)</td>
#     </tr>    <tr>
#         <th id="T_1a163680_6f40_11e8_9242_642737c470c3level0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row6_col0" class="data row6 col0" >1 1 0 0 </td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row6_col1" class="data row6 col1" >394086</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row6_col2" class="data row6 col2" >2.57909</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row6_col3" class="data row6 col3" > = <br>(7. / 1.844% / 0.735%)</td>
#     </tr>    <tr>
#         <th id="T_1a163680_6f40_11e8_9242_642737c470c3level0_row7" class="row_heading level0 row7" >8</th>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row7_col0" class="data row7 col0" >0 0 1 1 </td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row7_col1" class="data row7 col1" >87698</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row7_col2" class="data row7 col2" >0.573939</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row7_col3" class="data row7 col3" > = <br>(8. / 0.633% / -0.059%)</td>
#     </tr>    <tr>
#         <th id="T_1a163680_6f40_11e8_9242_642737c470c3level0_row8" class="row_heading level0 row8" >9</th>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row8_col0" class="data row8 col0" >0 1 1 0 </td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row8_col1" class="data row8 col1" >20199</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row8_col2" class="data row8 col2" >0.132192</td>
#         <td id="T_1a163680_6f40_11e8_9242_642737c470c3row8_col3" class="data row8 col3" > =
